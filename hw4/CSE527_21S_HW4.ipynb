# %% [markdown]
# # CSE527 Homework 4
# **Due date: 23:59 on April 24, 2021 (Sat.)**
#
# In this semester, we will use Google Colab for the assignments, which allows us to utilize resources that some of us might not have in their local machines such as GPUs. You will need to use your Stony Brook (*.stonybrook.edu) account for coding and Google Drive to save your results.
#
# ## Google Colab Tutorial
# ---
# Go to https://colab.research.google.com/notebooks/, you will see a tutorial named "Welcome to Colaboratory" file, where you can learn the basics of using google colab.
#
# Settings used for assignments: ***Edit -> Notebook Settings -> Runtime Type (Python 3)***.
#
#
# ## Description
# ---
# This project is an introduction to deep learning tools for computer vision. You will design and train deep convolutional networks for scene recognition using [PyTorch](http://pytorch.org). You can visualize the
# structure of the network with [mNeuron] (http://vision03.csail.mit.edu/cnn_art/index.html)
#
# In Problem 1 of the project you will train a deep convolutional network from scratch to recognize scenes. The starter codes gives you methods to load data and display them. You will need to define a simple network architecture and add jittering, normalization, and regularization to increase recognition accuracy to 50, 60, or perhaps 70%. Unfortunately, we only have 2,400 training examples so it doesn't seem possible to train a network from scratch which outperforms hand-crafted features
#
# For Problem 2 you will instead fine-tune a pre-trained deep network to achieve about 85% accuracy on the task. We will use the pretrained AlexNet network which was not trained to recognize scenes at all.
#
# These two approaches represent the most common approaches to recognition problems in computer vision today -- train a deep network from scratch if you have enough data (it's not always obvious whether or not you do), and if you cannot then instead fine-tune a pre-trained network.
#
# There are 2 problems in this homework with a total of 120 points including 20 bonus points. Be sure to read **Submission Guidelines** below. They are important. For the problems requiring text descriptions, you might want to add a markdown block for that.
#
# ## Dataset
# ---
# Save the [dataset(click me)](https://drive.google.com/open?id=1NWC3TMsXSWN2TeoYMCjhf2N1b-WRDh-M) into your working folder in your Google Drive for this homework. <br>
# Under your root folder, there should be a folder named "data" (i.e. XXX/Surname_Givenname_SBUID/data) containing the images.
# **Do not upload** the data subfolder before submitting on blackboard due to size limit. There should be only one .ipynb file under your root folder Surname_Givenname_SBUID.
#
# ## Some Tutorials (PyTorch)
# ---
# - You will be using PyTorch for deep learning toolbox (follow the [link](http://pytorch.org) for installation).
# - For PyTorch beginners, please read this [tutorial](http://pytorch.org/tutorials/beginner/deep_learning_60min_blitz.html) before doing your homework.
# - Feel free to study more tutorials at http://pytorch.org/tutorials/.
# - Find cool visualization here at http://playground.tensorflow.org.

# %%
# import packages here
import cv2
import numpy as np
import matplotlib.pyplot as plt
import glob
import random
import time
from torchvision import transforms, datasets, models

import torch
import torchvision
import torchvision.transforms as transforms
import cv2

from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F

from google.colab.patches import cv2_imshow

# %%
# torch.cuda.empty_cache()

# %%
# Mount your google drive where you've saved your assignment folder
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Set your working directory (in your google drive)
#   change it to your specific homework directory.
# %cd '/content/gdrive/MyDrive/Courses/CV/homework/Bhide_Aditya_Nandan_113216565_hw4/'
# Out:
# /content/gdrive/MyDrive/Courses/CV/homework/Bhide_Aditya_Nandan_113216565_hw4

# %% [markdown]
# ## Problem 0: Loading and Preprocessing data
# ---
# (0 point) In this part, you are provided with a function that loads data into minibatches for training and testing in PyTorch. However, some preprocessing parts are missing. Your will need to implement them when doing Problem 1.

# %%
#--------------------------------------------------
#    Load Training Data and Testing Data
#--------------------------------------------------

def set_random_seed(seed):
     torch.manual_seed(seed)
     torch.cuda.manual_seed_all(seed)
     np.random.seed(seed)
     random.seed(seed)
     torch.backends.cudnn.deterministic = True
set_random_seed(11)

class_names = [name[13:] for name in glob.glob('./data/train/*')]
class_names = dict(zip(range(len(class_names)), class_names))
print("class_names: %s " % class_names)



def load_dataset(path, img_size, num_per_class=-1, batch_size=16, shuffle=False,
           augment=False, is_color=False, zero_centered=False, rotate=False):    
    data = []
    labels = []   
    channel_num = 3 if is_color else 1
    if len(data) == 0:
    # read images and resizing
        for id, class_name in class_names.items():
            print("Loading images from class: %s" % id)
            img_path_class = glob.glob(path + class_name + '/*.jpg')
            if num_per_class > 0:
                img_path_class = img_path_class[:num_per_class]
            labels.extend([id]*len(img_path_class))
            for filename in img_path_class:
                if is_color:
                    img = cv2.imread(filename)
                else:
                    img = cv2.imread(filename, 0)
                
                # resize the image
                img = cv2.resize(img, img_size, cv2.INTER_LINEAR)
                
                if is_color:
                    img = np.transpose(img, [2, 0, 1])
                
                # norm pixel values to [-1, 1]
                data.append(img.astype(np.float)/255*2-1)
    ##########--WRITE YOUR CODE HERE--##########
    # Data Augmentation 
    if augment:
        length = len(data)
        for i in range(length):
            data.append(cv2.flip(data[i], 1))
            labels.append(labels[i])
    if rotate:
        length = len(data)
        prob1 = 0.5
        for i in range(length):
            for j in range(3):
                if prob1 < random.uniform(0, 1):
                    angle = random.uniform(0, 20)
                    side = random.choice([-1,1])
                    rot_mat = cv2.getRotationMatrix2D((img_size[1]/2,img_size[0]/2),  int(side * angle),1)
                    # rot_mat = cv2.getRotationMatrix2D((img_size[1]/2,img_size[0]/2),  90, 1)
                    temp = cv2.warpAffine(data[i], rot_mat, data[i].shape[1::-1], flags=cv2.INTER_LINEAR)
                    data.append(temp)
                    labels.append(labels[i])
    
    print(len(data))
    print(len(labels))        
        


    ##########-------END OF CODE-------##########    
    
    ##########--WRITE YOUR CODE HERE--##########
    # Data Normalization
    if zero_centered:
        length = len(data)
        for i in range(length):
            data[i] = data[i] - data[i].mean()
    ##########-------END OF CODE-------##########
         
    # randomly permute (this step is important for training)
    if shuffle:
        bundle = list(zip(data, labels))
        random.shuffle(bundle)
        data, labels = zip(*bundle)
    
    # divide data into minibatches of TorchTensors
    if batch_size > 1:
        batch_data = []
        batch_labels = []
         
        for i in range(int(len(data) / batch_size)):
            minibatch_d = data[i*batch_size: (i+1)*batch_size]
            minibatch_d = np.reshape(minibatch_d, (batch_size, channel_num, img_size[0], img_size[1]))
            batch_data.append(torch.from_numpy(minibatch_d))

            minibatch_l = labels[i*batch_size: (i+1)*batch_size]
            batch_labels.append(torch.LongTensor(minibatch_l))
        data, labels = batch_data, batch_labels 

    return zip(batch_data, batch_labels)
# Out:
# class_names: {0: 'Forest', 1: 'Industrial', 2: 'Flower', 3: 'Coast', 4: 'InsideCity', 5: 'Office', 6: 'Bedroom', 7: 'Highway', 8: 'Street', 9: 'TallBuilding', 10: 'LivingRoom', 11: 'Suburb', 12: 'OpenCountry', 13: 'Mountain', 14: 'Kitchen', 15: 'Store'}

# %%
# load data into size (64, 64)
img_size = (64, 64)
batch_size = 64 # training sample number per batch

# load training dataset
trainloader_small = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True))
train_num = len(trainloader_small)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_small = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size))
test_num = len(testloader_small)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# 2400
# 2400
# Finish loading 37 minibatches (batch_size=64) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# 400
# 400
# Finish loading 6 minibatches (batch_size=64) of testing samples.

# %%
# show some images
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    if len(npimg.shape) > 2:
        npimg = np.transpose(img, [1, 2, 0])
    plt.figure
    plt.imshow(npimg, 'gray')
    plt.show()
img, label = trainloader_small[0][0][25][0], trainloader_small[0][1][14]
label = int(np.array(label))
print(class_names[label])
imshow(img)
# Out:
# Coast

# %% [markdown]
# ## Problem 1: Training a Network From Scratch
# Gone are the days of hand designed features. Now we have end-to-end learning in which a highly non-linear representation is learned for our data to maximize our objective function (in this case, 16-way classification accuracy). Let's start!

# %% [markdown]
# First, let's define a simpe network architecture.

# %%
#--------------------------------------------------
#       Define Network Architecture
#--------------------------------------------------
class TNet(nn.Module):
    def __init__(self):
      super(TNet,self).__init__()  
           
      self.features = torch.nn.Sequential(
        nn.Conv2d(1, 16, 3),
        nn.ReLU(),
        nn.MaxPool2d(4, stride=4), 
      )
      
      self.classifier = nn.Sequential(
         nn.Linear(3600, 16), 
      )
      
    def forward(self, x):
      x = self.features(x)  
      x = torch.flatten(x, 1)
      x = self.classifier(x)
      return x

# %% [markdown]
# Then, let's define model training and evaluation functions.

# %%
#--------------------------------------------------
#       Model Training Function
#--------------------------------------------------
import torch.optim as optim
import time
  
def trainModel(net, trainloader, train_option, testloader=None):  
  loss_func = nn.CrossEntropyLoss()
  lr = train_option['lr']
  epoch = train_option['epoch']
  device = train_option['device'] if 'device' in train_option.keys() else 'cpu'
  log_iter = train_option['log_iter'] if 'log_iter' in train_option.keys() else 20
  eval_epoch = 1
  
  if 'optimizer' in train_option.keys():
    optimizer = train_option['optimizer']
  else:
    optimizer = optim.Adam(net.parameters(), lr=lr)

  start_time = time.time()
  if device == 'gpu':
    net = net.cuda()

  iters = 0
  running_loss = 0.0
  max_accuracy = -1
  for ep in range(epoch):
    net.train()        
    for iter, (x, y) in enumerate(trainloader):
      iters += 1
      batch_x = Variable(x).float()
      batch_y = Variable(y).long()
      if device == 'gpu':
        batch_x = batch_x.cuda()
        batch_y = batch_y.cuda()

      outputs = net(batch_x)
      loss = loss_func(outputs, batch_y)
      optimizer.zero_grad()
      loss.backward()
      optimizer.step()
      running_loss += loss.item()
      
      time_lapse = time.strftime('%H:%M:%S', time.gmtime(time.time() - start_time))
      if iter % log_iter == 0:
        print('Epoch:{:2d} | Iter:{:5d} | Time: {} | Train Loss: {:.4f} | Average Loss: {:.4f} '.format(ep+1, iter, time_lapse, loss.item(), running_loss/iters))
   
    if testloader is not None and ep % eval_epoch == 0:
      accuracy = evalModel(net, testloader)
      if max_accuracy < accuracy:
        max_accuracy = accuracy
  return max_accuracy

# %%
#--------------------------------------------------
#       Model Evaluating Function
#--------------------------------------------------
import time
  
def evalModel(net, testloader): 
  acc = 0.0
  count = 0
  start_time = time.time()
  device = 'gpu' if next(net.parameters()).is_cuda else 'cpu'
  net.eval()
  
  for iter, (x, y) in enumerate(testloader):
        count += x.shape[0]
        batch_x = Variable(x).float()
        batch_y = Variable(y).long()
        if device == 'gpu':
          batch_x = batch_x.cuda()
          batch_y = batch_y.cuda()
        outputs = net(batch_x)
        acc += torch.sum(outputs.max(1)[1]==batch_y)
        
  time_lapse = time.strftime('%H:%M:%S', time.gmtime(time.time() - start_time))
  print('Accuracy: {:5f} | Time: {}'.format(acc/count,time_lapse))
  return (acc/count)

# %% [markdown]
# Finally, let's start training and evaluation.

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
net = TNet()
print(net)
train_option = {}
train_option['lr'] = 0.002
train_option['epoch'] = 20
train_option['device'] = 'gpu'
trainModel(net, trainloader_small, train_option, testloader_small)
# Out:
# TNet(
#   (features): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=3600, out_features=16, bias=True)
#   )
# )
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.7550 | Average Loss: 2.7550
# Epoch: 1 | Iter:   20 | Time: 00:00:00 | Train Loss: 2.2938 | Average Loss: 2.7652
# Accuracy: 0.346354 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.6618 | Average Loss: 2.5200
# Epoch: 2 | Iter:   20 | Time: 00:00:00 | Train Loss: 1.7068 | Average Loss: 2.3115
# Accuracy: 0.429688 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.3608 | Average Loss: 2.1844
# Epoch: 3 | Iter:   20 | Time: 00:00:00 | Train Loss: 1.3809 | Average Loss: 2.0610
# Accuracy: 0.473958 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.1695 | Average Loss: 1.9707
# Epoch: 4 | Iter:   20 | Time: 00:00:00 | Train Loss: 1.1485 | Average Loss: 1.8791
# Accuracy: 0.481771 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.0044 | Average Loss: 1.8060
# Epoch: 5 | Iter:   20 | Time: 00:00:00 | Train Loss: 0.9548 | Average Loss: 1.7301
# Accuracy: 0.463542 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:00 | Train Loss: 0.8564 | Average Loss: 1.6678
# Epoch: 6 | Iter:   20 | Time: 00:00:00 | Train Loss: 0.7886 | Average Loss: 1.6021
# Accuracy: 0.450521 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:00 | Train Loss: 0.7294 | Average Loss: 1.5476
# Epoch: 7 | Iter:   20 | Time: 00:00:00 | Train Loss: 0.6507 | Average Loss: 1.4898
# Accuracy: 0.450521 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:00 | Train Loss: 0.6334 | Average Loss: 1.4416
# Epoch: 8 | Iter:   20 | Time: 00:00:01 | Train Loss: 0.5377 | Average Loss: 1.3902
# Accuracy: 0.447917 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.5618 | Average Loss: 1.3475
# Epoch: 9 | Iter:   20 | Time: 00:00:01 | Train Loss: 0.4463 | Average Loss: 1.3016
# Accuracy: 0.440104 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.4869 | Average Loss: 1.2632
# Epoch:10 | Iter:   20 | Time: 00:00:01 | Train Loss: 0.3921 | Average Loss: 1.2220
# Accuracy: 0.450521 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.4227 | Average Loss: 1.1876
# Epoch:11 | Iter:   20 | Time: 00:00:01 | Train Loss: 0.3500 | Average Loss: 1.1507
# Accuracy: 0.463542 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.3795 | Average Loss: 1.1211
# Epoch:12 | Iter:   20 | Time: 00:00:01 | Train Loss: 0.3134 | Average Loss: 1.0885
# Accuracy: 0.458333 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.3750 | Average Loss: 1.0637
# Epoch:13 | Iter:   20 | Time: 00:00:01 | Train Loss: 0.3100 | Average Loss: 1.0353
# Accuracy: 0.442708 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.4385 | Average Loss: 1.0135
# Epoch:14 | Iter:   20 | Time: 00:00:01 | Train Loss: 0.3164 | Average Loss: 0.9894
# Accuracy: 0.427083 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.3880 | Average Loss: 0.9689
# Epoch:15 | Iter:   20 | Time: 00:00:01 | Train Loss: 0.3855 | Average Loss: 0.9475
# Accuracy: 0.442708 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.3625 | Average Loss: 0.9289
# Epoch:16 | Iter:   20 | Time: 00:00:02 | Train Loss: 0.3117 | Average Loss: 0.9087
# Accuracy: 0.450521 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.2292 | Average Loss: 0.8921
# Epoch:17 | Iter:   20 | Time: 00:00:02 | Train Loss: 0.1960 | Average Loss: 0.8729
# Accuracy: 0.434896 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.2730 | Average Loss: 0.8571
# Epoch:18 | Iter:   20 | Time: 00:00:02 | Train Loss: 0.1447 | Average Loss: 0.8385
# Accuracy: 0.429688 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.3520 | Average Loss: 0.8239
# Epoch:19 | Iter:   20 | Time: 00:00:02 | Train Loss: 0.2554 | Average Loss: 0.8091
# Accuracy: 0.416667 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.3649 | Average Loss: 0.7964
# Epoch:20 | Iter:   20 | Time: 00:00:02 | Train Loss: 0.4866 | Average Loss: 0.7840
# Accuracy: 0.434896 | Time: 00:00:00
# tensor(0.4818, device='cuda:0')

# %% [markdown]
# Great! You would get around 0.45-0.50 accuracy by this very simple network. Now it's your job to beat this result.
#
# ### Problem 1.1
# (35 points) Try to boost the accuracy by doing the following steps:
#
# **Data Augmentation**: We don't have enough training data, let's augment the training data.
# If you **left-right flip (mirror) an image** of a scene, it never changes categories. A kitchen doesn't become a forest when mirrored. This isn't true in all domains — a "d" becomes a "b" when mirrored, so you can't "jitter" digit recognition training data in the same way. But we can synthetically increase our amount of training data by left-right mirroring training images during the learning process.
#
# After you implement mirroring, you should notice that your training error doesn't drop as quickly. That's actually a good thing, because it means the network isn't overfitting to the 2,400 original training images as much (because it sees 4,800 training images now, although they're not as good as 4,800 truly independent samples). Because the training and test errors fall more slowly, you may need more training epochs or you may try modifying the learning rate. You are **required** to implement mirroring as data augmentation for this part.
#
# You can try more elaborate forms of jittering -- zooming in a random amount, rotating a random amount, taking a random crop, etc. These are not required, you might want to try these in the bonus part.
#
# **Data Normalization**: The images aren't **zero-centered**. One simple trick which can help a lot is to subtract the mean from every image. It would arguably be more proper to only compute the mean from the training images (since the test/validation images should be strictly held out) but it won't make much of a difference. This part is **required**.
#
# **Network Regularization**: Add **dropout layer**. If you train your network (especially for more than the default 30 epochs) you'll see that the training error can decrease to zero while the val top1 error hovers at 40% to 50%. The network has learned weights which can perfectly recognize the training data, but those weights don't generalize to held out test data. The best regularization would be more training data but we don't have that. Instead we will use dropout regularization.
#
# What does dropout regularization do? It randomly turns off network connections at training time to fight overfitting. This prevents a unit in one layer from relying too strongly on a single unit in the previous layer. Dropout regularization can be interpreted as simultaneously training many "thinned" versions of your network. At test, all connections are restored which is analogous to taking an average prediction over all of the "thinned" networks. You can see a more complete discussion of dropout regularization in this [paper](https://www.cs.toronto.edu/~hinton/absps/JMLRdropout.pdf).
#
# The dropout layer has only one free parameter — the dropout rate — the proportion of connections that are randomly deleted. The default of 0.5 should be fine. Insert a dropout layer between your convolutional layers. In particular, insert it directly before your last convolutional layer (and try others if that helps). Your train accuracy should decrease much more slowly. That's to be expected — you're making life much harder for the training algorithm by cutting out connections randomly. In this part, you are **required** to add dropout layer to your network.
#
# **Please give detailed descriptions of your network layout in the following format:**<br>
# Data augmentation: [descriptions]<br>
# Data normalization: [descriptions]<br>
# Layer 1: [layer_type]: [Parameters]<br>
# Layer 2: [layer_type]: [Parameters]<br>
# ...<br>
# **Then report the final accuracy on test set.**
#
# The minimum accuracy required for this section is **0.55**.

# %%
# load data into size (64, 64)
img_size = (64, 64)
batch_size = 64 # training sample number per batch

# load training dataset
trainloader_small = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True, augment=True, zero_centered=True))
train_num = len(trainloader_small)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_small = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size, zero_centered=True))
test_num = len(testloader_small)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# 4800
# 4800
# Finish loading 75 minibatches (batch_size=64) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# 400
# 400
# Finish loading 6 minibatches (batch_size=64) of testing samples.

# %%
# --------------------------------------------------
#       Define Network Architecture
# --------------------------------------------------
class Adi_Net(nn.Module):
  def __init__(self):
    super(Adi_Net,self).__init__()  
          
    self.features = torch.nn.Sequential(
      nn.Conv2d(1, 16, 3),
      nn.ReLU(),
      nn.MaxPool2d(2), 
      nn.Conv2d(16, 64, 3),
      nn.ReLU(),
      nn.MaxPool2d(2),
    )
    
    self.classifier = nn.Sequential(
        nn.Linear(32* 14* 14, 1024),
        nn.Dropout(p=0.5),
        nn.Linear(1024, 16),
    )
    
  def forward(self, x):
    x = self.features(x) 
    # print(x.size()) 
    x = torch.flatten(x, 1)
    x = self.classifier(x)
    return x

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
net = Adi_Net()
train_option = {}
train_option['lr'] = 0.0001
train_option['epoch'] = 30
train_option['device'] = 'gpu'
print(type(trainloader_small))
max_accuracy = trainModel(net, trainloader_small, train_option, testloader_small)
print("max accuracy", max_accuracy)
# Out:
# <class 'list'>
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.7804 | Average Loss: 2.7804
# Epoch: 1 | Iter:   20 | Time: 00:00:00 | Train Loss: 2.6815 | Average Loss: 2.7340
# Epoch: 1 | Iter:   40 | Time: 00:00:00 | Train Loss: 2.5931 | Average Loss: 2.6779
# Epoch: 1 | Iter:   60 | Time: 00:00:00 | Train Loss: 2.3723 | Average Loss: 2.6182
# Accuracy: 0.343750 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.2279 | Average Loss: 2.5712
# Epoch: 2 | Iter:   20 | Time: 00:00:00 | Train Loss: 2.0750 | Average Loss: 2.5050
# Epoch: 2 | Iter:   40 | Time: 00:00:01 | Train Loss: 2.2300 | Average Loss: 2.4508
# Epoch: 2 | Iter:   60 | Time: 00:00:01 | Train Loss: 2.0504 | Average Loss: 2.4035
# Accuracy: 0.351562 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.0069 | Average Loss: 2.3668
# Epoch: 3 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.8657 | Average Loss: 2.3206
# Epoch: 3 | Iter:   40 | Time: 00:00:01 | Train Loss: 2.0649 | Average Loss: 2.2813
# Epoch: 3 | Iter:   60 | Time: 00:00:01 | Train Loss: 1.8784 | Average Loss: 2.2472
# Accuracy: 0.398438 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.8450 | Average Loss: 2.2218
# Epoch: 4 | Iter:   20 | Time: 00:00:02 | Train Loss: 1.6588 | Average Loss: 2.1879
# Epoch: 4 | Iter:   40 | Time: 00:00:02 | Train Loss: 1.9569 | Average Loss: 2.1588
# Epoch: 4 | Iter:   60 | Time: 00:00:02 | Train Loss: 1.8493 | Average Loss: 2.1337
# Accuracy: 0.414062 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.7511 | Average Loss: 2.1132
# Epoch: 5 | Iter:   20 | Time: 00:00:02 | Train Loss: 1.5929 | Average Loss: 2.0860
# Epoch: 5 | Iter:   40 | Time: 00:00:02 | Train Loss: 1.7903 | Average Loss: 2.0607
# Epoch: 5 | Iter:   60 | Time: 00:00:03 | Train Loss: 1.6519 | Average Loss: 2.0404
# Accuracy: 0.442708 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.6598 | Average Loss: 2.0236
# Epoch: 6 | Iter:   20 | Time: 00:00:03 | Train Loss: 1.4800 | Average Loss: 2.0003
# Epoch: 6 | Iter:   40 | Time: 00:00:03 | Train Loss: 1.7216 | Average Loss: 1.9785
# Epoch: 6 | Iter:   60 | Time: 00:00:03 | Train Loss: 1.5003 | Average Loss: 1.9588
# Accuracy: 0.453125 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.5785 | Average Loss: 1.9439
# Epoch: 7 | Iter:   20 | Time: 00:00:03 | Train Loss: 1.4155 | Average Loss: 1.9228
# Epoch: 7 | Iter:   40 | Time: 00:00:04 | Train Loss: 1.5003 | Average Loss: 1.9025
# Epoch: 7 | Iter:   60 | Time: 00:00:04 | Train Loss: 1.3712 | Average Loss: 1.8854
# Accuracy: 0.466146 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.4062 | Average Loss: 1.8715
# Epoch: 8 | Iter:   20 | Time: 00:00:04 | Train Loss: 1.3109 | Average Loss: 1.8522
# Epoch: 8 | Iter:   40 | Time: 00:00:04 | Train Loss: 1.5072 | Average Loss: 1.8339
# Epoch: 8 | Iter:   60 | Time: 00:00:04 | Train Loss: 1.4029 | Average Loss: 1.8179
# Accuracy: 0.481771 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.3145 | Average Loss: 1.8056
# Epoch: 9 | Iter:   20 | Time: 00:00:05 | Train Loss: 1.2182 | Average Loss: 1.7878
# Epoch: 9 | Iter:   40 | Time: 00:00:05 | Train Loss: 1.3675 | Average Loss: 1.7704
# Epoch: 9 | Iter:   60 | Time: 00:00:05 | Train Loss: 1.1643 | Average Loss: 1.7551
# Accuracy: 0.497396 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.2698 | Average Loss: 1.7435
# Epoch:10 | Iter:   20 | Time: 00:00:05 | Train Loss: 1.1388 | Average Loss: 1.7270
# Epoch:10 | Iter:   40 | Time: 00:00:05 | Train Loss: 1.2571 | Average Loss: 1.7112
# Epoch:10 | Iter:   60 | Time: 00:00:06 | Train Loss: 1.1179 | Average Loss: 1.6972
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:00:06 | Train Loss: 1.2119 | Average Loss: 1.6865
# Epoch:11 | Iter:   20 | Time: 00:00:06 | Train Loss: 1.0919 | Average Loss: 1.6713
# Epoch:11 | Iter:   40 | Time: 00:00:06 | Train Loss: 1.1644 | Average Loss: 1.6563
# Epoch:11 | Iter:   60 | Time: 00:00:06 | Train Loss: 1.0594 | Average Loss: 1.6429
# Accuracy: 0.518229 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:00:06 | Train Loss: 1.1297 | Average Loss: 1.6330
# Epoch:12 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.9675 | Average Loss: 1.6188
# Epoch:12 | Iter:   40 | Time: 00:00:07 | Train Loss: 1.0806 | Average Loss: 1.6050
# Epoch:12 | Iter:   60 | Time: 00:00:07 | Train Loss: 0.9919 | Average Loss: 1.5922
# Accuracy: 0.515625 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:00:07 | Train Loss: 1.0742 | Average Loss: 1.5830
# Epoch:13 | Iter:   20 | Time: 00:00:07 | Train Loss: 0.8838 | Average Loss: 1.5697
# Epoch:13 | Iter:   40 | Time: 00:00:07 | Train Loss: 1.0171 | Average Loss: 1.5566
# Epoch:13 | Iter:   60 | Time: 00:00:07 | Train Loss: 0.9261 | Average Loss: 1.5448
# Accuracy: 0.520833 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:00:07 | Train Loss: 1.0201 | Average Loss: 1.5360
# Epoch:14 | Iter:   20 | Time: 00:00:08 | Train Loss: 0.8574 | Average Loss: 1.5236
# Epoch:14 | Iter:   40 | Time: 00:00:08 | Train Loss: 0.9161 | Average Loss: 1.5116
# Epoch:14 | Iter:   60 | Time: 00:00:08 | Train Loss: 0.8318 | Average Loss: 1.5006
# Accuracy: 0.513021 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:00:08 | Train Loss: 1.0103 | Average Loss: 1.4924
# Epoch:15 | Iter:   20 | Time: 00:00:08 | Train Loss: 0.7938 | Average Loss: 1.4806
# Epoch:15 | Iter:   40 | Time: 00:00:08 | Train Loss: 0.8783 | Average Loss: 1.4693
# Epoch:15 | Iter:   60 | Time: 00:00:09 | Train Loss: 0.8633 | Average Loss: 1.4589
# Accuracy: 0.510417 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.8523 | Average Loss: 1.4511
# Epoch:16 | Iter:   20 | Time: 00:00:09 | Train Loss: 0.7516 | Average Loss: 1.4400
# Epoch:16 | Iter:   40 | Time: 00:00:09 | Train Loss: 0.7714 | Average Loss: 1.4290
# Epoch:16 | Iter:   60 | Time: 00:00:09 | Train Loss: 0.7010 | Average Loss: 1.4189
# Accuracy: 0.523438 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.9514 | Average Loss: 1.4117
# Epoch:17 | Iter:   20 | Time: 00:00:09 | Train Loss: 0.7474 | Average Loss: 1.4012
# Epoch:17 | Iter:   40 | Time: 00:00:10 | Train Loss: 0.8010 | Average Loss: 1.3913
# Epoch:17 | Iter:   60 | Time: 00:00:10 | Train Loss: 0.7032 | Average Loss: 1.3818
# Accuracy: 0.528646 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.7702 | Average Loss: 1.3746
# Epoch:18 | Iter:   20 | Time: 00:00:10 | Train Loss: 0.6583 | Average Loss: 1.3646
# Epoch:18 | Iter:   40 | Time: 00:00:10 | Train Loss: 0.6984 | Average Loss: 1.3551
# Epoch:18 | Iter:   60 | Time: 00:00:10 | Train Loss: 0.6637 | Average Loss: 1.3460
# Accuracy: 0.533854 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.7168 | Average Loss: 1.3393
# Epoch:19 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.6727 | Average Loss: 1.3300
# Epoch:19 | Iter:   40 | Time: 00:00:11 | Train Loss: 0.6334 | Average Loss: 1.3208
# Epoch:19 | Iter:   60 | Time: 00:00:11 | Train Loss: 0.6463 | Average Loss: 1.3120
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.6588 | Average Loss: 1.3055
# Epoch:20 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.6604 | Average Loss: 1.2966
# Epoch:20 | Iter:   40 | Time: 00:00:11 | Train Loss: 0.5715 | Average Loss: 1.2878
# Epoch:20 | Iter:   60 | Time: 00:00:12 | Train Loss: 0.5435 | Average Loss: 1.2795
# Accuracy: 0.536458 | Time: 00:00:00
# Epoch:21 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.6624 | Average Loss: 1.2734
# Epoch:21 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.6357 | Average Loss: 1.2648
# Epoch:21 | Iter:   40 | Time: 00:00:12 | Train Loss: 0.6310 | Average Loss: 1.2564
# Epoch:21 | Iter:   60 | Time: 00:00:12 | Train Loss: 0.5231 | Average Loss: 1.2485
# Accuracy: 0.544271 | Time: 00:00:00
# Epoch:22 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.5832 | Average Loss: 1.2425
# Epoch:22 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.5832 | Average Loss: 1.2343
# Epoch:22 | Iter:   40 | Time: 00:00:13 | Train Loss: 0.5810 | Average Loss: 1.2263
# Epoch:22 | Iter:   60 | Time: 00:00:13 | Train Loss: 0.5157 | Average Loss: 1.2187
# Accuracy: 0.541667 | Time: 00:00:00
# Epoch:23 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.5661 | Average Loss: 1.2130
# Epoch:23 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.4775 | Average Loss: 1.2049
# Epoch:23 | Iter:   40 | Time: 00:00:13 | Train Loss: 0.5102 | Average Loss: 1.1973
# Epoch:23 | Iter:   60 | Time: 00:00:13 | Train Loss: 0.4265 | Average Loss: 1.1899
# Accuracy: 0.526042 | Time: 00:00:00
# Epoch:24 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.5684 | Average Loss: 1.1845
# Epoch:24 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.5303 | Average Loss: 1.1770
# Epoch:24 | Iter:   40 | Time: 00:00:14 | Train Loss: 0.4838 | Average Loss: 1.1698
# Epoch:24 | Iter:   60 | Time: 00:00:14 | Train Loss: 0.4192 | Average Loss: 1.1626
# Accuracy: 0.523438 | Time: 00:00:00
# Epoch:25 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.4807 | Average Loss: 1.1574
# Epoch:25 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.4624 | Average Loss: 1.1501
# Epoch:25 | Iter:   40 | Time: 00:00:14 | Train Loss: 0.4872 | Average Loss: 1.1431
# Epoch:25 | Iter:   60 | Time: 00:00:15 | Train Loss: 0.4096 | Average Loss: 1.1362
# Accuracy: 0.549479 | Time: 00:00:00
# Epoch:26 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.4884 | Average Loss: 1.1312
# Epoch:26 | Iter:   20 | Time: 00:00:15 | Train Loss: 0.4485 | Average Loss: 1.1241
# Epoch:26 | Iter:   40 | Time: 00:00:15 | Train Loss: 0.4501 | Average Loss: 1.1174
# Epoch:26 | Iter:   60 | Time: 00:00:15 | Train Loss: 0.3683 | Average Loss: 1.1108
# Accuracy: 0.544271 | Time: 00:00:00
# Epoch:27 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.4413 | Average Loss: 1.1060
# Epoch:27 | Iter:   20 | Time: 00:00:16 | Train Loss: 0.4723 | Average Loss: 1.0992
# Epoch:27 | Iter:   40 | Time: 00:00:16 | Train Loss: 0.3988 | Average Loss: 1.0926
# Epoch:27 | Iter:   60 | Time: 00:00:16 | Train Loss: 0.3312 | Average Loss: 1.0862
# Accuracy: 0.557292 | Time: 00:00:00
# Epoch:28 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.4106 | Average Loss: 1.0815
# Epoch:28 | Iter:   20 | Time: 00:00:16 | Train Loss: 0.4646 | Average Loss: 1.0750
# Epoch:28 | Iter:   40 | Time: 00:00:16 | Train Loss: 0.4163 | Average Loss: 1.0687
# Epoch:28 | Iter:   60 | Time: 00:00:16 | Train Loss: 0.2944 | Average Loss: 1.0624
# Accuracy: 0.546875 | Time: 00:00:00
# Epoch:29 | Iter:    0 | Time: 00:00:17 | Train Loss: 0.3780 | Average Loss: 1.0579
# Epoch:29 | Iter:   20 | Time: 00:00:17 | Train Loss: 0.4269 | Average Loss: 1.0515
# Epoch:29 | Iter:   40 | Time: 00:00:17 | Train Loss: 0.3722 | Average Loss: 1.0455
# Epoch:29 | Iter:   60 | Time: 00:00:17 | Train Loss: 0.2613 | Average Loss: 1.0394
# Accuracy: 0.549479 | Time: 00:00:00
# Epoch:30 | Iter:    0 | Time: 00:00:17 | Train Loss: 0.3039 | Average Loss: 1.0349
# Epoch:30 | Iter:   20 | Time: 00:00:17 | Train Loss: 0.4060 | Average Loss: 1.0288
# Epoch:30 | Iter:   40 | Time: 00:00:18 | Train Loss: 0.3143 | Average Loss: 1.0230
# Epoch:30 | Iter:   60 | Time: 00:00:18 | Train Loss: 0.2984 | Average Loss: 1.0171
# Accuracy: 0.552083 | Time: 00:00:00
# Epoch:31 | Iter:    0 | Time: 00:00:18 | Train Loss: 0.2684 | Average Loss: 1.0128
# Epoch:31 | Iter:   20 | Time: 00:00:18 | Train Loss: 0.3376 | Average Loss: 1.0068
# Epoch:31 | Iter:   40 | Time: 00:00:18 | Train Loss: 0.3816 | Average Loss: 1.0011
# Epoch:31 | Iter:   60 | Time: 00:00:18 | Train Loss: 0.2524 | Average Loss: 0.9953
# Accuracy: 0.565104 | Time: 00:00:00
# Epoch:32 | Iter:    0 | Time: 00:00:18 | Train Loss: 0.3095 | Average Loss: 0.9912
# Epoch:32 | Iter:   20 | Time: 00:00:19 | Train Loss: 0.3634 | Average Loss: 0.9854
# Epoch:32 | Iter:   40 | Time: 00:00:19 | Train Loss: 0.2994 | Average Loss: 0.9799
# Epoch:32 | Iter:   60 | Time: 00:00:19 | Train Loss: 0.2369 | Average Loss: 0.9745
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:33 | Iter:    0 | Time: 00:00:19 | Train Loss: 0.3210 | Average Loss: 0.9704
# Epoch:33 | Iter:   20 | Time: 00:00:19 | Train Loss: 0.3437 | Average Loss: 0.9649
# Epoch:33 | Iter:   40 | Time: 00:00:19 | Train Loss: 0.3251 | Average Loss: 0.9595
# Epoch:33 | Iter:   60 | Time: 00:00:20 | Train Loss: 0.1795 | Average Loss: 0.9542
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch:34 | Iter:    0 | Time: 00:00:20 | Train Loss: 0.2339 | Average Loss: 0.9503
# Epoch:34 | Iter:   20 | Time: 00:00:20 | Train Loss: 0.3381 | Average Loss: 0.9449
# Epoch:34 | Iter:   40 | Time: 00:00:20 | Train Loss: 0.2859 | Average Loss: 0.9397
# Epoch:34 | Iter:   60 | Time: 00:00:20 | Train Loss: 0.2015 | Average Loss: 0.9345
# Accuracy: 0.557292 | Time: 00:00:00
# Epoch:35 | Iter:    0 | Time: 00:00:20 | Train Loss: 0.2591 | Average Loss: 0.9307
# Epoch:35 | Iter:   20 | Time: 00:00:20 | Train Loss: 0.2668 | Average Loss: 0.9255
# Epoch:35 | Iter:   40 | Time: 00:00:21 | Train Loss: 0.2609 | Average Loss: 0.9205
# Epoch:35 | Iter:   60 | Time: 00:00:21 | Train Loss: 0.1896 | Average Loss: 0.9154
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:36 | Iter:    0 | Time: 00:00:21 | Train Loss: 0.2517 | Average Loss: 0.9117
# Epoch:36 | Iter:   20 | Time: 00:00:21 | Train Loss: 0.2592 | Average Loss: 0.9066
# Epoch:36 | Iter:   40 | Time: 00:00:21 | Train Loss: 0.2114 | Average Loss: 0.9017
# Epoch:36 | Iter:   60 | Time: 00:00:21 | Train Loss: 0.1413 | Average Loss: 0.8968
# Accuracy: 0.549479 | Time: 00:00:00
# Epoch:37 | Iter:    0 | Time: 00:00:21 | Train Loss: 0.2101 | Average Loss: 0.8931
# Epoch:37 | Iter:   20 | Time: 00:00:22 | Train Loss: 0.2518 | Average Loss: 0.8883
# Epoch:37 | Iter:   40 | Time: 00:00:22 | Train Loss: 0.2238 | Average Loss: 0.8836
# Epoch:37 | Iter:   60 | Time: 00:00:22 | Train Loss: 0.1779 | Average Loss: 0.8789
# Accuracy: 0.559896 | Time: 00:00:00
# Epoch:38 | Iter:    0 | Time: 00:00:22 | Train Loss: 0.1987 | Average Loss: 0.8754
# Epoch:38 | Iter:   20 | Time: 00:00:22 | Train Loss: 0.2984 | Average Loss: 0.8707
# Epoch:38 | Iter:   40 | Time: 00:00:22 | Train Loss: 0.2005 | Average Loss: 0.8661
# Epoch:38 | Iter:   60 | Time: 00:00:23 | Train Loss: 0.1465 | Average Loss: 0.8615
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:39 | Iter:    0 | Time: 00:00:23 | Train Loss: 0.1876 | Average Loss: 0.8581
# Epoch:39 | Iter:   20 | Time: 00:00:23 | Train Loss: 0.2218 | Average Loss: 0.8536
# Epoch:39 | Iter:   40 | Time: 00:00:23 | Train Loss: 0.2218 | Average Loss: 0.8491
# Epoch:39 | Iter:   60 | Time: 00:00:23 | Train Loss: 0.1216 | Average Loss: 0.8447
# Accuracy: 0.546875 | Time: 00:00:00
# Epoch:40 | Iter:    0 | Time: 00:00:23 | Train Loss: 0.1594 | Average Loss: 0.8413
# Epoch:40 | Iter:   20 | Time: 00:00:23 | Train Loss: 0.2524 | Average Loss: 0.8369
# Epoch:40 | Iter:   40 | Time: 00:00:24 | Train Loss: 0.1641 | Average Loss: 0.8326
# Epoch:40 | Iter:   60 | Time: 00:00:24 | Train Loss: 0.1162 | Average Loss: 0.8283
# Accuracy: 0.570312 | Time: 00:00:00
# Epoch:41 | Iter:    0 | Time: 00:00:24 | Train Loss: 0.1337 | Average Loss: 0.8251
# Epoch:41 | Iter:   20 | Time: 00:00:24 | Train Loss: 0.1903 | Average Loss: 0.8208
# Epoch:41 | Iter:   40 | Time: 00:00:24 | Train Loss: 0.1822 | Average Loss: 0.8165
# Epoch:41 | Iter:   60 | Time: 00:00:24 | Train Loss: 0.1399 | Average Loss: 0.8123
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:42 | Iter:    0 | Time: 00:00:25 | Train Loss: 0.1314 | Average Loss: 0.8093
# Epoch:42 | Iter:   20 | Time: 00:00:25 | Train Loss: 0.2263 | Average Loss: 0.8051
# Epoch:42 | Iter:   40 | Time: 00:00:25 | Train Loss: 0.1424 | Average Loss: 0.8011
# Epoch:42 | Iter:   60 | Time: 00:00:25 | Train Loss: 0.1119 | Average Loss: 0.7969
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:43 | Iter:    0 | Time: 00:00:25 | Train Loss: 0.1365 | Average Loss: 0.7939
# Epoch:43 | Iter:   20 | Time: 00:00:25 | Train Loss: 0.2276 | Average Loss: 0.7899
# Epoch:43 | Iter:   40 | Time: 00:00:25 | Train Loss: 0.1700 | Average Loss: 0.7860
# Epoch:43 | Iter:   60 | Time: 00:00:26 | Train Loss: 0.0826 | Average Loss: 0.7820
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:44 | Iter:    0 | Time: 00:00:26 | Train Loss: 0.0906 | Average Loss: 0.7790
# Epoch:44 | Iter:   20 | Time: 00:00:26 | Train Loss: 0.2076 | Average Loss: 0.7751
# Epoch:44 | Iter:   40 | Time: 00:00:26 | Train Loss: 0.1220 | Average Loss: 0.7713
# Epoch:44 | Iter:   60 | Time: 00:00:26 | Train Loss: 0.0932 | Average Loss: 0.7674
# Accuracy: 0.565104 | Time: 00:00:00
# Epoch:45 | Iter:    0 | Time: 00:00:26 | Train Loss: 0.0868 | Average Loss: 0.7646
# Epoch:45 | Iter:   20 | Time: 00:00:27 | Train Loss: 0.1709 | Average Loss: 0.7608
# Epoch:45 | Iter:   40 | Time: 00:00:27 | Train Loss: 0.1172 | Average Loss: 0.7571
# Epoch:45 | Iter:   60 | Time: 00:00:27 | Train Loss: 0.0701 | Average Loss: 0.7533
# Accuracy: 0.570312 | Time: 00:00:00
# Epoch:46 | Iter:    0 | Time: 00:00:27 | Train Loss: 0.1039 | Average Loss: 0.7505
# Epoch:46 | Iter:   20 | Time: 00:00:27 | Train Loss: 0.1626 | Average Loss: 0.7469
# Epoch:46 | Iter:   40 | Time: 00:00:27 | Train Loss: 0.1085 | Average Loss: 0.7433
# Epoch:46 | Iter:   60 | Time: 00:00:27 | Train Loss: 0.0735 | Average Loss: 0.7397
# Accuracy: 0.583333 | Time: 00:00:00
# Epoch:47 | Iter:    0 | Time: 00:00:28 | Train Loss: 0.0986 | Average Loss: 0.7370
# Epoch:47 | Iter:   20 | Time: 00:00:28 | Train Loss: 0.1207 | Average Loss: 0.7334
# Epoch:47 | Iter:   40 | Time: 00:00:28 | Train Loss: 0.0941 | Average Loss: 0.7299
# Epoch:47 | Iter:   60 | Time: 00:00:28 | Train Loss: 0.0997 | Average Loss: 0.7264
# Accuracy: 0.572917 | Time: 00:00:00
# Epoch:48 | Iter:    0 | Time: 00:00:28 | Train Loss: 0.0921 | Average Loss: 0.7238
# Epoch:48 | Iter:   20 | Time: 00:00:28 | Train Loss: 0.1448 | Average Loss: 0.7203
# Epoch:48 | Iter:   40 | Time: 00:00:29 | Train Loss: 0.1034 | Average Loss: 0.7170
# Epoch:48 | Iter:   60 | Time: 00:00:29 | Train Loss: 0.0682 | Average Loss: 0.7136
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:49 | Iter:    0 | Time: 00:00:29 | Train Loss: 0.0630 | Average Loss: 0.7111
# Epoch:49 | Iter:   20 | Time: 00:00:29 | Train Loss: 0.1357 | Average Loss: 0.7077
# Epoch:49 | Iter:   40 | Time: 00:00:29 | Train Loss: 0.0927 | Average Loss: 0.7045
# Epoch:49 | Iter:   60 | Time: 00:00:29 | Train Loss: 0.0660 | Average Loss: 0.7011
# Accuracy: 0.570312 | Time: 00:00:00
# Epoch:50 | Iter:    0 | Time: 00:00:29 | Train Loss: 0.0652 | Average Loss: 0.6987
# Epoch:50 | Iter:   20 | Time: 00:00:30 | Train Loss: 0.1344 | Average Loss: 0.6954
# Epoch:50 | Iter:   40 | Time: 00:00:30 | Train Loss: 0.0896 | Average Loss: 0.6922
# Epoch:50 | Iter:   60 | Time: 00:00:30 | Train Loss: 0.0546 | Average Loss: 0.6890
# Accuracy: 0.578125 | Time: 00:00:00
# max accuracy tensor(0.5833, device='cuda:0')

# %% [markdown]
# **Answer**:
#
# Accuracy: 0.5833
#
# Data augmentation: Mirror the images
#
# Data normalization: Nomalize to get zero mean
#
# Layer 1:  nn.Conv2d(1, 16, 3),
#
# Layer 2: nn.ReLU()
#
# Layer 3: nn.MaxPool2d(2)
#
# Layer 4: nn.Conv2d(16, 32, 3)
#
# Layer 5: nn.ReLU()
#
# Layer 6: nn.MaxPool2d(2)
#
# Layer 7: nn.BatchNorm2d(32)
#
# Layer 8: nn.Linear(32* 14* 14, 1024)
#
# Layer 9: nn.BatchNorm1d(1024)
#
# Layer 10: nn.Linear(1024, 16)
#
# Accuray on test set:  0.5885

# %% [markdown]
# ## Problem 1.2
#
# (15 points) Try **three different techniques** taught in the class to increase the accuracy of your model. Such as increasing training data by randomly rotating training images, adding batch normalization, different activation functions (e.g., sigmoid) and model architecture modification. Note that too many layers can do you no good due to insufficient training data. Clearly describe your method and accuracy increase/decrease for each of the three techniques.
#
# The minimum accuracy required for this section is **0.60**. (At least one Technique should achieve this)
#
# ### Technique 1

# %%
#--------------------------------------------------
#    Load Training Data and Testing Data
#--------------------------------------------------
# load data into size (64, 64)
img_size = (64, 64)
batch_size = 64 # training sample number per batch

# load training dataset
trainloader_small = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True, augment=True, zero_centered=True))
train_num = len(trainloader_small)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_small = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size, zero_centered=True))
test_num = len(testloader_small)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# 4800
# 4800
# Finish loading 75 minibatches (batch_size=64) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# 400
# 400
# Finish loading 6 minibatches (batch_size=64) of testing samples.

# %%
#--------------------------------------------------
#       Define Network Architecture
#--------------------------------------------------
class Adi_Net(nn.Module):
  def __init__(self):
    super(Adi_Net,self).__init__()  
          
    self.features = torch.nn.Sequential(
      nn.Conv2d(1, 16, 3),
      nn.ReLU(),
      nn.MaxPool2d(2), 
      nn.Conv2d(16, 64, 3),
      nn.ReLU(),
      nn.MaxPool2d(2),
      nn.BatchNorm2d(64)
    )
    
    self.classifier = nn.Sequential(
        nn.Linear(64* 14* 14, 1024),
        nn.BatchNorm1d(1024),
        nn.Linear(1024, 16),
    )
    
  def forward(self, x):
    x = self.features(x) 
    # print(x.size())
    x = torch.flatten(x, 1)
    x = self.classifier(x)
    return x

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
net = Adi_Net()
train_option = {}
train_option['lr'] = 0.0005
train_option['epoch'] = 50
train_option['device'] = 'gpu'
max_accuracy = trainModel(net, trainloader_small, train_option, testloader_small)
print("max accuracy", max_accuracy)
# Out:
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.7770 | Average Loss: 2.7770
# Epoch: 1 | Iter:   20 | Time: 00:00:00 | Train Loss: 2.3610 | Average Loss: 2.6518
# Epoch: 1 | Iter:   40 | Time: 00:00:00 | Train Loss: 2.1895 | Average Loss: 2.4840
# Epoch: 1 | Iter:   60 | Time: 00:00:00 | Train Loss: 1.9515 | Average Loss: 2.3487
# Accuracy: 0.406250 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.4162 | Average Loss: 2.2537
# Epoch: 2 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.5033 | Average Loss: 2.1262
# Epoch: 2 | Iter:   40 | Time: 00:00:01 | Train Loss: 1.4207 | Average Loss: 2.0265
# Epoch: 2 | Iter:   60 | Time: 00:00:01 | Train Loss: 1.2439 | Average Loss: 1.9348
# Accuracy: 0.515625 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.9221 | Average Loss: 1.8733
# Epoch: 3 | Iter:   20 | Time: 00:00:02 | Train Loss: 0.8643 | Average Loss: 1.7914
# Epoch: 3 | Iter:   40 | Time: 00:00:02 | Train Loss: 1.0269 | Average Loss: 1.7224
# Epoch: 3 | Iter:   60 | Time: 00:00:02 | Train Loss: 0.9588 | Average Loss: 1.6577
# Accuracy: 0.549479 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.6390 | Average Loss: 1.6106
# Epoch: 4 | Iter:   20 | Time: 00:00:03 | Train Loss: 0.6408 | Average Loss: 1.5499
# Epoch: 4 | Iter:   40 | Time: 00:00:03 | Train Loss: 0.7958 | Average Loss: 1.4977
# Epoch: 4 | Iter:   60 | Time: 00:00:03 | Train Loss: 0.6757 | Average Loss: 1.4491
# Accuracy: 0.580729 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.4207 | Average Loss: 1.4126
# Epoch: 5 | Iter:   20 | Time: 00:00:04 | Train Loss: 0.5327 | Average Loss: 1.3640
# Epoch: 5 | Iter:   40 | Time: 00:00:04 | Train Loss: 0.5934 | Average Loss: 1.3203
# Epoch: 5 | Iter:   60 | Time: 00:00:04 | Train Loss: 0.5090 | Average Loss: 1.2784
# Accuracy: 0.596354 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.3494 | Average Loss: 1.2492
# Epoch: 6 | Iter:   20 | Time: 00:00:05 | Train Loss: 0.4061 | Average Loss: 1.2107
# Epoch: 6 | Iter:   40 | Time: 00:00:05 | Train Loss: 0.6469 | Average Loss: 1.1745
# Epoch: 6 | Iter:   60 | Time: 00:00:05 | Train Loss: 0.4321 | Average Loss: 1.1431
# Accuracy: 0.572917 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.2661 | Average Loss: 1.1192
# Epoch: 7 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.4007 | Average Loss: 1.0876
# Epoch: 7 | Iter:   40 | Time: 00:00:06 | Train Loss: 0.3628 | Average Loss: 1.0577
# Epoch: 7 | Iter:   60 | Time: 00:00:06 | Train Loss: 0.2851 | Average Loss: 1.0311
# Accuracy: 0.601562 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.2686 | Average Loss: 1.0117
# Epoch: 8 | Iter:   20 | Time: 00:00:07 | Train Loss: 0.2715 | Average Loss: 0.9848
# Epoch: 8 | Iter:   40 | Time: 00:00:07 | Train Loss: 0.3594 | Average Loss: 0.9597
# Epoch: 8 | Iter:   60 | Time: 00:00:07 | Train Loss: 0.3018 | Average Loss: 0.9386
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.1947 | Average Loss: 0.9230
# Epoch: 9 | Iter:   20 | Time: 00:00:07 | Train Loss: 0.2546 | Average Loss: 0.9008
# Epoch: 9 | Iter:   40 | Time: 00:00:08 | Train Loss: 0.1790 | Average Loss: 0.8785
# Epoch: 9 | Iter:   60 | Time: 00:00:08 | Train Loss: 0.2303 | Average Loss: 0.8587
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.1130 | Average Loss: 0.8442
# Epoch:10 | Iter:   20 | Time: 00:00:08 | Train Loss: 0.1511 | Average Loss: 0.8253
# Epoch:10 | Iter:   40 | Time: 00:00:09 | Train Loss: 0.1641 | Average Loss: 0.8071
# Epoch:10 | Iter:   60 | Time: 00:00:09 | Train Loss: 0.1037 | Average Loss: 0.7901
# Accuracy: 0.559896 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.1320 | Average Loss: 0.7782
# Epoch:11 | Iter:   20 | Time: 00:00:09 | Train Loss: 0.1331 | Average Loss: 0.7620
# Epoch:11 | Iter:   40 | Time: 00:00:10 | Train Loss: 0.1667 | Average Loss: 0.7465
# Epoch:11 | Iter:   60 | Time: 00:00:10 | Train Loss: 0.1448 | Average Loss: 0.7315
# Accuracy: 0.507812 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.2928 | Average Loss: 0.7212
# Epoch:12 | Iter:   20 | Time: 00:00:10 | Train Loss: 0.1253 | Average Loss: 0.7079
# Epoch:12 | Iter:   40 | Time: 00:00:11 | Train Loss: 0.1430 | Average Loss: 0.6940
# Epoch:12 | Iter:   60 | Time: 00:00:11 | Train Loss: 0.0757 | Average Loss: 0.6807
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.0299 | Average Loss: 0.6712
# Epoch:13 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.1190 | Average Loss: 0.6593
# Epoch:13 | Iter:   40 | Time: 00:00:12 | Train Loss: 0.1464 | Average Loss: 0.6474
# Epoch:13 | Iter:   60 | Time: 00:00:12 | Train Loss: 0.0844 | Average Loss: 0.6357
# Accuracy: 0.591146 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.0294 | Average Loss: 0.6271
# Epoch:14 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.0676 | Average Loss: 0.6162
# Epoch:14 | Iter:   40 | Time: 00:00:13 | Train Loss: 0.0687 | Average Loss: 0.6056
# Epoch:14 | Iter:   60 | Time: 00:00:13 | Train Loss: 0.0441 | Average Loss: 0.5948
# Accuracy: 0.570312 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.0258 | Average Loss: 0.5869
# Epoch:15 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.0357 | Average Loss: 0.5768
# Epoch:15 | Iter:   40 | Time: 00:00:13 | Train Loss: 0.0533 | Average Loss: 0.5673
# Epoch:15 | Iter:   60 | Time: 00:00:14 | Train Loss: 0.0229 | Average Loss: 0.5579
# Accuracy: 0.588542 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.0175 | Average Loss: 0.5511
# Epoch:16 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.0451 | Average Loss: 0.5421
# Epoch:16 | Iter:   40 | Time: 00:00:14 | Train Loss: 0.0340 | Average Loss: 0.5334
# Epoch:16 | Iter:   60 | Time: 00:00:15 | Train Loss: 0.0343 | Average Loss: 0.5249
# Accuracy: 0.565104 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.0285 | Average Loss: 0.5188
# Epoch:17 | Iter:   20 | Time: 00:00:15 | Train Loss: 0.0260 | Average Loss: 0.5108
# Epoch:17 | Iter:   40 | Time: 00:00:15 | Train Loss: 0.0380 | Average Loss: 0.5029
# Epoch:17 | Iter:   60 | Time: 00:00:16 | Train Loss: 0.0194 | Average Loss: 0.4953
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.0246 | Average Loss: 0.4898
# Epoch:18 | Iter:   20 | Time: 00:00:16 | Train Loss: 0.0222 | Average Loss: 0.4826
# Epoch:18 | Iter:   40 | Time: 00:00:16 | Train Loss: 0.0330 | Average Loss: 0.4755
# Epoch:18 | Iter:   60 | Time: 00:00:17 | Train Loss: 0.0145 | Average Loss: 0.4687
# Accuracy: 0.572917 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:00:17 | Train Loss: 0.0266 | Average Loss: 0.4638
# Epoch:19 | Iter:   20 | Time: 00:00:17 | Train Loss: 0.0127 | Average Loss: 0.4573
# Epoch:19 | Iter:   40 | Time: 00:00:17 | Train Loss: 0.0192 | Average Loss: 0.4509
# Epoch:19 | Iter:   60 | Time: 00:00:18 | Train Loss: 0.0085 | Average Loss: 0.4447
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:00:18 | Train Loss: 0.0117 | Average Loss: 0.4402
# Epoch:20 | Iter:   20 | Time: 00:00:18 | Train Loss: 0.0181 | Average Loss: 0.4343
# Epoch:20 | Iter:   40 | Time: 00:00:18 | Train Loss: 0.0246 | Average Loss: 0.4286
# Epoch:20 | Iter:   60 | Time: 00:00:19 | Train Loss: 0.0190 | Average Loss: 0.4230
# Accuracy: 0.588542 | Time: 00:00:00
# Epoch:21 | Iter:    0 | Time: 00:00:19 | Train Loss: 0.0086 | Average Loss: 0.4188
# Epoch:21 | Iter:   20 | Time: 00:00:19 | Train Loss: 0.0099 | Average Loss: 0.4135
# Epoch:21 | Iter:   40 | Time: 00:00:19 | Train Loss: 0.0179 | Average Loss: 0.4082
# Epoch:21 | Iter:   60 | Time: 00:00:20 | Train Loss: 0.0099 | Average Loss: 0.4031
# Accuracy: 0.596354 | Time: 00:00:00
# Epoch:22 | Iter:    0 | Time: 00:00:20 | Train Loss: 0.0153 | Average Loss: 0.3994
# Epoch:22 | Iter:   20 | Time: 00:00:20 | Train Loss: 0.0180 | Average Loss: 0.3945
# Epoch:22 | Iter:   40 | Time: 00:00:20 | Train Loss: 0.0101 | Average Loss: 0.3898
# Epoch:22 | Iter:   60 | Time: 00:00:20 | Train Loss: 0.0048 | Average Loss: 0.3851
# Accuracy: 0.591146 | Time: 00:00:00
# Epoch:23 | Iter:    0 | Time: 00:00:21 | Train Loss: 0.0049 | Average Loss: 0.3817
# Epoch:23 | Iter:   20 | Time: 00:00:21 | Train Loss: 0.0027 | Average Loss: 0.3772
# Epoch:23 | Iter:   40 | Time: 00:00:21 | Train Loss: 0.0062 | Average Loss: 0.3728
# Epoch:23 | Iter:   60 | Time: 00:00:21 | Train Loss: 0.0055 | Average Loss: 0.3685
# Accuracy: 0.583333 | Time: 00:00:00
# Epoch:24 | Iter:    0 | Time: 00:00:22 | Train Loss: 0.0040 | Average Loss: 0.3654
# Epoch:24 | Iter:   20 | Time: 00:00:22 | Train Loss: 0.0115 | Average Loss: 0.3612
# Epoch:24 | Iter:   40 | Time: 00:00:22 | Train Loss: 0.0085 | Average Loss: 0.3572
# Epoch:24 | Iter:   60 | Time: 00:00:22 | Train Loss: 0.0047 | Average Loss: 0.3533
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:25 | Iter:    0 | Time: 00:00:23 | Train Loss: 0.0030 | Average Loss: 0.3504
# Epoch:25 | Iter:   20 | Time: 00:00:23 | Train Loss: 0.0051 | Average Loss: 0.3466
# Epoch:25 | Iter:   40 | Time: 00:00:23 | Train Loss: 0.0059 | Average Loss: 0.3429
# Epoch:25 | Iter:   60 | Time: 00:00:23 | Train Loss: 0.0045 | Average Loss: 0.3393
# Accuracy: 0.580729 | Time: 00:00:00
# Epoch:26 | Iter:    0 | Time: 00:00:24 | Train Loss: 0.0046 | Average Loss: 0.3366
# Epoch:26 | Iter:   20 | Time: 00:00:24 | Train Loss: 0.0038 | Average Loss: 0.3331
# Epoch:26 | Iter:   40 | Time: 00:00:24 | Train Loss: 0.0068 | Average Loss: 0.3296
# Epoch:26 | Iter:   60 | Time: 00:00:24 | Train Loss: 0.0044 | Average Loss: 0.3263
# Accuracy: 0.591146 | Time: 00:00:00
# Epoch:27 | Iter:    0 | Time: 00:00:25 | Train Loss: 0.0041 | Average Loss: 0.3238
# Epoch:27 | Iter:   20 | Time: 00:00:25 | Train Loss: 0.0020 | Average Loss: 0.3205
# Epoch:27 | Iter:   40 | Time: 00:00:25 | Train Loss: 0.0062 | Average Loss: 0.3174
# Epoch:27 | Iter:   60 | Time: 00:00:25 | Train Loss: 0.0031 | Average Loss: 0.3142
# Accuracy: 0.570312 | Time: 00:00:00
# Epoch:28 | Iter:    0 | Time: 00:00:26 | Train Loss: 0.0039 | Average Loss: 0.3119
# Epoch:28 | Iter:   20 | Time: 00:00:26 | Train Loss: 0.0116 | Average Loss: 0.3089
# Epoch:28 | Iter:   40 | Time: 00:00:26 | Train Loss: 0.0017 | Average Loss: 0.3060
# Epoch:28 | Iter:   60 | Time: 00:00:26 | Train Loss: 0.0058 | Average Loss: 0.3031
# Accuracy: 0.601562 | Time: 00:00:00
# Epoch:29 | Iter:    0 | Time: 00:00:27 | Train Loss: 0.0064 | Average Loss: 0.3009
# Epoch:29 | Iter:   20 | Time: 00:00:27 | Train Loss: 0.0013 | Average Loss: 0.2981
# Epoch:29 | Iter:   40 | Time: 00:00:27 | Train Loss: 0.0043 | Average Loss: 0.2954
# Epoch:29 | Iter:   60 | Time: 00:00:27 | Train Loss: 0.0043 | Average Loss: 0.2927
# Accuracy: 0.585938 | Time: 00:00:00
# Epoch:30 | Iter:    0 | Time: 00:00:27 | Train Loss: 0.0013 | Average Loss: 0.2907
# Epoch:30 | Iter:   20 | Time: 00:00:28 | Train Loss: 0.0033 | Average Loss: 0.2881
# Epoch:30 | Iter:   40 | Time: 00:00:28 | Train Loss: 0.0022 | Average Loss: 0.2855
# Epoch:30 | Iter:   60 | Time: 00:00:28 | Train Loss: 0.0012 | Average Loss: 0.2830
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:31 | Iter:    0 | Time: 00:00:28 | Train Loss: 0.0011 | Average Loss: 0.2811
# Epoch:31 | Iter:   20 | Time: 00:00:29 | Train Loss: 0.0016 | Average Loss: 0.2786
# Epoch:31 | Iter:   40 | Time: 00:00:29 | Train Loss: 0.0100 | Average Loss: 0.2763
# Epoch:31 | Iter:   60 | Time: 00:00:29 | Train Loss: 0.0032 | Average Loss: 0.2740
# Accuracy: 0.559896 | Time: 00:00:00
# Epoch:32 | Iter:    0 | Time: 00:00:29 | Train Loss: 0.0157 | Average Loss: 0.2723
# Epoch:32 | Iter:   20 | Time: 00:00:30 | Train Loss: 0.0081 | Average Loss: 0.2701
# Epoch:32 | Iter:   40 | Time: 00:00:30 | Train Loss: 0.0492 | Average Loss: 0.2679
# Epoch:32 | Iter:   60 | Time: 00:00:30 | Train Loss: 0.0069 | Average Loss: 0.2657
# Accuracy: 0.598958 | Time: 00:00:00
# Epoch:33 | Iter:    0 | Time: 00:00:30 | Train Loss: 0.0071 | Average Loss: 0.2642
# Epoch:33 | Iter:   20 | Time: 00:00:31 | Train Loss: 0.0038 | Average Loss: 0.2621
# Epoch:33 | Iter:   40 | Time: 00:00:31 | Train Loss: 0.0139 | Average Loss: 0.2601
# Epoch:33 | Iter:   60 | Time: 00:00:31 | Train Loss: 0.0327 | Average Loss: 0.2582
# Accuracy: 0.588542 | Time: 00:00:00
# Epoch:34 | Iter:    0 | Time: 00:00:31 | Train Loss: 0.0128 | Average Loss: 0.2568
# Epoch:34 | Iter:   20 | Time: 00:00:32 | Train Loss: 0.0257 | Average Loss: 0.2549
# Epoch:34 | Iter:   40 | Time: 00:00:32 | Train Loss: 0.0437 | Average Loss: 0.2531
# Epoch:34 | Iter:   60 | Time: 00:00:32 | Train Loss: 0.1001 | Average Loss: 0.2515
# Accuracy: 0.572917 | Time: 00:00:00
# Epoch:35 | Iter:    0 | Time: 00:00:32 | Train Loss: 0.0121 | Average Loss: 0.2503
# Epoch:35 | Iter:   20 | Time: 00:00:33 | Train Loss: 0.0597 | Average Loss: 0.2487
# Epoch:35 | Iter:   40 | Time: 00:00:33 | Train Loss: 0.0552 | Average Loss: 0.2471
# Epoch:35 | Iter:   60 | Time: 00:00:33 | Train Loss: 0.0171 | Average Loss: 0.2457
# Accuracy: 0.575521 | Time: 00:00:00
# Epoch:36 | Iter:    0 | Time: 00:00:33 | Train Loss: 0.0434 | Average Loss: 0.2447
# Epoch:36 | Iter:   20 | Time: 00:00:34 | Train Loss: 0.0608 | Average Loss: 0.2434
# Epoch:36 | Iter:   40 | Time: 00:00:34 | Train Loss: 0.0757 | Average Loss: 0.2422
# Epoch:36 | Iter:   60 | Time: 00:00:34 | Train Loss: 0.0882 | Average Loss: 0.2411
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch:37 | Iter:    0 | Time: 00:00:34 | Train Loss: 0.0414 | Average Loss: 0.2402
# Epoch:37 | Iter:   20 | Time: 00:00:35 | Train Loss: 0.0658 | Average Loss: 0.2389
# Epoch:37 | Iter:   40 | Time: 00:00:35 | Train Loss: 0.0184 | Average Loss: 0.2375
# Epoch:37 | Iter:   60 | Time: 00:00:35 | Train Loss: 0.0292 | Average Loss: 0.2360
# Accuracy: 0.575521 | Time: 00:00:00
# Epoch:38 | Iter:    0 | Time: 00:00:35 | Train Loss: 0.0669 | Average Loss: 0.2349
# Epoch:38 | Iter:   20 | Time: 00:00:36 | Train Loss: 0.0185 | Average Loss: 0.2335
# Epoch:38 | Iter:   40 | Time: 00:00:36 | Train Loss: 0.0156 | Average Loss: 0.2321
# Epoch:38 | Iter:   60 | Time: 00:00:36 | Train Loss: 0.0216 | Average Loss: 0.2307
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:39 | Iter:    0 | Time: 00:00:36 | Train Loss: 0.0143 | Average Loss: 0.2297
# Epoch:39 | Iter:   20 | Time: 00:00:37 | Train Loss: 0.0909 | Average Loss: 0.2284
# Epoch:39 | Iter:   40 | Time: 00:00:37 | Train Loss: 0.0273 | Average Loss: 0.2271
# Epoch:39 | Iter:   60 | Time: 00:00:37 | Train Loss: 0.0140 | Average Loss: 0.2257
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:40 | Iter:    0 | Time: 00:00:37 | Train Loss: 0.0197 | Average Loss: 0.2247
# Epoch:40 | Iter:   20 | Time: 00:00:37 | Train Loss: 0.0101 | Average Loss: 0.2233
# Epoch:40 | Iter:   40 | Time: 00:00:38 | Train Loss: 0.0139 | Average Loss: 0.2221
# Epoch:40 | Iter:   60 | Time: 00:00:38 | Train Loss: 0.0106 | Average Loss: 0.2208
# Accuracy: 0.552083 | Time: 00:00:00
# Epoch:41 | Iter:    0 | Time: 00:00:38 | Train Loss: 0.0500 | Average Loss: 0.2199
# Epoch:41 | Iter:   20 | Time: 00:00:38 | Train Loss: 0.0137 | Average Loss: 0.2187
# Epoch:41 | Iter:   40 | Time: 00:00:39 | Train Loss: 0.0331 | Average Loss: 0.2175
# Epoch:41 | Iter:   60 | Time: 00:00:39 | Train Loss: 0.0043 | Average Loss: 0.2161
# Accuracy: 0.583333 | Time: 00:00:00
# Epoch:42 | Iter:    0 | Time: 00:00:39 | Train Loss: 0.0054 | Average Loss: 0.2152
# Epoch:42 | Iter:   20 | Time: 00:00:39 | Train Loss: 0.0447 | Average Loss: 0.2140
# Epoch:42 | Iter:   40 | Time: 00:00:40 | Train Loss: 0.0513 | Average Loss: 0.2128
# Epoch:42 | Iter:   60 | Time: 00:00:40 | Train Loss: 0.0027 | Average Loss: 0.2116
# Accuracy: 0.565104 | Time: 00:00:00
# Epoch:43 | Iter:    0 | Time: 00:00:40 | Train Loss: 0.0060 | Average Loss: 0.2106
# Epoch:43 | Iter:   20 | Time: 00:00:40 | Train Loss: 0.0103 | Average Loss: 0.2093
# Epoch:43 | Iter:   40 | Time: 00:00:41 | Train Loss: 0.0360 | Average Loss: 0.2081
# Epoch:43 | Iter:   60 | Time: 00:00:41 | Train Loss: 0.0021 | Average Loss: 0.2068
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:44 | Iter:    0 | Time: 00:00:41 | Train Loss: 0.0474 | Average Loss: 0.2059
# Epoch:44 | Iter:   20 | Time: 00:00:41 | Train Loss: 0.0036 | Average Loss: 0.2047
# Epoch:44 | Iter:   40 | Time: 00:00:42 | Train Loss: 0.0095 | Average Loss: 0.2034
# Epoch:44 | Iter:   60 | Time: 00:00:42 | Train Loss: 0.0016 | Average Loss: 0.2022
# Accuracy: 0.575521 | Time: 00:00:00
# Epoch:45 | Iter:    0 | Time: 00:00:42 | Train Loss: 0.0038 | Average Loss: 0.2013
# Epoch:45 | Iter:   20 | Time: 00:00:42 | Train Loss: 0.0041 | Average Loss: 0.2001
# Epoch:45 | Iter:   40 | Time: 00:00:43 | Train Loss: 0.0031 | Average Loss: 0.1990
# Epoch:45 | Iter:   60 | Time: 00:00:43 | Train Loss: 0.0027 | Average Loss: 0.1978
# Accuracy: 0.575521 | Time: 00:00:00
# Epoch:46 | Iter:    0 | Time: 00:00:43 | Train Loss: 0.0019 | Average Loss: 0.1969
# Epoch:46 | Iter:   20 | Time: 00:00:43 | Train Loss: 0.0006 | Average Loss: 0.1958
# Epoch:46 | Iter:   40 | Time: 00:00:44 | Train Loss: 0.0027 | Average Loss: 0.1947
# Epoch:46 | Iter:   60 | Time: 00:00:44 | Train Loss: 0.0010 | Average Loss: 0.1935
# Accuracy: 0.591146 | Time: 00:00:00
# Epoch:47 | Iter:    0 | Time: 00:00:44 | Train Loss: 0.0012 | Average Loss: 0.1927
# Epoch:47 | Iter:   20 | Time: 00:00:44 | Train Loss: 0.0005 | Average Loss: 0.1916
# Epoch:47 | Iter:   40 | Time: 00:00:45 | Train Loss: 0.0008 | Average Loss: 0.1905
# Epoch:47 | Iter:   60 | Time: 00:00:45 | Train Loss: 0.0025 | Average Loss: 0.1895
# Accuracy: 0.570312 | Time: 00:00:00
# Epoch:48 | Iter:    0 | Time: 00:00:45 | Train Loss: 0.0027 | Average Loss: 0.1887
# Epoch:48 | Iter:   20 | Time: 00:00:45 | Train Loss: 0.0019 | Average Loss: 0.1876
# Epoch:48 | Iter:   40 | Time: 00:00:45 | Train Loss: 0.0023 | Average Loss: 0.1866
# Epoch:48 | Iter:   60 | Time: 00:00:46 | Train Loss: 0.0043 | Average Loss: 0.1856
# Accuracy: 0.606771 | Time: 00:00:00
# Epoch:49 | Iter:    0 | Time: 00:00:46 | Train Loss: 0.0007 | Average Loss: 0.1848
# Epoch:49 | Iter:   20 | Time: 00:00:46 | Train Loss: 0.0005 | Average Loss: 0.1838
# Epoch:49 | Iter:   40 | Time: 00:00:46 | Train Loss: 0.0024 | Average Loss: 0.1828
# Epoch:49 | Iter:   60 | Time: 00:00:47 | Train Loss: 0.0041 | Average Loss: 0.1818
# Accuracy: 0.591146 | Time: 00:00:00
# Epoch:50 | Iter:    0 | Time: 00:00:47 | Train Loss: 0.0009 | Average Loss: 0.1811
# Epoch:50 | Iter:   20 | Time: 00:00:47 | Train Loss: 0.0011 | Average Loss: 0.1801
# Epoch:50 | Iter:   40 | Time: 00:00:47 | Train Loss: 0.0014 | Average Loss: 0.1791
# Epoch:50 | Iter:   60 | Time: 00:00:48 | Train Loss: 0.0011 | Average Loss: 0.1782
# Accuracy: 0.604167 | Time: 00:00:00
# max accuracy tensor(0.6068, device='cuda:0')

# %% [markdown]
# **Answer**:
#
# Technique 1: Batch Normalization
#
# Accuracy on test set: 0.6068
#
# Accuracy increases/decreases: Increases

# %% [markdown]
# ### Technique 2

# %%
#--------------------------------------------------
#    Load Training Data and Testing Data
#--------------------------------------------------
# load data into size (64, 64)
img_size = (64, 64)
batch_size = 64 # training sample number per batch

# load training dataset
trainloader_small = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True, zero_centered=True, augment=True, rotate=True))
train_num = len(trainloader_small)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_small = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size, zero_centered=True))
test_num = len(testloader_small)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# 12024
# 12024
# Finish loading 187 minibatches (batch_size=64) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# 400
# 400
# Finish loading 6 minibatches (batch_size=64) of testing samples.

# %%
#--------------------------------------------------
#       Define Network Architecture
#--------------------------------------------------
class Adi_Net(nn.Module):
  def __init__(self):
    super(Adi_Net,self).__init__()  
          
    self.features = torch.nn.Sequential(
      nn.Conv2d(1, 16, 3),
      nn.ReLU(),
      nn.MaxPool2d(2), 
      nn.Conv2d(16, 64, 3),
      nn.ReLU(),
      nn.MaxPool2d(2),
    )
    
    self.classifier = nn.Sequential(
        nn.Linear(64* 14* 14, 2048),
        nn.Linear(2048, 1024),
        nn.Linear(1024, 16),
    )
    
  def forward(self, x):
    x = self.features(x) 
    # print(x.size()) 
    x = torch.flatten(x, 1)
    x = self.classifier(x)
    return x

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
net = Adi_Net()
train_option = {}
train_option['lr'] = 0.0001
train_option['epoch'] = 50
train_option['device'] = 'gpu'
max_accuracy = trainModel(net, trainloader_small, train_option, testloader_small)
print("max accuracy", max_accuracy)
# Out:
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.7713 | Average Loss: 2.7713
# Epoch: 1 | Iter:   20 | Time: 00:00:00 | Train Loss: 2.5027 | Average Loss: 2.7170
# Epoch: 1 | Iter:   40 | Time: 00:00:00 | Train Loss: 2.4526 | Average Loss: 2.6039
# Epoch: 1 | Iter:   60 | Time: 00:00:01 | Train Loss: 2.1131 | Average Loss: 2.4865
# Epoch: 1 | Iter:   80 | Time: 00:00:01 | Train Loss: 2.1474 | Average Loss: 2.3937
# Epoch: 1 | Iter:  100 | Time: 00:00:02 | Train Loss: 1.8995 | Average Loss: 2.3279
# Epoch: 1 | Iter:  120 | Time: 00:00:02 | Train Loss: 2.0730 | Average Loss: 2.2591
# Epoch: 1 | Iter:  140 | Time: 00:00:02 | Train Loss: 1.9573 | Average Loss: 2.1978
# Epoch: 1 | Iter:  160 | Time: 00:00:03 | Train Loss: 2.0068 | Average Loss: 2.1447
# Epoch: 1 | Iter:  180 | Time: 00:00:03 | Train Loss: 1.6095 | Average Loss: 2.0963
# Accuracy: 0.453125 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.5764 | Average Loss: 2.0816
# Epoch: 2 | Iter:   20 | Time: 00:00:04 | Train Loss: 1.5058 | Average Loss: 2.0381
# Epoch: 2 | Iter:   40 | Time: 00:00:04 | Train Loss: 1.7351 | Average Loss: 2.0001
# Epoch: 2 | Iter:   60 | Time: 00:00:05 | Train Loss: 1.3721 | Average Loss: 1.9592
# Epoch: 2 | Iter:   80 | Time: 00:00:05 | Train Loss: 1.6996 | Average Loss: 1.9255
# Epoch: 2 | Iter:  100 | Time: 00:00:05 | Train Loss: 1.3292 | Average Loss: 1.8948
# Epoch: 2 | Iter:  120 | Time: 00:00:06 | Train Loss: 1.5239 | Average Loss: 1.8599
# Epoch: 2 | Iter:  140 | Time: 00:00:06 | Train Loss: 1.4315 | Average Loss: 1.8272
# Epoch: 2 | Iter:  160 | Time: 00:00:06 | Train Loss: 1.3941 | Average Loss: 1.7968
# Epoch: 2 | Iter:  180 | Time: 00:00:07 | Train Loss: 1.1705 | Average Loss: 1.7683
# Accuracy: 0.494792 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:07 | Train Loss: 1.2101 | Average Loss: 1.7586
# Epoch: 3 | Iter:   20 | Time: 00:00:07 | Train Loss: 1.0865 | Average Loss: 1.7310
# Epoch: 3 | Iter:   40 | Time: 00:00:08 | Train Loss: 1.3536 | Average Loss: 1.7053
# Epoch: 3 | Iter:   60 | Time: 00:00:08 | Train Loss: 0.9950 | Average Loss: 1.6806
# Epoch: 3 | Iter:   80 | Time: 00:00:09 | Train Loss: 1.3097 | Average Loss: 1.6576
# Epoch: 3 | Iter:  100 | Time: 00:00:09 | Train Loss: 0.9940 | Average Loss: 1.6347
# Epoch: 3 | Iter:  120 | Time: 00:00:09 | Train Loss: 1.2446 | Average Loss: 1.6106
# Epoch: 3 | Iter:  140 | Time: 00:00:10 | Train Loss: 1.0477 | Average Loss: 1.5884
# Epoch: 3 | Iter:  160 | Time: 00:00:10 | Train Loss: 1.0161 | Average Loss: 1.5664
# Epoch: 3 | Iter:  180 | Time: 00:00:11 | Train Loss: 0.9107 | Average Loss: 1.5450
# Accuracy: 0.541667 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.9552 | Average Loss: 1.5377
# Epoch: 4 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.8407 | Average Loss: 1.5168
# Epoch: 4 | Iter:   40 | Time: 00:00:12 | Train Loss: 1.0470 | Average Loss: 1.4960
# Epoch: 4 | Iter:   60 | Time: 00:00:12 | Train Loss: 0.8128 | Average Loss: 1.4774
# Epoch: 4 | Iter:   80 | Time: 00:00:12 | Train Loss: 0.9849 | Average Loss: 1.4588
# Epoch: 4 | Iter:  100 | Time: 00:00:13 | Train Loss: 0.7693 | Average Loss: 1.4402
# Epoch: 4 | Iter:  120 | Time: 00:00:13 | Train Loss: 0.9897 | Average Loss: 1.4215
# Epoch: 4 | Iter:  140 | Time: 00:00:14 | Train Loss: 0.7808 | Average Loss: 1.4040
# Epoch: 4 | Iter:  160 | Time: 00:00:14 | Train Loss: 0.7967 | Average Loss: 1.3864
# Epoch: 4 | Iter:  180 | Time: 00:00:14 | Train Loss: 0.7237 | Average Loss: 1.3691
# Accuracy: 0.583333 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.7071 | Average Loss: 1.3632
# Epoch: 5 | Iter:   20 | Time: 00:00:15 | Train Loss: 0.6763 | Average Loss: 1.3462
# Epoch: 5 | Iter:   40 | Time: 00:00:15 | Train Loss: 0.7798 | Average Loss: 1.3288
# Epoch: 5 | Iter:   60 | Time: 00:00:16 | Train Loss: 0.6686 | Average Loss: 1.3130
# Epoch: 5 | Iter:   80 | Time: 00:00:16 | Train Loss: 0.7729 | Average Loss: 1.2975
# Epoch: 5 | Iter:  100 | Time: 00:00:17 | Train Loss: 0.6033 | Average Loss: 1.2819
# Epoch: 5 | Iter:  120 | Time: 00:00:17 | Train Loss: 0.7389 | Average Loss: 1.2663
# Epoch: 5 | Iter:  140 | Time: 00:00:17 | Train Loss: 0.5551 | Average Loss: 1.2519
# Epoch: 5 | Iter:  160 | Time: 00:00:18 | Train Loss: 0.6444 | Average Loss: 1.2373
# Epoch: 5 | Iter:  180 | Time: 00:00:18 | Train Loss: 0.5732 | Average Loss: 1.2226
# Accuracy: 0.606771 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:18 | Train Loss: 0.4931 | Average Loss: 1.2176
# Epoch: 6 | Iter:   20 | Time: 00:00:19 | Train Loss: 0.5491 | Average Loss: 1.2035
# Epoch: 6 | Iter:   40 | Time: 00:00:19 | Train Loss: 0.5553 | Average Loss: 1.1887
# Epoch: 6 | Iter:   60 | Time: 00:00:20 | Train Loss: 0.5305 | Average Loss: 1.1752
# Epoch: 6 | Iter:   80 | Time: 00:00:20 | Train Loss: 0.5977 | Average Loss: 1.1619
# Epoch: 6 | Iter:  100 | Time: 00:00:20 | Train Loss: 0.4231 | Average Loss: 1.1488
# Epoch: 6 | Iter:  120 | Time: 00:00:21 | Train Loss: 0.5349 | Average Loss: 1.1356
# Epoch: 6 | Iter:  140 | Time: 00:00:21 | Train Loss: 0.3179 | Average Loss: 1.1240
# Epoch: 6 | Iter:  160 | Time: 00:00:22 | Train Loss: 0.5241 | Average Loss: 1.1128
# Epoch: 6 | Iter:  180 | Time: 00:00:22 | Train Loss: 0.4805 | Average Loss: 1.1004
# Accuracy: 0.604167 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:22 | Train Loss: 0.3505 | Average Loss: 1.0963
# Epoch: 7 | Iter:   20 | Time: 00:00:22 | Train Loss: 0.4719 | Average Loss: 1.0843
# Epoch: 7 | Iter:   40 | Time: 00:00:23 | Train Loss: 0.4330 | Average Loss: 1.0719
# Epoch: 7 | Iter:   60 | Time: 00:00:23 | Train Loss: 0.3958 | Average Loss: 1.0601
# Epoch: 7 | Iter:   80 | Time: 00:00:24 | Train Loss: 0.4509 | Average Loss: 1.0489
# Epoch: 7 | Iter:  100 | Time: 00:00:24 | Train Loss: 0.2986 | Average Loss: 1.0379
# Epoch: 7 | Iter:  120 | Time: 00:00:24 | Train Loss: 0.3904 | Average Loss: 1.0270
# Epoch: 7 | Iter:  140 | Time: 00:00:25 | Train Loss: 0.2349 | Average Loss: 1.0177
# Epoch: 7 | Iter:  160 | Time: 00:00:25 | Train Loss: 0.7042 | Average Loss: 1.0103
# Epoch: 7 | Iter:  180 | Time: 00:00:26 | Train Loss: 0.5040 | Average Loss: 1.0016
# Accuracy: 0.572917 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:26 | Train Loss: 0.3716 | Average Loss: 0.9985
# Epoch: 8 | Iter:   20 | Time: 00:00:26 | Train Loss: 0.3481 | Average Loss: 0.9887
# Epoch: 8 | Iter:   40 | Time: 00:00:27 | Train Loss: 0.4107 | Average Loss: 0.9786
# Epoch: 8 | Iter:   60 | Time: 00:00:27 | Train Loss: 0.3069 | Average Loss: 0.9690
# Epoch: 8 | Iter:   80 | Time: 00:00:27 | Train Loss: 0.3740 | Average Loss: 0.9595
# Epoch: 8 | Iter:  100 | Time: 00:00:28 | Train Loss: 0.3269 | Average Loss: 0.9505
# Epoch: 8 | Iter:  120 | Time: 00:00:28 | Train Loss: 0.3553 | Average Loss: 0.9414
# Epoch: 8 | Iter:  140 | Time: 00:00:29 | Train Loss: 0.4352 | Average Loss: 0.9329
# Epoch: 8 | Iter:  160 | Time: 00:00:29 | Train Loss: 0.3569 | Average Loss: 0.9258
# Epoch: 8 | Iter:  180 | Time: 00:00:29 | Train Loss: 0.2822 | Average Loss: 0.9175
# Accuracy: 0.606771 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:30 | Train Loss: 0.2543 | Average Loss: 0.9147
# Epoch: 9 | Iter:   20 | Time: 00:00:30 | Train Loss: 0.3007 | Average Loss: 0.9071
# Epoch: 9 | Iter:   40 | Time: 00:00:30 | Train Loss: 0.3061 | Average Loss: 0.8985
# Epoch: 9 | Iter:   60 | Time: 00:00:31 | Train Loss: 0.2625 | Average Loss: 0.8901
# Epoch: 9 | Iter:   80 | Time: 00:00:31 | Train Loss: 0.2742 | Average Loss: 0.8816
# Epoch: 9 | Iter:  100 | Time: 00:00:32 | Train Loss: 0.4078 | Average Loss: 0.8736
# Epoch: 9 | Iter:  120 | Time: 00:00:32 | Train Loss: 0.2543 | Average Loss: 0.8658
# Epoch: 9 | Iter:  140 | Time: 00:00:32 | Train Loss: 0.1309 | Average Loss: 0.8578
# Epoch: 9 | Iter:  160 | Time: 00:00:33 | Train Loss: 0.2144 | Average Loss: 0.8500
# Epoch: 9 | Iter:  180 | Time: 00:00:33 | Train Loss: 0.2159 | Average Loss: 0.8422
# Accuracy: 0.598958 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:33 | Train Loss: 0.1755 | Average Loss: 0.8396
# Epoch:10 | Iter:   20 | Time: 00:00:34 | Train Loss: 0.3692 | Average Loss: 0.8327
# Epoch:10 | Iter:   40 | Time: 00:00:34 | Train Loss: 0.2310 | Average Loss: 0.8259
# Epoch:10 | Iter:   60 | Time: 00:00:35 | Train Loss: 0.2669 | Average Loss: 0.8186
# Epoch:10 | Iter:   80 | Time: 00:00:35 | Train Loss: 0.2307 | Average Loss: 0.8112
# Epoch:10 | Iter:  100 | Time: 00:00:35 | Train Loss: 0.1606 | Average Loss: 0.8040
# Epoch:10 | Iter:  120 | Time: 00:00:36 | Train Loss: 0.1221 | Average Loss: 0.7966
# Epoch:10 | Iter:  140 | Time: 00:00:36 | Train Loss: 0.0667 | Average Loss: 0.7895
# Epoch:10 | Iter:  160 | Time: 00:00:37 | Train Loss: 0.1472 | Average Loss: 0.7825
# Epoch:10 | Iter:  180 | Time: 00:00:37 | Train Loss: 0.1483 | Average Loss: 0.7755
# Accuracy: 0.557292 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:00:37 | Train Loss: 0.2295 | Average Loss: 0.7731
# Epoch:11 | Iter:   20 | Time: 00:00:38 | Train Loss: 0.2891 | Average Loss: 0.7667
# Epoch:11 | Iter:   40 | Time: 00:00:38 | Train Loss: 0.1463 | Average Loss: 0.7602
# Epoch:11 | Iter:   60 | Time: 00:00:38 | Train Loss: 0.1438 | Average Loss: 0.7537
# Epoch:11 | Iter:   80 | Time: 00:00:39 | Train Loss: 0.1498 | Average Loss: 0.7472
# Epoch:11 | Iter:  100 | Time: 00:00:39 | Train Loss: 0.0948 | Average Loss: 0.7409
# Epoch:11 | Iter:  120 | Time: 00:00:40 | Train Loss: 0.1020 | Average Loss: 0.7345
# Epoch:11 | Iter:  140 | Time: 00:00:40 | Train Loss: 0.0979 | Average Loss: 0.7283
# Epoch:11 | Iter:  160 | Time: 00:00:40 | Train Loss: 0.0895 | Average Loss: 0.7222
# Epoch:11 | Iter:  180 | Time: 00:00:41 | Train Loss: 0.1148 | Average Loss: 0.7161
# Accuracy: 0.575521 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:00:41 | Train Loss: 0.1081 | Average Loss: 0.7140
# Epoch:12 | Iter:   20 | Time: 00:00:41 | Train Loss: 0.1486 | Average Loss: 0.7082
# Epoch:12 | Iter:   40 | Time: 00:00:42 | Train Loss: 0.1239 | Average Loss: 0.7027
# Epoch:12 | Iter:   60 | Time: 00:00:42 | Train Loss: 0.0755 | Average Loss: 0.6971
# Epoch:12 | Iter:   80 | Time: 00:00:43 | Train Loss: 0.1430 | Average Loss: 0.6913
# Epoch:12 | Iter:  100 | Time: 00:00:43 | Train Loss: 0.0881 | Average Loss: 0.6859
# Epoch:12 | Iter:  120 | Time: 00:00:43 | Train Loss: 0.0583 | Average Loss: 0.6804
# Epoch:12 | Iter:  140 | Time: 00:00:44 | Train Loss: 0.0798 | Average Loss: 0.6750
# Epoch:12 | Iter:  160 | Time: 00:00:44 | Train Loss: 0.0843 | Average Loss: 0.6699
# Epoch:12 | Iter:  180 | Time: 00:00:45 | Train Loss: 0.1378 | Average Loss: 0.6648
# Accuracy: 0.552083 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:00:45 | Train Loss: 0.1021 | Average Loss: 0.6630
# Epoch:13 | Iter:   20 | Time: 00:00:45 | Train Loss: 0.0990 | Average Loss: 0.6579
# Epoch:13 | Iter:   40 | Time: 00:00:46 | Train Loss: 0.0958 | Average Loss: 0.6528
# Epoch:13 | Iter:   60 | Time: 00:00:46 | Train Loss: 0.0745 | Average Loss: 0.6478
# Epoch:13 | Iter:   80 | Time: 00:00:46 | Train Loss: 0.1376 | Average Loss: 0.6428
# Epoch:13 | Iter:  100 | Time: 00:00:47 | Train Loss: 0.1479 | Average Loss: 0.6380
# Epoch:13 | Iter:  120 | Time: 00:00:47 | Train Loss: 0.0495 | Average Loss: 0.6331
# Epoch:13 | Iter:  140 | Time: 00:00:48 | Train Loss: 0.0742 | Average Loss: 0.6283
# Epoch:13 | Iter:  160 | Time: 00:00:48 | Train Loss: 0.1353 | Average Loss: 0.6238
# Epoch:13 | Iter:  180 | Time: 00:00:48 | Train Loss: 0.1092 | Average Loss: 0.6196
# Accuracy: 0.572917 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:00:49 | Train Loss: 0.0967 | Average Loss: 0.6180
# Epoch:14 | Iter:   20 | Time: 00:00:49 | Train Loss: 0.0623 | Average Loss: 0.6135
# Epoch:14 | Iter:   40 | Time: 00:00:49 | Train Loss: 0.0551 | Average Loss: 0.6090
# Epoch:14 | Iter:   60 | Time: 00:00:50 | Train Loss: 0.0680 | Average Loss: 0.6047
# Epoch:14 | Iter:   80 | Time: 00:00:50 | Train Loss: 0.0723 | Average Loss: 0.6002
# Epoch:14 | Iter:  100 | Time: 00:00:51 | Train Loss: 0.0832 | Average Loss: 0.5959
# Epoch:14 | Iter:  120 | Time: 00:00:51 | Train Loss: 0.0694 | Average Loss: 0.5918
# Epoch:14 | Iter:  140 | Time: 00:00:51 | Train Loss: 0.0672 | Average Loss: 0.5875
# Epoch:14 | Iter:  160 | Time: 00:00:52 | Train Loss: 0.0550 | Average Loss: 0.5833
# Epoch:14 | Iter:  180 | Time: 00:00:52 | Train Loss: 0.0701 | Average Loss: 0.5794
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:00:52 | Train Loss: 0.0789 | Average Loss: 0.5780
# Epoch:15 | Iter:   20 | Time: 00:00:53 | Train Loss: 0.0593 | Average Loss: 0.5741
# Epoch:15 | Iter:   40 | Time: 00:00:53 | Train Loss: 0.0721 | Average Loss: 0.5701
# Epoch:15 | Iter:   60 | Time: 00:00:54 | Train Loss: 0.0498 | Average Loss: 0.5662
# Epoch:15 | Iter:   80 | Time: 00:00:54 | Train Loss: 0.0449 | Average Loss: 0.5623
# Epoch:15 | Iter:  100 | Time: 00:00:54 | Train Loss: 0.0370 | Average Loss: 0.5584
# Epoch:15 | Iter:  120 | Time: 00:00:55 | Train Loss: 0.0297 | Average Loss: 0.5545
# Epoch:15 | Iter:  140 | Time: 00:00:55 | Train Loss: 0.0081 | Average Loss: 0.5507
# Epoch:15 | Iter:  160 | Time: 00:00:56 | Train Loss: 0.0190 | Average Loss: 0.5470
# Epoch:15 | Iter:  180 | Time: 00:00:56 | Train Loss: 0.0719 | Average Loss: 0.5433
# Accuracy: 0.588542 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:00:56 | Train Loss: 0.0447 | Average Loss: 0.5421
# Epoch:16 | Iter:   20 | Time: 00:00:57 | Train Loss: 0.0436 | Average Loss: 0.5388
# Epoch:16 | Iter:   40 | Time: 00:00:57 | Train Loss: 0.0259 | Average Loss: 0.5353
# Epoch:16 | Iter:   60 | Time: 00:00:57 | Train Loss: 0.0411 | Average Loss: 0.5318
# Epoch:16 | Iter:   80 | Time: 00:00:58 | Train Loss: 0.0336 | Average Loss: 0.5283
# Epoch:16 | Iter:  100 | Time: 00:00:58 | Train Loss: 0.0299 | Average Loss: 0.5248
# Epoch:16 | Iter:  120 | Time: 00:00:59 | Train Loss: 0.0131 | Average Loss: 0.5214
# Epoch:16 | Iter:  140 | Time: 00:00:59 | Train Loss: 0.0132 | Average Loss: 0.5180
# Epoch:16 | Iter:  160 | Time: 00:00:59 | Train Loss: 0.0153 | Average Loss: 0.5146
# Epoch:16 | Iter:  180 | Time: 00:01:00 | Train Loss: 0.0154 | Average Loss: 0.5113
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:01:00 | Train Loss: 0.0206 | Average Loss: 0.5102
# Epoch:17 | Iter:   20 | Time: 00:01:00 | Train Loss: 0.0357 | Average Loss: 0.5069
# Epoch:17 | Iter:   40 | Time: 00:01:01 | Train Loss: 0.0151 | Average Loss: 0.5038
# Epoch:17 | Iter:   60 | Time: 00:01:01 | Train Loss: 0.0153 | Average Loss: 0.5006
# Epoch:17 | Iter:   80 | Time: 00:01:02 | Train Loss: 0.0162 | Average Loss: 0.4975
# Epoch:17 | Iter:  100 | Time: 00:01:02 | Train Loss: 0.0197 | Average Loss: 0.4944
# Epoch:17 | Iter:  120 | Time: 00:01:02 | Train Loss: 0.0074 | Average Loss: 0.4913
# Epoch:17 | Iter:  140 | Time: 00:01:03 | Train Loss: 0.0047 | Average Loss: 0.4882
# Epoch:17 | Iter:  160 | Time: 00:01:03 | Train Loss: 0.0105 | Average Loss: 0.4852
# Epoch:17 | Iter:  180 | Time: 00:01:04 | Train Loss: 0.0088 | Average Loss: 0.4822
# Accuracy: 0.606771 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:01:04 | Train Loss: 0.0095 | Average Loss: 0.4812
# Epoch:18 | Iter:   20 | Time: 00:01:04 | Train Loss: 0.0192 | Average Loss: 0.4782
# Epoch:18 | Iter:   40 | Time: 00:01:05 | Train Loss: 0.0253 | Average Loss: 0.4753
# Epoch:18 | Iter:   60 | Time: 00:01:05 | Train Loss: 0.0382 | Average Loss: 0.4725
# Epoch:18 | Iter:   80 | Time: 00:01:05 | Train Loss: 0.0116 | Average Loss: 0.4697
# Epoch:18 | Iter:  100 | Time: 00:01:06 | Train Loss: 0.0095 | Average Loss: 0.4668
# Epoch:18 | Iter:  120 | Time: 00:01:06 | Train Loss: 0.0083 | Average Loss: 0.4641
# Epoch:18 | Iter:  140 | Time: 00:01:07 | Train Loss: 0.0053 | Average Loss: 0.4613
# Epoch:18 | Iter:  160 | Time: 00:01:07 | Train Loss: 0.0075 | Average Loss: 0.4586
# Epoch:18 | Iter:  180 | Time: 00:01:08 | Train Loss: 0.0094 | Average Loss: 0.4559
# Accuracy: 0.601562 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:01:08 | Train Loss: 0.0053 | Average Loss: 0.4550
# Epoch:19 | Iter:   20 | Time: 00:01:08 | Train Loss: 0.0141 | Average Loss: 0.4524
# Epoch:19 | Iter:   40 | Time: 00:01:08 | Train Loss: 0.0089 | Average Loss: 0.4497
# Epoch:19 | Iter:   60 | Time: 00:01:09 | Train Loss: 0.0044 | Average Loss: 0.4472
# Epoch:19 | Iter:   80 | Time: 00:01:09 | Train Loss: 0.0061 | Average Loss: 0.4446
# Epoch:19 | Iter:  100 | Time: 00:01:10 | Train Loss: 0.0064 | Average Loss: 0.4421
# Epoch:19 | Iter:  120 | Time: 00:01:10 | Train Loss: 0.0039 | Average Loss: 0.4396
# Epoch:19 | Iter:  140 | Time: 00:01:11 | Train Loss: 0.0058 | Average Loss: 0.4372
# Epoch:19 | Iter:  160 | Time: 00:01:11 | Train Loss: 0.0048 | Average Loss: 0.4347
# Epoch:19 | Iter:  180 | Time: 00:01:11 | Train Loss: 0.0075 | Average Loss: 0.4323
# Accuracy: 0.604167 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:01:11 | Train Loss: 0.0040 | Average Loss: 0.4315
# Epoch:20 | Iter:   20 | Time: 00:01:12 | Train Loss: 0.0114 | Average Loss: 0.4291
# Epoch:20 | Iter:   40 | Time: 00:01:12 | Train Loss: 0.0077 | Average Loss: 0.4267
# Epoch:20 | Iter:   60 | Time: 00:01:13 | Train Loss: 0.0046 | Average Loss: 0.4244
# Epoch:20 | Iter:   80 | Time: 00:01:13 | Train Loss: 0.0041 | Average Loss: 0.4221
# Epoch:20 | Iter:  100 | Time: 00:01:14 | Train Loss: 0.0042 | Average Loss: 0.4198
# Epoch:20 | Iter:  120 | Time: 00:01:14 | Train Loss: 0.0066 | Average Loss: 0.4176
# Epoch:20 | Iter:  140 | Time: 00:01:14 | Train Loss: 0.0067 | Average Loss: 0.4153
# Epoch:20 | Iter:  160 | Time: 00:01:15 | Train Loss: 0.0037 | Average Loss: 0.4131
# Epoch:20 | Iter:  180 | Time: 00:01:15 | Train Loss: 0.0051 | Average Loss: 0.4109
# Accuracy: 0.609375 | Time: 00:00:00
# Epoch:21 | Iter:    0 | Time: 00:01:15 | Train Loss: 0.0030 | Average Loss: 0.4102
# Epoch:21 | Iter:   20 | Time: 00:01:16 | Train Loss: 0.0096 | Average Loss: 0.4080
# Epoch:21 | Iter:   40 | Time: 00:01:16 | Train Loss: 0.0050 | Average Loss: 0.4059
# Epoch:21 | Iter:   60 | Time: 00:01:17 | Train Loss: 0.0062 | Average Loss: 0.4038
# Epoch:21 | Iter:   80 | Time: 00:01:17 | Train Loss: 0.0033 | Average Loss: 0.4017
# Epoch:21 | Iter:  100 | Time: 00:01:17 | Train Loss: 0.0046 | Average Loss: 0.3996
# Epoch:21 | Iter:  120 | Time: 00:01:18 | Train Loss: 0.0050 | Average Loss: 0.3976
# Epoch:21 | Iter:  140 | Time: 00:01:18 | Train Loss: 0.0027 | Average Loss: 0.3955
# Epoch:21 | Iter:  160 | Time: 00:01:19 | Train Loss: 0.0025 | Average Loss: 0.3935
# Epoch:21 | Iter:  180 | Time: 00:01:19 | Train Loss: 0.0036 | Average Loss: 0.3915
# Accuracy: 0.601562 | Time: 00:00:00
# Epoch:22 | Iter:    0 | Time: 00:01:19 | Train Loss: 0.0025 | Average Loss: 0.3908
# Epoch:22 | Iter:   20 | Time: 00:01:19 | Train Loss: 0.0068 | Average Loss: 0.3889
# Epoch:22 | Iter:   40 | Time: 00:01:20 | Train Loss: 0.0039 | Average Loss: 0.3869
# Epoch:22 | Iter:   60 | Time: 00:01:20 | Train Loss: 0.0032 | Average Loss: 0.3850
# Epoch:22 | Iter:   80 | Time: 00:01:21 | Train Loss: 0.0031 | Average Loss: 0.3831
# Epoch:22 | Iter:  100 | Time: 00:01:21 | Train Loss: 0.0051 | Average Loss: 0.3812
# Epoch:22 | Iter:  120 | Time: 00:01:22 | Train Loss: 0.0030 | Average Loss: 0.3794
# Epoch:22 | Iter:  140 | Time: 00:01:22 | Train Loss: 0.0020 | Average Loss: 0.3775
# Epoch:22 | Iter:  160 | Time: 00:01:22 | Train Loss: 0.0023 | Average Loss: 0.3757
# Epoch:22 | Iter:  180 | Time: 00:01:23 | Train Loss: 0.0022 | Average Loss: 0.3739
# Accuracy: 0.596354 | Time: 00:00:00
# Epoch:23 | Iter:    0 | Time: 00:01:23 | Train Loss: 0.0020 | Average Loss: 0.3732
# Epoch:23 | Iter:   20 | Time: 00:01:23 | Train Loss: 0.0062 | Average Loss: 0.3714
# Epoch:23 | Iter:   40 | Time: 00:01:24 | Train Loss: 0.0027 | Average Loss: 0.3697
# Epoch:23 | Iter:   60 | Time: 00:01:24 | Train Loss: 0.0025 | Average Loss: 0.3679
# Epoch:23 | Iter:   80 | Time: 00:01:25 | Train Loss: 0.0029 | Average Loss: 0.3662
# Epoch:23 | Iter:  100 | Time: 00:01:25 | Train Loss: 0.0022 | Average Loss: 0.3644
# Epoch:23 | Iter:  120 | Time: 00:01:25 | Train Loss: 0.0018 | Average Loss: 0.3627
# Epoch:23 | Iter:  140 | Time: 00:01:26 | Train Loss: 0.0017 | Average Loss: 0.3610
# Epoch:23 | Iter:  160 | Time: 00:01:26 | Train Loss: 0.0019 | Average Loss: 0.3593
# Epoch:23 | Iter:  180 | Time: 00:01:27 | Train Loss: 0.0019 | Average Loss: 0.3577
# Accuracy: 0.596354 | Time: 00:00:00
# Epoch:24 | Iter:    0 | Time: 00:01:27 | Train Loss: 0.0016 | Average Loss: 0.3571
# Epoch:24 | Iter:   20 | Time: 00:01:27 | Train Loss: 0.0055 | Average Loss: 0.3555
# Epoch:24 | Iter:   40 | Time: 00:01:28 | Train Loss: 0.0023 | Average Loss: 0.3538
# Epoch:24 | Iter:   60 | Time: 00:01:28 | Train Loss: 0.0020 | Average Loss: 0.3522
# Epoch:24 | Iter:   80 | Time: 00:01:28 | Train Loss: 0.0023 | Average Loss: 0.3506
# Epoch:24 | Iter:  100 | Time: 00:01:29 | Train Loss: 0.0020 | Average Loss: 0.3490
# Epoch:24 | Iter:  120 | Time: 00:01:29 | Train Loss: 0.0014 | Average Loss: 0.3475
# Epoch:24 | Iter:  140 | Time: 00:01:30 | Train Loss: 0.0012 | Average Loss: 0.3459
# Epoch:24 | Iter:  160 | Time: 00:01:30 | Train Loss: 0.0015 | Average Loss: 0.3444
# Epoch:24 | Iter:  180 | Time: 00:01:30 | Train Loss: 0.0018 | Average Loss: 0.3428
# Accuracy: 0.598958 | Time: 00:00:00
# Epoch:25 | Iter:    0 | Time: 00:01:30 | Train Loss: 0.0014 | Average Loss: 0.3423
# Epoch:25 | Iter:   20 | Time: 00:01:31 | Train Loss: 0.0030 | Average Loss: 0.3408
# Epoch:25 | Iter:   40 | Time: 00:01:31 | Train Loss: 0.0021 | Average Loss: 0.3393
# Epoch:25 | Iter:   60 | Time: 00:01:32 | Train Loss: 0.0015 | Average Loss: 0.3378
# Epoch:25 | Iter:   80 | Time: 00:01:32 | Train Loss: 0.0019 | Average Loss: 0.3363
# Epoch:25 | Iter:  100 | Time: 00:01:33 | Train Loss: 0.0018 | Average Loss: 0.3349
# Epoch:25 | Iter:  120 | Time: 00:01:33 | Train Loss: 0.0012 | Average Loss: 0.3334
# Epoch:25 | Iter:  140 | Time: 00:01:33 | Train Loss: 0.0010 | Average Loss: 0.3320
# Epoch:25 | Iter:  160 | Time: 00:01:34 | Train Loss: 0.0012 | Average Loss: 0.3306
# Epoch:25 | Iter:  180 | Time: 00:01:34 | Train Loss: 0.0015 | Average Loss: 0.3292
# Accuracy: 0.601562 | Time: 00:00:00
# Epoch:26 | Iter:    0 | Time: 00:01:34 | Train Loss: 0.0012 | Average Loss: 0.3287
# Epoch:26 | Iter:   20 | Time: 00:01:35 | Train Loss: 0.0020 | Average Loss: 0.3273
# Epoch:26 | Iter:   40 | Time: 00:01:35 | Train Loss: 0.0016 | Average Loss: 0.3259
# Epoch:26 | Iter:   60 | Time: 00:01:36 | Train Loss: 0.0013 | Average Loss: 0.3245
# Epoch:26 | Iter:   80 | Time: 00:01:36 | Train Loss: 0.0016 | Average Loss: 0.3232
# Epoch:26 | Iter:  100 | Time: 00:01:36 | Train Loss: 0.0015 | Average Loss: 0.3218
# Epoch:26 | Iter:  120 | Time: 00:01:37 | Train Loss: 0.0010 | Average Loss: 0.3205
# Epoch:26 | Iter:  140 | Time: 00:01:37 | Train Loss: 0.0008 | Average Loss: 0.3192
# Epoch:26 | Iter:  160 | Time: 00:01:38 | Train Loss: 0.0011 | Average Loss: 0.3178
# Epoch:26 | Iter:  180 | Time: 00:01:38 | Train Loss: 0.0013 | Average Loss: 0.3165
# Accuracy: 0.601562 | Time: 00:00:00
# Epoch:27 | Iter:    0 | Time: 00:01:38 | Train Loss: 0.0010 | Average Loss: 0.3161
# Epoch:27 | Iter:   20 | Time: 00:01:39 | Train Loss: 0.0015 | Average Loss: 0.3148
# Epoch:27 | Iter:   40 | Time: 00:01:39 | Train Loss: 0.0013 | Average Loss: 0.3135
# Epoch:27 | Iter:   60 | Time: 00:01:39 | Train Loss: 0.0012 | Average Loss: 0.3122
# Epoch:27 | Iter:   80 | Time: 00:01:40 | Train Loss: 0.0014 | Average Loss: 0.3110
# Epoch:27 | Iter:  100 | Time: 00:01:40 | Train Loss: 0.0012 | Average Loss: 0.3097
# Epoch:27 | Iter:  120 | Time: 00:01:41 | Train Loss: 0.0009 | Average Loss: 0.3085
# Epoch:27 | Iter:  140 | Time: 00:01:41 | Train Loss: 0.0007 | Average Loss: 0.3073
# Epoch:27 | Iter:  160 | Time: 00:01:41 | Train Loss: 0.0010 | Average Loss: 0.3060
# Epoch:27 | Iter:  180 | Time: 00:01:42 | Train Loss: 0.0011 | Average Loss: 0.3048
# Accuracy: 0.609375 | Time: 00:00:00
# Epoch:28 | Iter:    0 | Time: 00:01:42 | Train Loss: 0.0009 | Average Loss: 0.3044
# Epoch:28 | Iter:   20 | Time: 00:01:42 | Train Loss: 0.0013 | Average Loss: 0.3032
# Epoch:28 | Iter:   40 | Time: 00:01:43 | Train Loss: 0.0012 | Average Loss: 0.3020
# Epoch:28 | Iter:   60 | Time: 00:01:43 | Train Loss: 0.0010 | Average Loss: 0.3008
# Epoch:28 | Iter:   80 | Time: 00:01:44 | Train Loss: 0.0012 | Average Loss: 0.2997
# Epoch:28 | Iter:  100 | Time: 00:01:44 | Train Loss: 0.0011 | Average Loss: 0.2985
# Epoch:28 | Iter:  120 | Time: 00:01:44 | Train Loss: 0.0008 | Average Loss: 0.2974
# Epoch:28 | Iter:  140 | Time: 00:01:45 | Train Loss: 0.0007 | Average Loss: 0.2962
# Epoch:28 | Iter:  160 | Time: 00:01:45 | Train Loss: 0.0009 | Average Loss: 0.2951
# Epoch:28 | Iter:  180 | Time: 00:01:46 | Train Loss: 0.0009 | Average Loss: 0.2940
# Accuracy: 0.606771 | Time: 00:00:00
# Epoch:29 | Iter:    0 | Time: 00:01:46 | Train Loss: 0.0008 | Average Loss: 0.2936
# Epoch:29 | Iter:   20 | Time: 00:01:46 | Train Loss: 0.0011 | Average Loss: 0.2925
# Epoch:29 | Iter:   40 | Time: 00:01:47 | Train Loss: 0.0010 | Average Loss: 0.2914
# Epoch:29 | Iter:   60 | Time: 00:01:47 | Train Loss: 0.0009 | Average Loss: 0.2903
# Epoch:29 | Iter:   80 | Time: 00:01:47 | Train Loss: 0.0011 | Average Loss: 0.2892
# Epoch:29 | Iter:  100 | Time: 00:01:48 | Train Loss: 0.0009 | Average Loss: 0.2881
# Epoch:29 | Iter:  120 | Time: 00:01:48 | Train Loss: 0.0007 | Average Loss: 0.2870
# Epoch:29 | Iter:  140 | Time: 00:01:49 | Train Loss: 0.0006 | Average Loss: 0.2860
# Epoch:29 | Iter:  160 | Time: 00:01:49 | Train Loss: 0.0008 | Average Loss: 0.2849
# Epoch:29 | Iter:  180 | Time: 00:01:49 | Train Loss: 0.0008 | Average Loss: 0.2838
# Accuracy: 0.606771 | Time: 00:00:00
# Epoch:30 | Iter:    0 | Time: 00:01:50 | Train Loss: 0.0007 | Average Loss: 0.2835
# Epoch:30 | Iter:   20 | Time: 00:01:50 | Train Loss: 0.0010 | Average Loss: 0.2824
# Epoch:30 | Iter:   40 | Time: 00:01:50 | Train Loss: 0.0009 | Average Loss: 0.2814
# Epoch:30 | Iter:   60 | Time: 00:01:51 | Train Loss: 0.0008 | Average Loss: 0.2804
# Epoch:30 | Iter:   80 | Time: 00:01:51 | Train Loss: 0.0010 | Average Loss: 0.2794
# Epoch:30 | Iter:  100 | Time: 00:01:52 | Train Loss: 0.0008 | Average Loss: 0.2784
# Epoch:30 | Iter:  120 | Time: 00:01:52 | Train Loss: 0.0006 | Average Loss: 0.2774
# Epoch:30 | Iter:  140 | Time: 00:01:52 | Train Loss: 0.0005 | Average Loss: 0.2764
# Epoch:30 | Iter:  160 | Time: 00:01:53 | Train Loss: 0.0007 | Average Loss: 0.2754
# Epoch:30 | Iter:  180 | Time: 00:01:53 | Train Loss: 0.0007 | Average Loss: 0.2744
# Accuracy: 0.606771 | Time: 00:00:00
# Epoch:31 | Iter:    0 | Time: 00:01:53 | Train Loss: 0.0006 | Average Loss: 0.2741
# Epoch:31 | Iter:   20 | Time: 00:01:54 | Train Loss: 0.0009 | Average Loss: 0.2731
# Epoch:31 | Iter:   40 | Time: 00:01:54 | Train Loss: 0.0008 | Average Loss: 0.2721
# Epoch:31 | Iter:   60 | Time: 00:01:55 | Train Loss: 0.0007 | Average Loss: 0.2712
# Epoch:31 | Iter:   80 | Time: 00:01:55 | Train Loss: 0.0008 | Average Loss: 0.2702
# Epoch:31 | Iter:  100 | Time: 00:01:55 | Train Loss: 0.0007 | Average Loss: 0.2693
# Epoch:31 | Iter:  120 | Time: 00:01:56 | Train Loss: 0.0005 | Average Loss: 0.2683
# Epoch:31 | Iter:  140 | Time: 00:01:56 | Train Loss: 0.0005 | Average Loss: 0.2674
# Epoch:31 | Iter:  160 | Time: 00:01:57 | Train Loss: 0.0006 | Average Loss: 0.2665
# Epoch:31 | Iter:  180 | Time: 00:01:57 | Train Loss: 0.0006 | Average Loss: 0.2656
# Accuracy: 0.609375 | Time: 00:00:00
# Epoch:32 | Iter:    0 | Time: 00:01:57 | Train Loss: 0.0005 | Average Loss: 0.2652
# Epoch:32 | Iter:   20 | Time: 00:01:58 | Train Loss: 0.0008 | Average Loss: 0.2643
# Epoch:32 | Iter:   40 | Time: 00:01:58 | Train Loss: 0.0007 | Average Loss: 0.2634
# Epoch:32 | Iter:   60 | Time: 00:01:58 | Train Loss: 0.0006 | Average Loss: 0.2625
# Epoch:32 | Iter:   80 | Time: 00:01:59 | Train Loss: 0.0007 | Average Loss: 0.2616
# Epoch:32 | Iter:  100 | Time: 00:01:59 | Train Loss: 0.0006 | Average Loss: 0.2607
# Epoch:32 | Iter:  120 | Time: 00:02:00 | Train Loss: 0.0005 | Average Loss: 0.2599
# Epoch:32 | Iter:  140 | Time: 00:02:00 | Train Loss: 0.0004 | Average Loss: 0.2590
# Epoch:32 | Iter:  160 | Time: 00:02:00 | Train Loss: 0.0005 | Average Loss: 0.2581
# Epoch:32 | Iter:  180 | Time: 00:02:01 | Train Loss: 0.0006 | Average Loss: 0.2573
# Accuracy: 0.609375 | Time: 00:00:00
# Epoch:33 | Iter:    0 | Time: 00:02:01 | Train Loss: 0.0004 | Average Loss: 0.2570
# Epoch:33 | Iter:   20 | Time: 00:02:01 | Train Loss: 0.0007 | Average Loss: 0.2561
# Epoch:33 | Iter:   40 | Time: 00:02:02 | Train Loss: 0.0006 | Average Loss: 0.2553
# Epoch:33 | Iter:   60 | Time: 00:02:02 | Train Loss: 0.0006 | Average Loss: 0.2544
# Epoch:33 | Iter:   80 | Time: 00:02:03 | Train Loss: 0.0007 | Average Loss: 0.2536
# Epoch:33 | Iter:  100 | Time: 00:02:03 | Train Loss: 0.0005 | Average Loss: 0.2527
# Epoch:33 | Iter:  120 | Time: 00:02:03 | Train Loss: 0.0004 | Average Loss: 0.2519
# Epoch:33 | Iter:  140 | Time: 00:02:04 | Train Loss: 0.0004 | Average Loss: 0.2511
# Epoch:33 | Iter:  160 | Time: 00:02:04 | Train Loss: 0.0005 | Average Loss: 0.2503
# Epoch:33 | Iter:  180 | Time: 00:02:05 | Train Loss: 0.0005 | Average Loss: 0.2495
# Accuracy: 0.609375 | Time: 00:00:00
# Epoch:34 | Iter:    0 | Time: 00:02:05 | Train Loss: 0.0004 | Average Loss: 0.2492
# Epoch:34 | Iter:   20 | Time: 00:02:05 | Train Loss: 0.0006 | Average Loss: 0.2484
# Epoch:34 | Iter:   40 | Time: 00:02:06 | Train Loss: 0.0005 | Average Loss: 0.2476
# Epoch:34 | Iter:   60 | Time: 00:02:06 | Train Loss: 0.0005 | Average Loss: 0.2468
# Epoch:34 | Iter:   80 | Time: 00:02:06 | Train Loss: 0.0006 | Average Loss: 0.2460
# Epoch:34 | Iter:  100 | Time: 00:02:07 | Train Loss: 0.0005 | Average Loss: 0.2452
# Epoch:34 | Iter:  120 | Time: 00:02:07 | Train Loss: 0.0004 | Average Loss: 0.2444
# Epoch:34 | Iter:  140 | Time: 00:02:08 | Train Loss: 0.0003 | Average Loss: 0.2437
# Epoch:34 | Iter:  160 | Time: 00:02:08 | Train Loss: 0.0004 | Average Loss: 0.2429
# Epoch:34 | Iter:  180 | Time: 00:02:08 | Train Loss: 0.0004 | Average Loss: 0.2421
# Accuracy: 0.606771 | Time: 00:00:00
# Epoch:35 | Iter:    0 | Time: 00:02:09 | Train Loss: 0.0003 | Average Loss: 0.2419
# Epoch:35 | Iter:   20 | Time: 00:02:09 | Train Loss: 0.0005 | Average Loss: 0.2411
# Epoch:35 | Iter:   40 | Time: 00:02:09 | Train Loss: 0.0004 | Average Loss: 0.2404
# Epoch:35 | Iter:   60 | Time: 00:02:10 | Train Loss: 0.0004 | Average Loss: 0.2396
# Epoch:35 | Iter:   80 | Time: 00:02:10 | Train Loss: 0.0005 | Average Loss: 0.2389
# Epoch:35 | Iter:  100 | Time: 00:02:11 | Train Loss: 0.0004 | Average Loss: 0.2381
# Epoch:35 | Iter:  120 | Time: 00:02:11 | Train Loss: 0.0003 | Average Loss: 0.2374
# Epoch:35 | Iter:  140 | Time: 00:02:11 | Train Loss: 0.0003 | Average Loss: 0.2367
# Epoch:35 | Iter:  160 | Time: 00:02:12 | Train Loss: 0.0004 | Average Loss: 0.2359
# Epoch:35 | Iter:  180 | Time: 00:02:12 | Train Loss: 0.0004 | Average Loss: 0.2352
# Accuracy: 0.609375 | Time: 00:00:00
# Epoch:36 | Iter:    0 | Time: 00:02:12 | Train Loss: 0.0003 | Average Loss: 0.2350
# Epoch:36 | Iter:   20 | Time: 00:02:13 | Train Loss: 0.0005 | Average Loss: 0.2343
# Epoch:36 | Iter:   40 | Time: 00:02:13 | Train Loss: 0.0004 | Average Loss: 0.2336
# Epoch:36 | Iter:   60 | Time: 00:02:14 | Train Loss: 0.0004 | Average Loss: 0.2328
# Epoch:36 | Iter:   80 | Time: 00:02:14 | Train Loss: 0.0005 | Average Loss: 0.2321
# Epoch:36 | Iter:  100 | Time: 00:02:14 | Train Loss: 0.0004 | Average Loss: 0.2314
# Epoch:36 | Iter:  120 | Time: 00:02:15 | Train Loss: 0.0003 | Average Loss: 0.2308
# Epoch:36 | Iter:  140 | Time: 00:02:15 | Train Loss: 0.0003 | Average Loss: 0.2301
# Epoch:36 | Iter:  160 | Time: 00:02:16 | Train Loss: 0.0003 | Average Loss: 0.2294
# Epoch:36 | Iter:  180 | Time: 00:02:16 | Train Loss: 0.0003 | Average Loss: 0.2287
# Accuracy: 0.609375 | Time: 00:00:00
# Epoch:37 | Iter:    0 | Time: 00:02:16 | Train Loss: 0.0003 | Average Loss: 0.2285
# Epoch:37 | Iter:   20 | Time: 00:02:17 | Train Loss: 0.0004 | Average Loss: 0.2278
# Epoch:37 | Iter:   40 | Time: 00:02:17 | Train Loss: 0.0004 | Average Loss: 0.2271
# Epoch:37 | Iter:   60 | Time: 00:02:17 | Train Loss: 0.0003 | Average Loss: 0.2264
# Epoch:37 | Iter:   80 | Time: 00:02:18 | Train Loss: 0.0004 | Average Loss: 0.2258
# Epoch:37 | Iter:  100 | Time: 00:02:18 | Train Loss: 0.0003 | Average Loss: 0.2251
# Epoch:37 | Iter:  120 | Time: 00:02:19 | Train Loss: 0.0003 | Average Loss: 0.2245
# Epoch:37 | Iter:  140 | Time: 00:02:19 | Train Loss: 0.0002 | Average Loss: 0.2238
# Epoch:37 | Iter:  160 | Time: 00:02:19 | Train Loss: 0.0003 | Average Loss: 0.2232
# Epoch:37 | Iter:  180 | Time: 00:02:20 | Train Loss: 0.0003 | Average Loss: 0.2225
# Accuracy: 0.609375 | Time: 00:00:00
# Epoch:38 | Iter:    0 | Time: 00:02:20 | Train Loss: 0.0002 | Average Loss: 0.2223
# Epoch:38 | Iter:   20 | Time: 00:02:20 | Train Loss: 0.0004 | Average Loss: 0.2217
# Epoch:38 | Iter:   40 | Time: 00:02:21 | Train Loss: 0.0003 | Average Loss: 0.2210
# Epoch:38 | Iter:   60 | Time: 00:02:21 | Train Loss: 0.0003 | Average Loss: 0.2204
# Epoch:38 | Iter:   80 | Time: 00:02:22 | Train Loss: 0.0004 | Average Loss: 0.2198
# Epoch:38 | Iter:  100 | Time: 00:02:22 | Train Loss: 0.0003 | Average Loss: 0.2191
# Epoch:38 | Iter:  120 | Time: 00:02:22 | Train Loss: 0.0002 | Average Loss: 0.2185
# Epoch:38 | Iter:  140 | Time: 00:02:23 | Train Loss: 0.0002 | Average Loss: 0.2179
# Epoch:38 | Iter:  160 | Time: 00:02:23 | Train Loss: 0.0003 | Average Loss: 0.2173
# Epoch:38 | Iter:  180 | Time: 00:02:24 | Train Loss: 0.0003 | Average Loss: 0.2167
# Accuracy: 0.606771 | Time: 00:00:00
# Epoch:39 | Iter:    0 | Time: 00:02:24 | Train Loss: 0.0002 | Average Loss: 0.2165
# Epoch:39 | Iter:   20 | Time: 00:02:24 | Train Loss: 0.0003 | Average Loss: 0.2158
# Epoch:39 | Iter:   40 | Time: 00:02:25 | Train Loss: 0.0003 | Average Loss: 0.2152
# Epoch:39 | Iter:   60 | Time: 00:02:25 | Train Loss: 0.0003 | Average Loss: 0.2146
# Epoch:39 | Iter:   80 | Time: 00:02:25 | Train Loss: 0.0003 | Average Loss: 0.2140
# Epoch:39 | Iter:  100 | Time: 00:02:26 | Train Loss: 0.0003 | Average Loss: 0.2135
# Epoch:39 | Iter:  120 | Time: 00:02:26 | Train Loss: 0.0002 | Average Loss: 0.2129
# Epoch:39 | Iter:  140 | Time: 00:02:27 | Train Loss: 0.0002 | Average Loss: 0.2123
# Epoch:39 | Iter:  160 | Time: 00:02:27 | Train Loss: 0.0003 | Average Loss: 0.2117
# Epoch:39 | Iter:  180 | Time: 00:02:27 | Train Loss: 0.0002 | Average Loss: 0.2111
# Accuracy: 0.606771 | Time: 00:00:00
# Epoch:40 | Iter:    0 | Time: 00:02:28 | Train Loss: 0.0002 | Average Loss: 0.2109
# Epoch:40 | Iter:   20 | Time: 00:02:28 | Train Loss: 0.0003 | Average Loss: 0.2103
# Epoch:40 | Iter:   40 | Time: 00:02:28 | Train Loss: 0.0003 | Average Loss: 0.2098
# Epoch:40 | Iter:   60 | Time: 00:02:29 | Train Loss: 0.0002 | Average Loss: 0.2092
# Epoch:40 | Iter:   80 | Time: 00:02:29 | Train Loss: 0.0003 | Average Loss: 0.2086
# Epoch:40 | Iter:  100 | Time: 00:02:30 | Train Loss: 0.0002 | Average Loss: 0.2081
# Epoch:40 | Iter:  120 | Time: 00:02:30 | Train Loss: 0.0002 | Average Loss: 0.2075
# Epoch:40 | Iter:  140 | Time: 00:02:30 | Train Loss: 0.0002 | Average Loss: 0.2069
# Epoch:40 | Iter:  160 | Time: 00:02:31 | Train Loss: 0.0002 | Average Loss: 0.2064
# Epoch:40 | Iter:  180 | Time: 00:02:31 | Train Loss: 0.0002 | Average Loss: 0.2058
# Accuracy: 0.606771 | Time: 00:00:00
# Epoch:41 | Iter:    0 | Time: 00:02:31 | Train Loss: 0.0002 | Average Loss: 0.2056
# Epoch:41 | Iter:   20 | Time: 00:02:32 | Train Loss: 0.0003 | Average Loss: 0.2051
# Epoch:41 | Iter:   40 | Time: 00:02:32 | Train Loss: 0.0002 | Average Loss: 0.2045
# Epoch:41 | Iter:   60 | Time: 00:02:33 | Train Loss: 0.0002 | Average Loss: 0.2040
# Epoch:41 | Iter:   80 | Time: 00:02:33 | Train Loss: 0.0003 | Average Loss: 0.2035
# Epoch:41 | Iter:  100 | Time: 00:02:33 | Train Loss: 0.0002 | Average Loss: 0.2029
# Epoch:41 | Iter:  120 | Time: 00:02:34 | Train Loss: 0.0002 | Average Loss: 0.2024
# Epoch:41 | Iter:  140 | Time: 00:02:34 | Train Loss: 0.0001 | Average Loss: 0.2019
# Epoch:41 | Iter:  160 | Time: 00:02:35 | Train Loss: 0.0002 | Average Loss: 0.2013
# Epoch:41 | Iter:  180 | Time: 00:02:35 | Train Loss: 0.0002 | Average Loss: 0.2008
# Accuracy: 0.606771 | Time: 00:00:00
# Epoch:42 | Iter:    0 | Time: 00:02:35 | Train Loss: 0.0002 | Average Loss: 0.2006
# Epoch:42 | Iter:   20 | Time: 00:02:36 | Train Loss: 0.0002 | Average Loss: 0.2001
# Epoch:42 | Iter:   40 | Time: 00:02:36 | Train Loss: 0.0002 | Average Loss: 0.1996
# Epoch:42 | Iter:   60 | Time: 00:02:36 | Train Loss: 0.0002 | Average Loss: 0.1991
# Epoch:42 | Iter:   80 | Time: 00:02:37 | Train Loss: 0.0002 | Average Loss: 0.1986
# Epoch:42 | Iter:  100 | Time: 00:02:37 | Train Loss: 0.0002 | Average Loss: 0.1980
# Epoch:42 | Iter:  120 | Time: 00:02:38 | Train Loss: 0.0002 | Average Loss: 0.1975
# Epoch:42 | Iter:  140 | Time: 00:02:38 | Train Loss: 0.0001 | Average Loss: 0.1970
# Epoch:42 | Iter:  160 | Time: 00:02:38 | Train Loss: 0.0002 | Average Loss: 0.1965
# Epoch:42 | Iter:  180 | Time: 00:02:39 | Train Loss: 0.0002 | Average Loss: 0.1960
# Accuracy: 0.606771 | Time: 00:00:00
# Epoch:43 | Iter:    0 | Time: 00:02:39 | Train Loss: 0.0001 | Average Loss: 0.1959
# Epoch:43 | Iter:   20 | Time: 00:02:39 | Train Loss: 0.0002 | Average Loss: 0.1954
# Epoch:43 | Iter:   40 | Time: 00:02:40 | Train Loss: 0.0002 | Average Loss: 0.1949
# Epoch:43 | Iter:   60 | Time: 00:02:40 | Train Loss: 0.0002 | Average Loss: 0.1944
# Epoch:43 | Iter:   80 | Time: 00:02:41 | Train Loss: 0.0002 | Average Loss: 0.1939
# Epoch:43 | Iter:  100 | Time: 00:02:41 | Train Loss: 0.0002 | Average Loss: 0.1934
# Epoch:43 | Iter:  120 | Time: 00:02:41 | Train Loss: 0.0001 | Average Loss: 0.1929
# Epoch:43 | Iter:  140 | Time: 00:02:42 | Train Loss: 0.0001 | Average Loss: 0.1924
# Epoch:43 | Iter:  160 | Time: 00:02:42 | Train Loss: 0.0002 | Average Loss: 0.1920
# Epoch:43 | Iter:  180 | Time: 00:02:43 | Train Loss: 0.0002 | Average Loss: 0.1915
# Accuracy: 0.606771 | Time: 00:00:00
# Epoch:44 | Iter:    0 | Time: 00:02:43 | Train Loss: 0.0001 | Average Loss: 0.1913
# Epoch:44 | Iter:   20 | Time: 00:02:43 | Train Loss: 0.0002 | Average Loss: 0.1908
# Epoch:44 | Iter:   40 | Time: 00:02:44 | Train Loss: 0.0002 | Average Loss: 0.1904
# Epoch:44 | Iter:   60 | Time: 00:02:44 | Train Loss: 0.0002 | Average Loss: 0.1899
# Epoch:44 | Iter:   80 | Time: 00:02:44 | Train Loss: 0.0002 | Average Loss: 0.1894
# Epoch:44 | Iter:  100 | Time: 00:02:45 | Train Loss: 0.0001 | Average Loss: 0.1890
# Epoch:44 | Iter:  120 | Time: 00:02:45 | Train Loss: 0.0001 | Average Loss: 0.1885
# Epoch:44 | Iter:  140 | Time: 00:02:46 | Train Loss: 0.0001 | Average Loss: 0.1880
# Epoch:44 | Iter:  160 | Time: 00:02:46 | Train Loss: 0.0001 | Average Loss: 0.1876
# Epoch:44 | Iter:  180 | Time: 00:02:46 | Train Loss: 0.0001 | Average Loss: 0.1871
# Accuracy: 0.604167 | Time: 00:00:00
# Epoch:45 | Iter:    0 | Time: 00:02:47 | Train Loss: 0.0001 | Average Loss: 0.1870
# Epoch:45 | Iter:   20 | Time: 00:02:47 | Train Loss: 0.0002 | Average Loss: 0.1865
# Epoch:45 | Iter:   40 | Time: 00:02:47 | Train Loss: 0.0001 | Average Loss: 0.1861
# Epoch:45 | Iter:   60 | Time: 00:02:48 | Train Loss: 0.0001 | Average Loss: 0.1856
# Epoch:45 | Iter:   80 | Time: 00:02:48 | Train Loss: 0.0002 | Average Loss: 0.1852
# Epoch:45 | Iter:  100 | Time: 00:02:49 | Train Loss: 0.0001 | Average Loss: 0.1847
# Epoch:45 | Iter:  120 | Time: 00:02:49 | Train Loss: 0.0001 | Average Loss: 0.1843
# Epoch:45 | Iter:  140 | Time: 00:02:49 | Train Loss: 0.0001 | Average Loss: 0.1838
# Epoch:45 | Iter:  160 | Time: 00:02:50 | Train Loss: 0.0001 | Average Loss: 0.1834
# Epoch:45 | Iter:  180 | Time: 00:02:50 | Train Loss: 0.0001 | Average Loss: 0.1830
# Accuracy: 0.606771 | Time: 00:00:00
# Epoch:46 | Iter:    0 | Time: 00:02:50 | Train Loss: 0.0001 | Average Loss: 0.1828
# Epoch:46 | Iter:   20 | Time: 00:02:51 | Train Loss: 0.0002 | Average Loss: 0.1824
# Epoch:46 | Iter:   40 | Time: 00:02:51 | Train Loss: 0.0001 | Average Loss: 0.1819
# Epoch:46 | Iter:   60 | Time: 00:02:52 | Train Loss: 0.0001 | Average Loss: 0.1815
# Epoch:46 | Iter:   80 | Time: 00:02:52 | Train Loss: 0.0001 | Average Loss: 0.1811
# Epoch:46 | Iter:  100 | Time: 00:02:52 | Train Loss: 0.0001 | Average Loss: 0.1807
# Epoch:46 | Iter:  120 | Time: 00:02:53 | Train Loss: 0.0001 | Average Loss: 0.1802
# Epoch:46 | Iter:  140 | Time: 00:02:53 | Train Loss: 0.0001 | Average Loss: 0.1798
# Epoch:46 | Iter:  160 | Time: 00:02:54 | Train Loss: 0.0001 | Average Loss: 0.1794
# Epoch:46 | Iter:  180 | Time: 00:02:54 | Train Loss: 0.0001 | Average Loss: 0.1790
# Accuracy: 0.606771 | Time: 00:00:00
# Epoch:47 | Iter:    0 | Time: 00:02:54 | Train Loss: 0.0001 | Average Loss: 0.1788
# Epoch:47 | Iter:   20 | Time: 00:02:55 | Train Loss: 0.0001 | Average Loss: 0.1784
# Epoch:47 | Iter:   40 | Time: 00:02:55 | Train Loss: 0.0001 | Average Loss: 0.1780
# Epoch:47 | Iter:   60 | Time: 00:02:55 | Train Loss: 0.0001 | Average Loss: 0.1776
# Epoch:47 | Iter:   80 | Time: 00:02:56 | Train Loss: 0.0001 | Average Loss: 0.1772
# Epoch:47 | Iter:  100 | Time: 00:02:56 | Train Loss: 0.0001 | Average Loss: 0.1768
# Epoch:47 | Iter:  120 | Time: 00:02:57 | Train Loss: 0.0001 | Average Loss: 0.1764
# Epoch:47 | Iter:  140 | Time: 00:02:57 | Train Loss: 0.0001 | Average Loss: 0.1760
# Epoch:47 | Iter:  160 | Time: 00:02:57 | Train Loss: 0.0001 | Average Loss: 0.1756
# Epoch:47 | Iter:  180 | Time: 00:02:58 | Train Loss: 0.0001 | Average Loss: 0.1752
# Accuracy: 0.606771 | Time: 00:00:00
# Epoch:48 | Iter:    0 | Time: 00:02:58 | Train Loss: 0.0001 | Average Loss: 0.1750
# Epoch:48 | Iter:   20 | Time: 00:02:58 | Train Loss: 0.0001 | Average Loss: 0.1746
# Epoch:48 | Iter:   40 | Time: 00:02:59 | Train Loss: 0.0001 | Average Loss: 0.1742
# Epoch:48 | Iter:   60 | Time: 00:02:59 | Train Loss: 0.0001 | Average Loss: 0.1739
# Epoch:48 | Iter:   80 | Time: 00:03:00 | Train Loss: 0.0001 | Average Loss: 0.1735
# Epoch:48 | Iter:  100 | Time: 00:03:00 | Train Loss: 0.0001 | Average Loss: 0.1731
# Epoch:48 | Iter:  120 | Time: 00:03:00 | Train Loss: 0.0001 | Average Loss: 0.1727
# Epoch:48 | Iter:  140 | Time: 00:03:01 | Train Loss: 0.0001 | Average Loss: 0.1723
# Epoch:48 | Iter:  160 | Time: 00:03:01 | Train Loss: 0.0001 | Average Loss: 0.1719
# Epoch:48 | Iter:  180 | Time: 00:03:02 | Train Loss: 0.0001 | Average Loss: 0.1715
# Accuracy: 0.611979 | Time: 00:00:00
# Epoch:49 | Iter:    0 | Time: 00:03:02 | Train Loss: 0.0001 | Average Loss: 0.1714
# Epoch:49 | Iter:   20 | Time: 00:03:02 | Train Loss: 0.0001 | Average Loss: 0.1710
# Epoch:49 | Iter:   40 | Time: 00:03:03 | Train Loss: 0.0001 | Average Loss: 0.1706
# Epoch:49 | Iter:   60 | Time: 00:03:03 | Train Loss: 0.0001 | Average Loss: 0.1703
# Epoch:49 | Iter:   80 | Time: 00:03:03 | Train Loss: 0.0001 | Average Loss: 0.1699
# Epoch:49 | Iter:  100 | Time: 00:03:04 | Train Loss: 0.0001 | Average Loss: 0.1695
# Epoch:49 | Iter:  120 | Time: 00:03:04 | Train Loss: 0.0001 | Average Loss: 0.1691
# Epoch:49 | Iter:  140 | Time: 00:03:05 | Train Loss: 0.0001 | Average Loss: 0.1688
# Epoch:49 | Iter:  160 | Time: 00:03:05 | Train Loss: 0.0001 | Average Loss: 0.1684
# Epoch:49 | Iter:  180 | Time: 00:03:05 | Train Loss: 0.0001 | Average Loss: 0.1680
# Accuracy: 0.611979 | Time: 00:00:00
# Epoch:50 | Iter:    0 | Time: 00:03:06 | Train Loss: 0.0001 | Average Loss: 0.1679
# Epoch:50 | Iter:   20 | Time: 00:03:06 | Train Loss: 0.0001 | Average Loss: 0.1675
# Epoch:50 | Iter:   40 | Time: 00:03:06 | Train Loss: 0.0001 | Average Loss: 0.1672
# Epoch:50 | Iter:   60 | Time: 00:03:07 | Train Loss: 0.0001 | Average Loss: 0.1668
# Epoch:50 | Iter:   80 | Time: 00:03:07 | Train Loss: 0.0001 | Average Loss: 0.1664
# Epoch:50 | Iter:  100 | Time: 00:03:08 | Train Loss: 0.0001 | Average Loss: 0.1661
# Epoch:50 | Iter:  120 | Time: 00:03:08 | Train Loss: 0.0001 | Average Loss: 0.1657
# Epoch:50 | Iter:  140 | Time: 00:03:08 | Train Loss: 0.0001 | Average Loss: 0.1654
# Epoch:50 | Iter:  160 | Time: 00:03:09 | Train Loss: 0.0001 | Average Loss: 0.1650
# Epoch:50 | Iter:  180 | Time: 00:03:09 | Train Loss: 0.0001 | Average Loss: 0.1647
# Accuracy: 0.611979 | Time: 00:00:00
# max accuracy tensor(0.6120, device='cuda:0')

# %% [markdown]
# **Answer**:
#
# Technique 2: Image augmentation by randomly rotating images.
#
# Accuracy on test set: 0.6120
#
# Accuracy increases/decreases: Increases

# %% [markdown]
# ### Technique 3

# %%
#--------------------------------------------------
#    Load Training Data and Testing Data
#--------------------------------------------------
# load data into size (64, 64)
img_size = (64, 64)
batch_size = 64 # training sample number per batch

# load training dataset
trainloader_small = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True, augment=True, zero_centered=True))
train_num = len(trainloader_small)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_small = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size, zero_centered=True))
test_num = len(testloader_small)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# 4800
# 4800
# Finish loading 75 minibatches (batch_size=64) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# 400
# 400
# Finish loading 6 minibatches (batch_size=64) of testing samples.

# %%
#--------------------------------------------------
#       Define Network Architecture
#--------------------------------------------------
#--------------------------------------------------
#       Define Network Architecture
#--------------------------------------------------
class Adi_Net(nn.Module):
  def __init__(self):
    super(Adi_Net,self).__init__()  
          
    self.features = torch.nn.Sequential(
      nn.Conv2d(1, 16, 3),
      nn.LeakyReLU(),
      nn.MaxPool2d(2), 
      nn.Conv2d(16, 64, 3),
      nn.LeakyReLU(),
      nn.MaxPool2d(2),
    )
    
    self.classifier = nn.Sequential(
        nn.Linear(64* 14* 14, 1024),
        nn.Dropout(),
        nn.Linear(1024, 16),
    )
    
  def forward(self, x):
    x = self.features(x) 
    # print(x.size()) 
    x = torch.flatten(x, 1)
    x = self.classifier(x)
    return x

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
net = Adi_Net()
train_option = {}
train_option['lr'] = 0.0005
train_option['epoch'] = 50
train_option['device'] = 'gpu'
max_accuracy = trainModel(net, trainloader_small, train_option, testloader_small)
print("max accuracy", max_accuracy)
# Out:
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.7646 | Average Loss: 2.7646
# Epoch: 1 | Iter:   20 | Time: 00:00:00 | Train Loss: 2.3766 | Average Loss: 2.6421
# Epoch: 1 | Iter:   40 | Time: 00:00:00 | Train Loss: 2.0270 | Average Loss: 2.4640
# Epoch: 1 | Iter:   60 | Time: 00:00:00 | Train Loss: 1.9623 | Average Loss: 2.3257
# Accuracy: 0.424479 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.4529 | Average Loss: 2.2358
# Epoch: 2 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.4199 | Average Loss: 2.1185
# Epoch: 2 | Iter:   40 | Time: 00:00:01 | Train Loss: 1.4412 | Average Loss: 2.0283
# Epoch: 2 | Iter:   60 | Time: 00:00:01 | Train Loss: 1.1833 | Average Loss: 1.9427
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.0341 | Average Loss: 1.8832
# Epoch: 3 | Iter:   20 | Time: 00:00:02 | Train Loss: 0.9568 | Average Loss: 1.8025
# Epoch: 3 | Iter:   40 | Time: 00:00:02 | Train Loss: 0.9868 | Average Loss: 1.7351
# Epoch: 3 | Iter:   60 | Time: 00:00:02 | Train Loss: 0.9194 | Average Loss: 1.6679
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.5851 | Average Loss: 1.6202
# Epoch: 4 | Iter:   20 | Time: 00:00:03 | Train Loss: 0.6652 | Average Loss: 1.5577
# Epoch: 4 | Iter:   40 | Time: 00:00:03 | Train Loss: 0.7947 | Average Loss: 1.5033
# Epoch: 4 | Iter:   60 | Time: 00:00:03 | Train Loss: 0.6621 | Average Loss: 1.4516
# Accuracy: 0.611979 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.3852 | Average Loss: 1.4137
# Epoch: 5 | Iter:   20 | Time: 00:00:04 | Train Loss: 0.5382 | Average Loss: 1.3648
# Epoch: 5 | Iter:   40 | Time: 00:00:04 | Train Loss: 0.6111 | Average Loss: 1.3214
# Epoch: 5 | Iter:   60 | Time: 00:00:04 | Train Loss: 0.4281 | Average Loss: 1.2794
# Accuracy: 0.640625 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.2590 | Average Loss: 1.2483
# Epoch: 6 | Iter:   20 | Time: 00:00:05 | Train Loss: 0.3372 | Average Loss: 1.2063
# Epoch: 6 | Iter:   40 | Time: 00:00:05 | Train Loss: 0.5602 | Average Loss: 1.1689
# Epoch: 6 | Iter:   60 | Time: 00:00:05 | Train Loss: 0.3999 | Average Loss: 1.1343
# Accuracy: 0.622396 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.2159 | Average Loss: 1.1086
# Epoch: 7 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.2538 | Average Loss: 1.0742
# Epoch: 7 | Iter:   40 | Time: 00:00:06 | Train Loss: 0.4427 | Average Loss: 1.0437
# Epoch: 7 | Iter:   60 | Time: 00:00:06 | Train Loss: 0.2416 | Average Loss: 1.0151
# Accuracy: 0.635417 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.1721 | Average Loss: 0.9945
# Epoch: 8 | Iter:   20 | Time: 00:00:07 | Train Loss: 0.1727 | Average Loss: 0.9660
# Epoch: 8 | Iter:   40 | Time: 00:00:07 | Train Loss: 0.2193 | Average Loss: 0.9400
# Epoch: 8 | Iter:   60 | Time: 00:00:07 | Train Loss: 0.1589 | Average Loss: 0.9177
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.1478 | Average Loss: 0.9003
# Epoch: 9 | Iter:   20 | Time: 00:00:08 | Train Loss: 0.1692 | Average Loss: 0.8769
# Epoch: 9 | Iter:   40 | Time: 00:00:08 | Train Loss: 0.1742 | Average Loss: 0.8552
# Epoch: 9 | Iter:   60 | Time: 00:00:08 | Train Loss: 0.1481 | Average Loss: 0.8356
# Accuracy: 0.601562 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.1210 | Average Loss: 0.8213
# Epoch:10 | Iter:   20 | Time: 00:00:08 | Train Loss: 0.1131 | Average Loss: 0.8017
# Epoch:10 | Iter:   40 | Time: 00:00:09 | Train Loss: 0.1770 | Average Loss: 0.7829
# Epoch:10 | Iter:   60 | Time: 00:00:09 | Train Loss: 0.0995 | Average Loss: 0.7661
# Accuracy: 0.557292 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.2345 | Average Loss: 0.7552
# Epoch:11 | Iter:   20 | Time: 00:00:09 | Train Loss: 0.0779 | Average Loss: 0.7396
# Epoch:11 | Iter:   40 | Time: 00:00:10 | Train Loss: 0.1563 | Average Loss: 0.7240
# Epoch:11 | Iter:   60 | Time: 00:00:10 | Train Loss: 0.0515 | Average Loss: 0.7087
# Accuracy: 0.627604 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.0448 | Average Loss: 0.6975
# Epoch:12 | Iter:   20 | Time: 00:00:10 | Train Loss: 0.0511 | Average Loss: 0.6830
# Epoch:12 | Iter:   40 | Time: 00:00:11 | Train Loss: 0.0884 | Average Loss: 0.6692
# Epoch:12 | Iter:   60 | Time: 00:00:11 | Train Loss: 0.0470 | Average Loss: 0.6553
# Accuracy: 0.622396 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.0445 | Average Loss: 0.6456
# Epoch:13 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.0515 | Average Loss: 0.6327
# Epoch:13 | Iter:   40 | Time: 00:00:12 | Train Loss: 0.0856 | Average Loss: 0.6205
# Epoch:13 | Iter:   60 | Time: 00:00:12 | Train Loss: 0.0420 | Average Loss: 0.6086
# Accuracy: 0.622396 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.0380 | Average Loss: 0.6001
# Epoch:14 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.0278 | Average Loss: 0.5891
# Epoch:14 | Iter:   40 | Time: 00:00:13 | Train Loss: 0.0631 | Average Loss: 0.5784
# Epoch:14 | Iter:   60 | Time: 00:00:13 | Train Loss: 0.0212 | Average Loss: 0.5679
# Accuracy: 0.604167 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.0283 | Average Loss: 0.5604
# Epoch:15 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.0262 | Average Loss: 0.5508
# Epoch:15 | Iter:   40 | Time: 00:00:14 | Train Loss: 0.0570 | Average Loss: 0.5417
# Epoch:15 | Iter:   60 | Time: 00:00:14 | Train Loss: 0.0238 | Average Loss: 0.5324
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.0265 | Average Loss: 0.5256
# Epoch:16 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.0369 | Average Loss: 0.5170
# Epoch:16 | Iter:   40 | Time: 00:00:15 | Train Loss: 0.0292 | Average Loss: 0.5087
# Epoch:16 | Iter:   60 | Time: 00:00:15 | Train Loss: 0.0084 | Average Loss: 0.5004
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.0112 | Average Loss: 0.4944
# Epoch:17 | Iter:   20 | Time: 00:00:15 | Train Loss: 0.0129 | Average Loss: 0.4866
# Epoch:17 | Iter:   40 | Time: 00:00:16 | Train Loss: 0.0083 | Average Loss: 0.4791
# Epoch:17 | Iter:   60 | Time: 00:00:16 | Train Loss: 0.0088 | Average Loss: 0.4717
# Accuracy: 0.622396 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.0138 | Average Loss: 0.4664
# Epoch:18 | Iter:   20 | Time: 00:00:16 | Train Loss: 0.0162 | Average Loss: 0.4594
# Epoch:18 | Iter:   40 | Time: 00:00:16 | Train Loss: 0.0090 | Average Loss: 0.4527
# Epoch:18 | Iter:   60 | Time: 00:00:17 | Train Loss: 0.0081 | Average Loss: 0.4462
# Accuracy: 0.614583 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:00:17 | Train Loss: 0.0179 | Average Loss: 0.4414
# Epoch:19 | Iter:   20 | Time: 00:00:17 | Train Loss: 0.0166 | Average Loss: 0.4352
# Epoch:19 | Iter:   40 | Time: 00:00:17 | Train Loss: 0.0078 | Average Loss: 0.4291
# Epoch:19 | Iter:   60 | Time: 00:00:18 | Train Loss: 0.0173 | Average Loss: 0.4232
# Accuracy: 0.630208 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:00:18 | Train Loss: 0.0080 | Average Loss: 0.4189
# Epoch:20 | Iter:   20 | Time: 00:00:18 | Train Loss: 0.0119 | Average Loss: 0.4133
# Epoch:20 | Iter:   40 | Time: 00:00:18 | Train Loss: 0.0062 | Average Loss: 0.4078
# Epoch:20 | Iter:   60 | Time: 00:00:19 | Train Loss: 0.0114 | Average Loss: 0.4025
# Accuracy: 0.622396 | Time: 00:00:00
# Epoch:21 | Iter:    0 | Time: 00:00:19 | Train Loss: 0.0051 | Average Loss: 0.3985
# Epoch:21 | Iter:   20 | Time: 00:00:19 | Train Loss: 0.0054 | Average Loss: 0.3934
# Epoch:21 | Iter:   40 | Time: 00:00:19 | Train Loss: 0.0368 | Average Loss: 0.3884
# Epoch:21 | Iter:   60 | Time: 00:00:20 | Train Loss: 0.0070 | Average Loss: 0.3836
# Accuracy: 0.614583 | Time: 00:00:00
# Epoch:22 | Iter:    0 | Time: 00:00:20 | Train Loss: 0.0053 | Average Loss: 0.3800
# Epoch:22 | Iter:   20 | Time: 00:00:20 | Train Loss: 0.0076 | Average Loss: 0.3753
# Epoch:22 | Iter:   40 | Time: 00:00:20 | Train Loss: 0.0145 | Average Loss: 0.3708
# Epoch:22 | Iter:   60 | Time: 00:00:21 | Train Loss: 0.0070 | Average Loss: 0.3663
# Accuracy: 0.606771 | Time: 00:00:00
# Epoch:23 | Iter:    0 | Time: 00:00:21 | Train Loss: 0.0047 | Average Loss: 0.3630
# Epoch:23 | Iter:   20 | Time: 00:00:21 | Train Loss: 0.0034 | Average Loss: 0.3588
# Epoch:23 | Iter:   40 | Time: 00:00:21 | Train Loss: 0.0117 | Average Loss: 0.3546
# Epoch:23 | Iter:   60 | Time: 00:00:22 | Train Loss: 0.0018 | Average Loss: 0.3505
# Accuracy: 0.622396 | Time: 00:00:00
# Epoch:24 | Iter:    0 | Time: 00:00:22 | Train Loss: 0.0026 | Average Loss: 0.3475
# Epoch:24 | Iter:   20 | Time: 00:00:22 | Train Loss: 0.0092 | Average Loss: 0.3436
# Epoch:24 | Iter:   40 | Time: 00:00:22 | Train Loss: 0.0254 | Average Loss: 0.3397
# Epoch:24 | Iter:   60 | Time: 00:00:23 | Train Loss: 0.0025 | Average Loss: 0.3360
# Accuracy: 0.632812 | Time: 00:00:00
# Epoch:25 | Iter:    0 | Time: 00:00:23 | Train Loss: 0.0052 | Average Loss: 0.3333
# Epoch:25 | Iter:   20 | Time: 00:00:23 | Train Loss: 0.0017 | Average Loss: 0.3296
# Epoch:25 | Iter:   40 | Time: 00:00:23 | Train Loss: 0.0103 | Average Loss: 0.3261
# Epoch:25 | Iter:   60 | Time: 00:00:24 | Train Loss: 0.0023 | Average Loss: 0.3226
# Accuracy: 0.630208 | Time: 00:00:00
# Epoch:26 | Iter:    0 | Time: 00:00:24 | Train Loss: 0.0025 | Average Loss: 0.3201
# Epoch:26 | Iter:   20 | Time: 00:00:24 | Train Loss: 0.0030 | Average Loss: 0.3167
# Epoch:26 | Iter:   40 | Time: 00:00:24 | Train Loss: 0.0046 | Average Loss: 0.3135
# Epoch:26 | Iter:   60 | Time: 00:00:24 | Train Loss: 0.0020 | Average Loss: 0.3102
# Accuracy: 0.630208 | Time: 00:00:00
# Epoch:27 | Iter:    0 | Time: 00:00:25 | Train Loss: 0.0036 | Average Loss: 0.3079
# Epoch:27 | Iter:   20 | Time: 00:00:25 | Train Loss: 0.0028 | Average Loss: 0.3048
# Epoch:27 | Iter:   40 | Time: 00:00:25 | Train Loss: 0.0116 | Average Loss: 0.3018
# Epoch:27 | Iter:   60 | Time: 00:00:25 | Train Loss: 0.0014 | Average Loss: 0.2988
# Accuracy: 0.622396 | Time: 00:00:00
# Epoch:28 | Iter:    0 | Time: 00:00:26 | Train Loss: 0.0010 | Average Loss: 0.2966
# Epoch:28 | Iter:   20 | Time: 00:00:26 | Train Loss: 0.0022 | Average Loss: 0.2937
# Epoch:28 | Iter:   40 | Time: 00:00:26 | Train Loss: 0.0021 | Average Loss: 0.2909
# Epoch:28 | Iter:   60 | Time: 00:00:26 | Train Loss: 0.0018 | Average Loss: 0.2881
# Accuracy: 0.651042 | Time: 00:00:00
# Epoch:29 | Iter:    0 | Time: 00:00:27 | Train Loss: 0.0006 | Average Loss: 0.2861
# Epoch:29 | Iter:   20 | Time: 00:00:27 | Train Loss: 0.0010 | Average Loss: 0.2834
# Epoch:29 | Iter:   40 | Time: 00:00:27 | Train Loss: 0.0027 | Average Loss: 0.2808
# Epoch:29 | Iter:   60 | Time: 00:00:27 | Train Loss: 0.0022 | Average Loss: 0.2782
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:30 | Iter:    0 | Time: 00:00:28 | Train Loss: 0.0014 | Average Loss: 0.2763
# Epoch:30 | Iter:   20 | Time: 00:00:28 | Train Loss: 0.0016 | Average Loss: 0.2738
# Epoch:30 | Iter:   40 | Time: 00:00:28 | Train Loss: 0.0025 | Average Loss: 0.2713
# Epoch:30 | Iter:   60 | Time: 00:00:28 | Train Loss: 0.0025 | Average Loss: 0.2689
# Accuracy: 0.632812 | Time: 00:00:00
# Epoch:31 | Iter:    0 | Time: 00:00:29 | Train Loss: 0.0011 | Average Loss: 0.2671
# Epoch:31 | Iter:   20 | Time: 00:00:29 | Train Loss: 0.0009 | Average Loss: 0.2648
# Epoch:31 | Iter:   40 | Time: 00:00:29 | Train Loss: 0.0020 | Average Loss: 0.2625
# Epoch:31 | Iter:   60 | Time: 00:00:29 | Train Loss: 0.0073 | Average Loss: 0.2602
# Accuracy: 0.630208 | Time: 00:00:00
# Epoch:32 | Iter:    0 | Time: 00:00:30 | Train Loss: 0.0011 | Average Loss: 0.2586
# Epoch:32 | Iter:   20 | Time: 00:00:30 | Train Loss: 0.0027 | Average Loss: 0.2564
# Epoch:32 | Iter:   40 | Time: 00:00:30 | Train Loss: 0.0017 | Average Loss: 0.2542
# Epoch:32 | Iter:   60 | Time: 00:00:30 | Train Loss: 0.0006 | Average Loss: 0.2521
# Accuracy: 0.622396 | Time: 00:00:00
# Epoch:33 | Iter:    0 | Time: 00:00:31 | Train Loss: 0.0011 | Average Loss: 0.2505
# Epoch:33 | Iter:   20 | Time: 00:00:31 | Train Loss: 0.0009 | Average Loss: 0.2485
# Epoch:33 | Iter:   40 | Time: 00:00:31 | Train Loss: 0.0016 | Average Loss: 0.2465
# Epoch:33 | Iter:   60 | Time: 00:00:31 | Train Loss: 0.0043 | Average Loss: 0.2445
# Accuracy: 0.632812 | Time: 00:00:00
# Epoch:34 | Iter:    0 | Time: 00:00:31 | Train Loss: 0.0009 | Average Loss: 0.2430
# Epoch:34 | Iter:   20 | Time: 00:00:32 | Train Loss: 0.0034 | Average Loss: 0.2411
# Epoch:34 | Iter:   40 | Time: 00:00:32 | Train Loss: 0.0011 | Average Loss: 0.2392
# Epoch:34 | Iter:   60 | Time: 00:00:32 | Train Loss: 0.0021 | Average Loss: 0.2373
# Accuracy: 0.627604 | Time: 00:00:00
# Epoch:35 | Iter:    0 | Time: 00:00:32 | Train Loss: 0.0008 | Average Loss: 0.2359
# Epoch:35 | Iter:   20 | Time: 00:00:33 | Train Loss: 0.0008 | Average Loss: 0.2341
# Epoch:35 | Iter:   40 | Time: 00:00:33 | Train Loss: 0.0016 | Average Loss: 0.2323
# Epoch:35 | Iter:   60 | Time: 00:00:33 | Train Loss: 0.0009 | Average Loss: 0.2305
# Accuracy: 0.622396 | Time: 00:00:00
# Epoch:36 | Iter:    0 | Time: 00:00:33 | Train Loss: 0.0004 | Average Loss: 0.2292
# Epoch:36 | Iter:   20 | Time: 00:00:34 | Train Loss: 0.0014 | Average Loss: 0.2275
# Epoch:36 | Iter:   40 | Time: 00:00:34 | Train Loss: 0.0016 | Average Loss: 0.2258
# Epoch:36 | Iter:   60 | Time: 00:00:34 | Train Loss: 0.0007 | Average Loss: 0.2241
# Accuracy: 0.630208 | Time: 00:00:00
# Epoch:37 | Iter:    0 | Time: 00:00:34 | Train Loss: 0.0007 | Average Loss: 0.2228
# Epoch:37 | Iter:   20 | Time: 00:00:35 | Train Loss: 0.0006 | Average Loss: 0.2212
# Epoch:37 | Iter:   40 | Time: 00:00:35 | Train Loss: 0.0007 | Average Loss: 0.2196
# Epoch:37 | Iter:   60 | Time: 00:00:35 | Train Loss: 0.0006 | Average Loss: 0.2180
# Accuracy: 0.635417 | Time: 00:00:00
# Epoch:38 | Iter:    0 | Time: 00:00:35 | Train Loss: 0.0007 | Average Loss: 0.2168
# Epoch:38 | Iter:   20 | Time: 00:00:36 | Train Loss: 0.0013 | Average Loss: 0.2153
# Epoch:38 | Iter:   40 | Time: 00:00:36 | Train Loss: 0.0013 | Average Loss: 0.2138
# Epoch:38 | Iter:   60 | Time: 00:00:36 | Train Loss: 0.0005 | Average Loss: 0.2123
# Accuracy: 0.632812 | Time: 00:00:00
# Epoch:39 | Iter:    0 | Time: 00:00:36 | Train Loss: 0.0003 | Average Loss: 0.2112
# Epoch:39 | Iter:   20 | Time: 00:00:37 | Train Loss: 0.0005 | Average Loss: 0.2097
# Epoch:39 | Iter:   40 | Time: 00:00:37 | Train Loss: 0.0009 | Average Loss: 0.2083
# Epoch:39 | Iter:   60 | Time: 00:00:37 | Train Loss: 0.0003 | Average Loss: 0.2068
# Accuracy: 0.622396 | Time: 00:00:00
# Epoch:40 | Iter:    0 | Time: 00:00:37 | Train Loss: 0.0005 | Average Loss: 0.2058
# Epoch:40 | Iter:   20 | Time: 00:00:38 | Train Loss: 0.0004 | Average Loss: 0.2044
# Epoch:40 | Iter:   40 | Time: 00:00:38 | Train Loss: 0.0006 | Average Loss: 0.2030
# Epoch:40 | Iter:   60 | Time: 00:00:38 | Train Loss: 0.0005 | Average Loss: 0.2016
# Accuracy: 0.622396 | Time: 00:00:00
# Epoch:41 | Iter:    0 | Time: 00:00:38 | Train Loss: 0.0004 | Average Loss: 0.2006
# Epoch:41 | Iter:   20 | Time: 00:00:39 | Train Loss: 0.0003 | Average Loss: 0.1993
# Epoch:41 | Iter:   40 | Time: 00:00:39 | Train Loss: 0.0010 | Average Loss: 0.1980
# Epoch:41 | Iter:   60 | Time: 00:00:39 | Train Loss: 0.0005 | Average Loss: 0.1967
# Accuracy: 0.627604 | Time: 00:00:00
# Epoch:42 | Iter:    0 | Time: 00:00:39 | Train Loss: 0.0005 | Average Loss: 0.1958
# Epoch:42 | Iter:   20 | Time: 00:00:39 | Train Loss: 0.0006 | Average Loss: 0.1945
# Epoch:42 | Iter:   40 | Time: 00:00:40 | Train Loss: 0.0017 | Average Loss: 0.1933
# Epoch:42 | Iter:   60 | Time: 00:00:40 | Train Loss: 0.0003 | Average Loss: 0.1920
# Accuracy: 0.627604 | Time: 00:00:00
# Epoch:43 | Iter:    0 | Time: 00:00:40 | Train Loss: 0.0004 | Average Loss: 0.1911
# Epoch:43 | Iter:   20 | Time: 00:00:40 | Train Loss: 0.0008 | Average Loss: 0.1899
# Epoch:43 | Iter:   40 | Time: 00:00:41 | Train Loss: 0.0013 | Average Loss: 0.1887
# Epoch:43 | Iter:   60 | Time: 00:00:41 | Train Loss: 0.0009 | Average Loss: 0.1876
# Accuracy: 0.648438 | Time: 00:00:00
# Epoch:44 | Iter:    0 | Time: 00:00:41 | Train Loss: 0.0005 | Average Loss: 0.1867
# Epoch:44 | Iter:   20 | Time: 00:00:41 | Train Loss: 0.0005 | Average Loss: 0.1856
# Epoch:44 | Iter:   40 | Time: 00:00:42 | Train Loss: 0.0005 | Average Loss: 0.1844
# Epoch:44 | Iter:   60 | Time: 00:00:42 | Train Loss: 0.0008 | Average Loss: 0.1833
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:45 | Iter:    0 | Time: 00:00:42 | Train Loss: 0.0007 | Average Loss: 0.1825
# Epoch:45 | Iter:   20 | Time: 00:00:42 | Train Loss: 0.0003 | Average Loss: 0.1814
# Epoch:45 | Iter:   40 | Time: 00:00:43 | Train Loss: 0.0006 | Average Loss: 0.1803
# Epoch:45 | Iter:   60 | Time: 00:00:43 | Train Loss: 0.0002 | Average Loss: 0.1792
# Accuracy: 0.638021 | Time: 00:00:00
# Epoch:46 | Iter:    0 | Time: 00:00:43 | Train Loss: 0.0003 | Average Loss: 0.1784
# Epoch:46 | Iter:   20 | Time: 00:00:43 | Train Loss: 0.0004 | Average Loss: 0.1774
# Epoch:46 | Iter:   40 | Time: 00:00:44 | Train Loss: 0.0004 | Average Loss: 0.1764
# Epoch:46 | Iter:   60 | Time: 00:00:44 | Train Loss: 0.0003 | Average Loss: 0.1753
# Accuracy: 0.632812 | Time: 00:00:00
# Epoch:47 | Iter:    0 | Time: 00:00:44 | Train Loss: 0.0006 | Average Loss: 0.1746
# Epoch:47 | Iter:   20 | Time: 00:00:44 | Train Loss: 0.0004 | Average Loss: 0.1736
# Epoch:47 | Iter:   40 | Time: 00:00:45 | Train Loss: 0.0005 | Average Loss: 0.1726
# Epoch:47 | Iter:   60 | Time: 00:00:45 | Train Loss: 0.0004 | Average Loss: 0.1716
# Accuracy: 0.638021 | Time: 00:00:00
# Epoch:48 | Iter:    0 | Time: 00:00:45 | Train Loss: 0.0005 | Average Loss: 0.1709
# Epoch:48 | Iter:   20 | Time: 00:00:45 | Train Loss: 0.0003 | Average Loss: 0.1699
# Epoch:48 | Iter:   40 | Time: 00:00:46 | Train Loss: 0.0002 | Average Loss: 0.1690
# Epoch:48 | Iter:   60 | Time: 00:00:46 | Train Loss: 0.0001 | Average Loss: 0.1680
# Accuracy: 0.632812 | Time: 00:00:00
# Epoch:49 | Iter:    0 | Time: 00:00:46 | Train Loss: 0.0004 | Average Loss: 0.1673
# Epoch:49 | Iter:   20 | Time: 00:00:46 | Train Loss: 0.0003 | Average Loss: 0.1664
# Epoch:49 | Iter:   40 | Time: 00:00:46 | Train Loss: 0.0007 | Average Loss: 0.1655
# Epoch:49 | Iter:   60 | Time: 00:00:47 | Train Loss: 0.0002 | Average Loss: 0.1646
# Accuracy: 0.645833 | Time: 00:00:00
# Epoch:50 | Iter:    0 | Time: 00:00:47 | Train Loss: 0.0002 | Average Loss: 0.1639
# Epoch:50 | Iter:   20 | Time: 00:00:47 | Train Loss: 0.0003 | Average Loss: 0.1630
# Epoch:50 | Iter:   40 | Time: 00:00:47 | Train Loss: 0.0004 | Average Loss: 0.1622
# Epoch:50 | Iter:   60 | Time: 00:00:48 | Train Loss: 0.0035 | Average Loss: 0.1613
# Accuracy: 0.611979 | Time: 00:00:00
# max accuracy tensor(0.6510, device='cuda:0')

# %% [markdown]
# **Answer**:
#
# Technique 3: Using LeakyReLu activation function rather than ReLU.
#
# Accuracy on test set: 0.6510
#
# Accuracy increases/decreases: Increases

# %% [markdown]
# ## Problem 2: Fine Tuning a Pre-Trained Deep Network
# Our convolutional network to this point isn't "deep". Fortunately, the representations learned by deep convolutional networks is that they generalize surprisingly well to other recognition tasks.
#
# But how do we use an existing deep network for a new recognition task? Take for instance,  [AlexNet](http://papers.nips.cc/paper/4824-imagenet-classification-with-deep-convolutional-neural-networks) network has 1000 units in the final layer corresponding to 1000 ImageNet categories.
#
#
# **Hints**:
# - Many pre-trained models are available in PyTorch at [here](http://pytorch.org/docs/master/torchvision/models.html).
# - For fine-tuning pretrained network using PyTorch, please read this [tutorial](http://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html).

# %% [markdown]
# ### Problem 2.1
#
# **Strategy A**: *Fine-tune* an existing network. In this scenario you take an existing network, replace the final layer (or more) with random weights, and train the entire network again with images and ground truth labels for your recognition task. You are effectively treating the pre-trained deep network as a better initialization than the random weights used when training from scratch. When you don't have enough training data to train a complex network from scratch (e.g. with the 16 classes) this is an attractive option. Fine-tuning can work far better than Strategy B of taking the activations directly from an pre-trained CNN. For example, in [this paper](http://www.cc.gatech.edu/~hays/papers/deep_geo.pdf) from CVPR 2015, there wasn't enough data to train a deep network from scratch, but fine tuning led to 4 times higher accuracy than using off-the-shelf networks directly.
#
# (25 points) You are required to implement Strategy A to fine-tune a pre-trained **AlexNet** for this scene classification task. You should be able to achieve accuracy of **0.85** approximately. The minimum accuracy required for this section is **0.75**.
#
# Please provide detailed descriptions of:<br>
# (1) which layers of AlexNet have been replaced<br>
# (2) the architecture of the new layers added including activation methods (same as problem 1)<br>
# (3) the final accuracy on test set <br>

# %%
# reload data with a larger size
img_size = (224, 224)
batch_size = 16 # training sample number per batch 

# load training dataset
trainloader_large = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True, 
                                      augment=True, is_color=True, zero_centered=True))
train_num = len(trainloader_large)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_large = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size, is_color=True, zero_centered=True))
test_num = len(testloader_large)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# 4800
# 4800
# Finish loading 300 minibatches (batch_size=16) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# 400
# 400
# Finish loading 25 minibatches (batch_size=16) of testing samples.

# %%
model = models.alexnet(pretrained=True)
model.classifier[-1] = nn.Linear(in_features=4096, out_features=1024, bias=True)
# Out:
# Downloading: "https://download.pytorch.org/models/alexnet-owt-4df8aa71.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-4df8aa71.pth
# HBox(children=(FloatProgress(value=0.0, max=244418560.0), HTML(value='')))

# %%
#--------------------------------------------------
#       Fine-Tune Pretrained Network
#--------------------------------------------------
#--------------------------------------------------
#       Define Network Architecture
#--------------------------------------------------
class Adi_Net(nn.Module):
  def __init__(self):
    super(Adi_Net,self).__init__()  
          
    self.features = torch.nn.Sequential(
      model,
    )
    
    self.classifier = nn.Sequential(
        nn.Linear(1024, 16),
    )
    
  def forward(self, x):
    x = self.features(x) 
    # print(x.size()) 
    x = torch.flatten(x, 1)
    x = self.classifier(x)
    return x

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
net = Adi_Net()
train_option = {}
train_option['lr'] = 0.0001
train_option['epoch'] = 30
train_option['device'] = 'gpu'
max_accuracy = trainModel(net, trainloader_large, train_option, testloader_large)
print("max accuracy", max_accuracy)
# Out:
# Epoch: 1 | Iter:    0 | Time: 00:00:11 | Train Loss: 2.8045 | Average Loss: 2.8045
# Epoch: 1 | Iter:   20 | Time: 00:00:12 | Train Loss: 1.1532 | Average Loss: 1.6815
# Epoch: 1 | Iter:   40 | Time: 00:00:13 | Train Loss: 0.4811 | Average Loss: 1.3544
# Epoch: 1 | Iter:   60 | Time: 00:00:14 | Train Loss: 0.4567 | Average Loss: 1.2076
# Epoch: 1 | Iter:   80 | Time: 00:00:14 | Train Loss: 0.6673 | Average Loss: 1.0948
# Epoch: 1 | Iter:  100 | Time: 00:00:15 | Train Loss: 0.5465 | Average Loss: 1.0098
# Epoch: 1 | Iter:  120 | Time: 00:00:16 | Train Loss: 1.2459 | Average Loss: 1.0008
# Epoch: 1 | Iter:  140 | Time: 00:00:17 | Train Loss: 0.4364 | Average Loss: 0.9420
# Epoch: 1 | Iter:  160 | Time: 00:00:18 | Train Loss: 0.8173 | Average Loss: 0.9025
# Epoch: 1 | Iter:  180 | Time: 00:00:19 | Train Loss: 0.6999 | Average Loss: 0.8746
# Epoch: 1 | Iter:  200 | Time: 00:00:20 | Train Loss: 0.9167 | Average Loss: 0.8477
# Epoch: 1 | Iter:  220 | Time: 00:00:21 | Train Loss: 0.4136 | Average Loss: 0.8270
# Epoch: 1 | Iter:  240 | Time: 00:00:22 | Train Loss: 0.4091 | Average Loss: 0.8092
# Epoch: 1 | Iter:  260 | Time: 00:00:23 | Train Loss: 0.5176 | Average Loss: 0.7969
# Epoch: 1 | Iter:  280 | Time: 00:00:24 | Train Loss: 0.4270 | Average Loss: 0.7827
# Accuracy: 0.805000 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:25 | Train Loss: 0.4743 | Average Loss: 0.7640
# Epoch: 2 | Iter:   20 | Time: 00:00:26 | Train Loss: 0.3463 | Average Loss: 0.7387
# Epoch: 2 | Iter:   40 | Time: 00:00:27 | Train Loss: 0.3368 | Average Loss: 0.7194
# Epoch: 2 | Iter:   60 | Time: 00:00:28 | Train Loss: 0.1529 | Average Loss: 0.7003
# Epoch: 2 | Iter:   80 | Time: 00:00:29 | Train Loss: 0.1913 | Average Loss: 0.6817
# Epoch: 2 | Iter:  100 | Time: 00:00:30 | Train Loss: 0.0430 | Average Loss: 0.6600
# Epoch: 2 | Iter:  120 | Time: 00:00:31 | Train Loss: 0.5462 | Average Loss: 0.6477
# Epoch: 2 | Iter:  140 | Time: 00:00:32 | Train Loss: 0.1024 | Average Loss: 0.6338
# Epoch: 2 | Iter:  160 | Time: 00:00:33 | Train Loss: 0.5997 | Average Loss: 0.6220
# Epoch: 2 | Iter:  180 | Time: 00:00:34 | Train Loss: 0.5316 | Average Loss: 0.6132
# Epoch: 2 | Iter:  200 | Time: 00:00:35 | Train Loss: 0.2656 | Average Loss: 0.5997
# Epoch: 2 | Iter:  220 | Time: 00:00:36 | Train Loss: 0.3166 | Average Loss: 0.5876
# Epoch: 2 | Iter:  240 | Time: 00:00:37 | Train Loss: 0.0800 | Average Loss: 0.5755
# Epoch: 2 | Iter:  260 | Time: 00:00:38 | Train Loss: 0.1280 | Average Loss: 0.5671
# Epoch: 2 | Iter:  280 | Time: 00:00:39 | Train Loss: 0.8041 | Average Loss: 0.5602
# Accuracy: 0.835000 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:40 | Train Loss: 0.0823 | Average Loss: 0.5503
# Epoch: 3 | Iter:   20 | Time: 00:00:41 | Train Loss: 0.0602 | Average Loss: 0.5403
# Epoch: 3 | Iter:   40 | Time: 00:00:42 | Train Loss: 0.1919 | Average Loss: 0.5336
# Epoch: 3 | Iter:   60 | Time: 00:00:43 | Train Loss: 0.1165 | Average Loss: 0.5254
# Epoch: 3 | Iter:   80 | Time: 00:00:44 | Train Loss: 0.0359 | Average Loss: 0.5153
# Epoch: 3 | Iter:  100 | Time: 00:00:45 | Train Loss: 0.1414 | Average Loss: 0.5046
# Epoch: 3 | Iter:  120 | Time: 00:00:46 | Train Loss: 0.1891 | Average Loss: 0.4988
# Epoch: 3 | Iter:  140 | Time: 00:00:47 | Train Loss: 0.0263 | Average Loss: 0.4900
# Epoch: 3 | Iter:  160 | Time: 00:00:47 | Train Loss: 1.0710 | Average Loss: 0.4839
# Epoch: 3 | Iter:  180 | Time: 00:00:48 | Train Loss: 0.4049 | Average Loss: 0.4770
# Epoch: 3 | Iter:  200 | Time: 00:00:49 | Train Loss: 0.2933 | Average Loss: 0.4693
# Epoch: 3 | Iter:  220 | Time: 00:00:50 | Train Loss: 0.0995 | Average Loss: 0.4629
# Epoch: 3 | Iter:  240 | Time: 00:00:51 | Train Loss: 0.0441 | Average Loss: 0.4576
# Epoch: 3 | Iter:  260 | Time: 00:00:52 | Train Loss: 0.0712 | Average Loss: 0.4519
# Epoch: 3 | Iter:  280 | Time: 00:00:53 | Train Loss: 0.4937 | Average Loss: 0.4456
# Accuracy: 0.830000 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:54 | Train Loss: 0.0191 | Average Loss: 0.4383
# Epoch: 4 | Iter:   20 | Time: 00:00:55 | Train Loss: 0.2226 | Average Loss: 0.4319
# Epoch: 4 | Iter:   40 | Time: 00:00:56 | Train Loss: 0.0700 | Average Loss: 0.4277
# Epoch: 4 | Iter:   60 | Time: 00:00:57 | Train Loss: 0.0932 | Average Loss: 0.4229
# Epoch: 4 | Iter:   80 | Time: 00:00:58 | Train Loss: 0.0174 | Average Loss: 0.4166
# Epoch: 4 | Iter:  100 | Time: 00:00:59 | Train Loss: 0.1353 | Average Loss: 0.4110
# Epoch: 4 | Iter:  120 | Time: 00:01:00 | Train Loss: 0.0556 | Average Loss: 0.4066
# Epoch: 4 | Iter:  140 | Time: 00:01:01 | Train Loss: 0.1637 | Average Loss: 0.4008
# Epoch: 4 | Iter:  160 | Time: 00:01:02 | Train Loss: 0.6532 | Average Loss: 0.3977
# Epoch: 4 | Iter:  180 | Time: 00:01:03 | Train Loss: 0.0902 | Average Loss: 0.3941
# Epoch: 4 | Iter:  200 | Time: 00:01:04 | Train Loss: 0.6460 | Average Loss: 0.3898
# Epoch: 4 | Iter:  220 | Time: 00:01:05 | Train Loss: 0.0323 | Average Loss: 0.3851
# Epoch: 4 | Iter:  240 | Time: 00:01:06 | Train Loss: 0.1118 | Average Loss: 0.3816
# Epoch: 4 | Iter:  260 | Time: 00:01:07 | Train Loss: 0.0055 | Average Loss: 0.3769
# Epoch: 4 | Iter:  280 | Time: 00:01:08 | Train Loss: 0.0972 | Average Loss: 0.3748
# Accuracy: 0.820000 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:01:09 | Train Loss: 0.0392 | Average Loss: 0.3721
# Epoch: 5 | Iter:   20 | Time: 00:01:10 | Train Loss: 0.0988 | Average Loss: 0.3683
# Epoch: 5 | Iter:   40 | Time: 00:01:11 | Train Loss: 0.1053 | Average Loss: 0.3636
# Epoch: 5 | Iter:   60 | Time: 00:01:12 | Train Loss: 0.1550 | Average Loss: 0.3596
# Epoch: 5 | Iter:   80 | Time: 00:01:13 | Train Loss: 0.1723 | Average Loss: 0.3558
# Epoch: 5 | Iter:  100 | Time: 00:01:14 | Train Loss: 0.0723 | Average Loss: 0.3524
# Epoch: 5 | Iter:  120 | Time: 00:01:15 | Train Loss: 0.0500 | Average Loss: 0.3492
# Epoch: 5 | Iter:  140 | Time: 00:01:16 | Train Loss: 0.0035 | Average Loss: 0.3457
# Epoch: 5 | Iter:  160 | Time: 00:01:17 | Train Loss: 0.0640 | Average Loss: 0.3421
# Epoch: 5 | Iter:  180 | Time: 00:01:18 | Train Loss: 0.0123 | Average Loss: 0.3390
# Epoch: 5 | Iter:  200 | Time: 00:01:19 | Train Loss: 1.1568 | Average Loss: 0.3364
# Epoch: 5 | Iter:  220 | Time: 00:01:20 | Train Loss: 0.0562 | Average Loss: 0.3334
# Epoch: 5 | Iter:  240 | Time: 00:01:21 | Train Loss: 0.3530 | Average Loss: 0.3314
# Epoch: 5 | Iter:  260 | Time: 00:01:22 | Train Loss: 0.0980 | Average Loss: 0.3284
# Epoch: 5 | Iter:  280 | Time: 00:01:23 | Train Loss: 0.1711 | Average Loss: 0.3253
# Accuracy: 0.850000 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:01:24 | Train Loss: 0.0070 | Average Loss: 0.3223
# Epoch: 6 | Iter:   20 | Time: 00:01:25 | Train Loss: 0.1073 | Average Loss: 0.3189
# Epoch: 6 | Iter:   40 | Time: 00:01:26 | Train Loss: 0.1027 | Average Loss: 0.3158
# Epoch: 6 | Iter:   60 | Time: 00:01:27 | Train Loss: 0.2896 | Average Loss: 0.3126
# Epoch: 6 | Iter:   80 | Time: 00:01:28 | Train Loss: 0.1878 | Average Loss: 0.3103
# Epoch: 6 | Iter:  100 | Time: 00:01:29 | Train Loss: 0.1501 | Average Loss: 0.3075
# Epoch: 6 | Iter:  120 | Time: 00:01:30 | Train Loss: 0.0970 | Average Loss: 0.3047
# Epoch: 6 | Iter:  140 | Time: 00:01:31 | Train Loss: 0.1235 | Average Loss: 0.3016
# Epoch: 6 | Iter:  160 | Time: 00:01:32 | Train Loss: 0.0623 | Average Loss: 0.2990
# Epoch: 6 | Iter:  180 | Time: 00:01:33 | Train Loss: 0.0434 | Average Loss: 0.2968
# Epoch: 6 | Iter:  200 | Time: 00:01:34 | Train Loss: 0.0068 | Average Loss: 0.2950
# Epoch: 6 | Iter:  220 | Time: 00:01:35 | Train Loss: 0.2163 | Average Loss: 0.2927
# Epoch: 6 | Iter:  240 | Time: 00:01:36 | Train Loss: 0.1546 | Average Loss: 0.2900
# Epoch: 6 | Iter:  260 | Time: 00:01:37 | Train Loss: 0.0127 | Average Loss: 0.2873
# Epoch: 6 | Iter:  280 | Time: 00:01:38 | Train Loss: 0.1081 | Average Loss: 0.2844
# Accuracy: 0.850000 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:01:39 | Train Loss: 0.1056 | Average Loss: 0.2820
# Epoch: 7 | Iter:   20 | Time: 00:01:40 | Train Loss: 0.0032 | Average Loss: 0.2802
# Epoch: 7 | Iter:   40 | Time: 00:01:41 | Train Loss: 0.0372 | Average Loss: 0.2786
# Epoch: 7 | Iter:   60 | Time: 00:01:42 | Train Loss: 0.0092 | Average Loss: 0.2764
# Epoch: 7 | Iter:   80 | Time: 00:01:43 | Train Loss: 0.0040 | Average Loss: 0.2740
# Epoch: 7 | Iter:  100 | Time: 00:01:44 | Train Loss: 0.1617 | Average Loss: 0.2722
# Epoch: 7 | Iter:  120 | Time: 00:01:45 | Train Loss: 0.0663 | Average Loss: 0.2706
# Epoch: 7 | Iter:  140 | Time: 00:01:46 | Train Loss: 0.0635 | Average Loss: 0.2688
# Epoch: 7 | Iter:  160 | Time: 00:01:47 | Train Loss: 0.0330 | Average Loss: 0.2667
# Epoch: 7 | Iter:  180 | Time: 00:01:48 | Train Loss: 0.0111 | Average Loss: 0.2645
# Epoch: 7 | Iter:  200 | Time: 00:01:49 | Train Loss: 0.1811 | Average Loss: 0.2627
# Epoch: 7 | Iter:  220 | Time: 00:01:49 | Train Loss: 0.0013 | Average Loss: 0.2608
# Epoch: 7 | Iter:  240 | Time: 00:01:50 | Train Loss: 0.0328 | Average Loss: 0.2590
# Epoch: 7 | Iter:  260 | Time: 00:01:51 | Train Loss: 0.0005 | Average Loss: 0.2571
# Epoch: 7 | Iter:  280 | Time: 00:01:52 | Train Loss: 0.0019 | Average Loss: 0.2550
# Accuracy: 0.832500 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:01:54 | Train Loss: 0.0011 | Average Loss: 0.2529
# Epoch: 8 | Iter:   20 | Time: 00:01:55 | Train Loss: 0.0325 | Average Loss: 0.2508
# Epoch: 8 | Iter:   40 | Time: 00:01:56 | Train Loss: 0.0026 | Average Loss: 0.2489
# Epoch: 8 | Iter:   60 | Time: 00:01:57 | Train Loss: 0.2029 | Average Loss: 0.2474
# Epoch: 8 | Iter:   80 | Time: 00:01:58 | Train Loss: 0.0175 | Average Loss: 0.2466
# Epoch: 8 | Iter:  100 | Time: 00:01:59 | Train Loss: 0.1565 | Average Loss: 0.2450
# Epoch: 8 | Iter:  120 | Time: 00:02:00 | Train Loss: 0.0457 | Average Loss: 0.2435
# Epoch: 8 | Iter:  140 | Time: 00:02:01 | Train Loss: 0.0049 | Average Loss: 0.2416
# Epoch: 8 | Iter:  160 | Time: 00:02:02 | Train Loss: 0.0201 | Average Loss: 0.2400
# Epoch: 8 | Iter:  180 | Time: 00:02:03 | Train Loss: 0.1547 | Average Loss: 0.2386
# Epoch: 8 | Iter:  200 | Time: 00:02:03 | Train Loss: 0.0095 | Average Loss: 0.2370
# Epoch: 8 | Iter:  220 | Time: 00:02:04 | Train Loss: 0.0470 | Average Loss: 0.2357
# Epoch: 8 | Iter:  240 | Time: 00:02:05 | Train Loss: 0.0909 | Average Loss: 0.2350
# Epoch: 8 | Iter:  260 | Time: 00:02:06 | Train Loss: 0.0066 | Average Loss: 0.2346
# Epoch: 8 | Iter:  280 | Time: 00:02:07 | Train Loss: 0.0020 | Average Loss: 0.2338
# Accuracy: 0.822500 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:02:09 | Train Loss: 0.0835 | Average Loss: 0.2333
# Epoch: 9 | Iter:   20 | Time: 00:02:10 | Train Loss: 0.0618 | Average Loss: 0.2321
# Epoch: 9 | Iter:   40 | Time: 00:02:11 | Train Loss: 0.0185 | Average Loss: 0.2312
# Epoch: 9 | Iter:   60 | Time: 00:02:12 | Train Loss: 0.1328 | Average Loss: 0.2302
# Epoch: 9 | Iter:   80 | Time: 00:02:13 | Train Loss: 0.0224 | Average Loss: 0.2290
# Epoch: 9 | Iter:  100 | Time: 00:02:14 | Train Loss: 0.0026 | Average Loss: 0.2280
# Epoch: 9 | Iter:  120 | Time: 00:02:15 | Train Loss: 0.0972 | Average Loss: 0.2264
# Epoch: 9 | Iter:  140 | Time: 00:02:15 | Train Loss: 0.0356 | Average Loss: 0.2251
# Epoch: 9 | Iter:  160 | Time: 00:02:16 | Train Loss: 0.0092 | Average Loss: 0.2240
# Epoch: 9 | Iter:  180 | Time: 00:02:17 | Train Loss: 0.1454 | Average Loss: 0.2230
# Epoch: 9 | Iter:  200 | Time: 00:02:18 | Train Loss: 0.0478 | Average Loss: 0.2230
# Epoch: 9 | Iter:  220 | Time: 00:02:19 | Train Loss: 0.0332 | Average Loss: 0.2228
# Epoch: 9 | Iter:  240 | Time: 00:02:20 | Train Loss: 0.0606 | Average Loss: 0.2220
# Epoch: 9 | Iter:  260 | Time: 00:02:21 | Train Loss: 0.0051 | Average Loss: 0.2211
# Epoch: 9 | Iter:  280 | Time: 00:02:22 | Train Loss: 0.0258 | Average Loss: 0.2200
# Accuracy: 0.852500 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:02:24 | Train Loss: 0.0181 | Average Loss: 0.2185
# Epoch:10 | Iter:   20 | Time: 00:02:25 | Train Loss: 0.1236 | Average Loss: 0.2170
# Epoch:10 | Iter:   40 | Time: 00:02:26 | Train Loss: 0.0430 | Average Loss: 0.2158
# Epoch:10 | Iter:   60 | Time: 00:02:27 | Train Loss: 0.0019 | Average Loss: 0.2148
# Epoch:10 | Iter:   80 | Time: 00:02:28 | Train Loss: 0.0715 | Average Loss: 0.2137
# Epoch:10 | Iter:  100 | Time: 00:02:29 | Train Loss: 0.0538 | Average Loss: 0.2131
# Epoch:10 | Iter:  120 | Time: 00:02:30 | Train Loss: 0.0004 | Average Loss: 0.2123
# Epoch:10 | Iter:  140 | Time: 00:02:30 | Train Loss: 0.4683 | Average Loss: 0.2114
# Epoch:10 | Iter:  160 | Time: 00:02:31 | Train Loss: 0.5532 | Average Loss: 0.2106
# Epoch:10 | Iter:  180 | Time: 00:02:32 | Train Loss: 0.0671 | Average Loss: 0.2095
# Epoch:10 | Iter:  200 | Time: 00:02:33 | Train Loss: 0.0538 | Average Loss: 0.2087
# Epoch:10 | Iter:  220 | Time: 00:02:34 | Train Loss: 0.1944 | Average Loss: 0.2076
# Epoch:10 | Iter:  240 | Time: 00:02:35 | Train Loss: 0.0031 | Average Loss: 0.2064
# Epoch:10 | Iter:  260 | Time: 00:02:36 | Train Loss: 0.0089 | Average Loss: 0.2052
# Epoch:10 | Iter:  280 | Time: 00:02:37 | Train Loss: 0.1635 | Average Loss: 0.2041
# Accuracy: 0.840000 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:02:39 | Train Loss: 0.0007 | Average Loss: 0.2033
# Epoch:11 | Iter:   20 | Time: 00:02:40 | Train Loss: 0.0082 | Average Loss: 0.2024
# Epoch:11 | Iter:   40 | Time: 00:02:41 | Train Loss: 0.0151 | Average Loss: 0.2013
# Epoch:11 | Iter:   60 | Time: 00:02:42 | Train Loss: 0.0001 | Average Loss: 0.2005
# Epoch:11 | Iter:   80 | Time: 00:02:43 | Train Loss: 0.0030 | Average Loss: 0.1995
# Epoch:11 | Iter:  100 | Time: 00:02:44 | Train Loss: 0.0145 | Average Loss: 0.1985
# Epoch:11 | Iter:  120 | Time: 00:02:45 | Train Loss: 0.0174 | Average Loss: 0.1980
# Epoch:11 | Iter:  140 | Time: 00:02:46 | Train Loss: 0.0075 | Average Loss: 0.1971
# Epoch:11 | Iter:  160 | Time: 00:02:46 | Train Loss: 0.0019 | Average Loss: 0.1961
# Epoch:11 | Iter:  180 | Time: 00:02:47 | Train Loss: 0.0086 | Average Loss: 0.1958
# Epoch:11 | Iter:  200 | Time: 00:02:48 | Train Loss: 0.0033 | Average Loss: 0.1950
# Epoch:11 | Iter:  220 | Time: 00:02:49 | Train Loss: 0.1789 | Average Loss: 0.1942
# Epoch:11 | Iter:  240 | Time: 00:02:50 | Train Loss: 0.0091 | Average Loss: 0.1934
# Epoch:11 | Iter:  260 | Time: 00:02:51 | Train Loss: 0.0029 | Average Loss: 0.1925
# Epoch:11 | Iter:  280 | Time: 00:02:52 | Train Loss: 0.1411 | Average Loss: 0.1915
# Accuracy: 0.820000 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:02:54 | Train Loss: 0.0016 | Average Loss: 0.1906
# Epoch:12 | Iter:   20 | Time: 00:02:55 | Train Loss: 0.0054 | Average Loss: 0.1903
# Epoch:12 | Iter:   40 | Time: 00:02:56 | Train Loss: 0.1070 | Average Loss: 0.1898
# Epoch:12 | Iter:   60 | Time: 00:02:57 | Train Loss: 0.0001 | Average Loss: 0.1889
# Epoch:12 | Iter:   80 | Time: 00:02:58 | Train Loss: 0.0088 | Average Loss: 0.1880
# Epoch:12 | Iter:  100 | Time: 00:02:59 | Train Loss: 0.0263 | Average Loss: 0.1871
# Epoch:12 | Iter:  120 | Time: 00:03:00 | Train Loss: 0.0113 | Average Loss: 0.1863
# Epoch:12 | Iter:  140 | Time: 00:03:01 | Train Loss: 0.0008 | Average Loss: 0.1855
# Epoch:12 | Iter:  160 | Time: 00:03:02 | Train Loss: 0.0885 | Average Loss: 0.1848
# Epoch:12 | Iter:  180 | Time: 00:03:03 | Train Loss: 0.0075 | Average Loss: 0.1838
# Epoch:12 | Iter:  200 | Time: 00:03:03 | Train Loss: 0.1086 | Average Loss: 0.1829
# Epoch:12 | Iter:  220 | Time: 00:03:04 | Train Loss: 0.0062 | Average Loss: 0.1822
# Epoch:12 | Iter:  240 | Time: 00:03:05 | Train Loss: 0.0002 | Average Loss: 0.1812
# Epoch:12 | Iter:  260 | Time: 00:03:06 | Train Loss: 0.0000 | Average Loss: 0.1803
# Epoch:12 | Iter:  280 | Time: 00:03:07 | Train Loss: 0.0000 | Average Loss: 0.1795
# Accuracy: 0.822500 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:03:09 | Train Loss: 0.0207 | Average Loss: 0.1789
# Epoch:13 | Iter:   20 | Time: 00:03:10 | Train Loss: 0.1714 | Average Loss: 0.1788
# Epoch:13 | Iter:   40 | Time: 00:03:11 | Train Loss: 0.0078 | Average Loss: 0.1781
# Epoch:13 | Iter:   60 | Time: 00:03:12 | Train Loss: 0.3260 | Average Loss: 0.1775
# Epoch:13 | Iter:   80 | Time: 00:03:13 | Train Loss: 0.0346 | Average Loss: 0.1769
# Epoch:13 | Iter:  100 | Time: 00:03:14 | Train Loss: 0.3250 | Average Loss: 0.1763
# Epoch:13 | Iter:  120 | Time: 00:03:15 | Train Loss: 0.0037 | Average Loss: 0.1755
# Epoch:13 | Iter:  140 | Time: 00:03:16 | Train Loss: 0.0241 | Average Loss: 0.1749
# Epoch:13 | Iter:  160 | Time: 00:03:17 | Train Loss: 0.0205 | Average Loss: 0.1744
# Epoch:13 | Iter:  180 | Time: 00:03:18 | Train Loss: 0.0822 | Average Loss: 0.1738
# Epoch:13 | Iter:  200 | Time: 00:03:19 | Train Loss: 0.0807 | Average Loss: 0.1731
# Epoch:13 | Iter:  220 | Time: 00:03:20 | Train Loss: 0.0075 | Average Loss: 0.1728
# Epoch:13 | Iter:  240 | Time: 00:03:21 | Train Loss: 0.0155 | Average Loss: 0.1724
# Epoch:13 | Iter:  260 | Time: 00:03:21 | Train Loss: 0.0002 | Average Loss: 0.1717
# Epoch:13 | Iter:  280 | Time: 00:03:22 | Train Loss: 0.3549 | Average Loss: 0.1713
# Accuracy: 0.840000 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:03:24 | Train Loss: 0.0100 | Average Loss: 0.1709
# Epoch:14 | Iter:   20 | Time: 00:03:25 | Train Loss: 0.2981 | Average Loss: 0.1704
# Epoch:14 | Iter:   40 | Time: 00:03:26 | Train Loss: 0.0192 | Average Loss: 0.1698
# Epoch:14 | Iter:   60 | Time: 00:03:27 | Train Loss: 0.0000 | Average Loss: 0.1691
# Epoch:14 | Iter:   80 | Time: 00:03:28 | Train Loss: 0.0007 | Average Loss: 0.1688
# Epoch:14 | Iter:  100 | Time: 00:03:29 | Train Loss: 0.0205 | Average Loss: 0.1682
# Epoch:14 | Iter:  120 | Time: 00:03:30 | Train Loss: 0.0176 | Average Loss: 0.1679
# Epoch:14 | Iter:  140 | Time: 00:03:31 | Train Loss: 0.0026 | Average Loss: 0.1673
# Epoch:14 | Iter:  160 | Time: 00:03:32 | Train Loss: 0.0119 | Average Loss: 0.1666
# Epoch:14 | Iter:  180 | Time: 00:03:33 | Train Loss: 0.0218 | Average Loss: 0.1662
# Epoch:14 | Iter:  200 | Time: 00:03:34 | Train Loss: 0.0032 | Average Loss: 0.1656
# Epoch:14 | Iter:  220 | Time: 00:03:35 | Train Loss: 0.0005 | Average Loss: 0.1649
# Epoch:14 | Iter:  240 | Time: 00:03:36 | Train Loss: 0.0192 | Average Loss: 0.1642
# Epoch:14 | Iter:  260 | Time: 00:03:37 | Train Loss: 0.0046 | Average Loss: 0.1638
# Epoch:14 | Iter:  280 | Time: 00:03:38 | Train Loss: 0.0020 | Average Loss: 0.1633
# Accuracy: 0.825000 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:03:39 | Train Loss: 0.0003 | Average Loss: 0.1627
# Epoch:15 | Iter:   20 | Time: 00:03:40 | Train Loss: 0.0043 | Average Loss: 0.1620
# Epoch:15 | Iter:   40 | Time: 00:03:41 | Train Loss: 0.0050 | Average Loss: 0.1615
# Epoch:15 | Iter:   60 | Time: 00:03:42 | Train Loss: 0.0001 | Average Loss: 0.1611
# Epoch:15 | Iter:   80 | Time: 00:03:43 | Train Loss: 0.0027 | Average Loss: 0.1607
# Epoch:15 | Iter:  100 | Time: 00:03:44 | Train Loss: 0.1481 | Average Loss: 0.1602
# Epoch:15 | Iter:  120 | Time: 00:03:45 | Train Loss: 0.0018 | Average Loss: 0.1596
# Epoch:15 | Iter:  140 | Time: 00:03:46 | Train Loss: 0.0012 | Average Loss: 0.1589
# Epoch:15 | Iter:  160 | Time: 00:03:47 | Train Loss: 0.0026 | Average Loss: 0.1583
# Epoch:15 | Iter:  180 | Time: 00:03:48 | Train Loss: 0.0032 | Average Loss: 0.1578
# Epoch:15 | Iter:  200 | Time: 00:03:49 | Train Loss: 0.0363 | Average Loss: 0.1574
# Epoch:15 | Iter:  220 | Time: 00:03:50 | Train Loss: 0.0051 | Average Loss: 0.1570
# Epoch:15 | Iter:  240 | Time: 00:03:51 | Train Loss: 0.0593 | Average Loss: 0.1566
# Epoch:15 | Iter:  260 | Time: 00:03:52 | Train Loss: 0.1674 | Average Loss: 0.1561
# Epoch:15 | Iter:  280 | Time: 00:03:53 | Train Loss: 0.0940 | Average Loss: 0.1557
# Accuracy: 0.760000 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:03:54 | Train Loss: 0.0322 | Average Loss: 0.1554
# Epoch:16 | Iter:   20 | Time: 00:03:55 | Train Loss: 0.0053 | Average Loss: 0.1554
# Epoch:16 | Iter:   40 | Time: 00:03:56 | Train Loss: 0.0493 | Average Loss: 0.1551
# Epoch:16 | Iter:   60 | Time: 00:03:57 | Train Loss: 0.0005 | Average Loss: 0.1547
# Epoch:16 | Iter:   80 | Time: 00:03:58 | Train Loss: 0.0169 | Average Loss: 0.1541
# Epoch:16 | Iter:  100 | Time: 00:03:59 | Train Loss: 0.0203 | Average Loss: 0.1537
# Epoch:16 | Iter:  120 | Time: 00:04:00 | Train Loss: 0.0350 | Average Loss: 0.1532
# Epoch:16 | Iter:  140 | Time: 00:04:01 | Train Loss: 0.0160 | Average Loss: 0.1527
# Epoch:16 | Iter:  160 | Time: 00:04:02 | Train Loss: 0.0100 | Average Loss: 0.1522
# Epoch:16 | Iter:  180 | Time: 00:04:03 | Train Loss: 0.0321 | Average Loss: 0.1521
# Epoch:16 | Iter:  200 | Time: 00:04:04 | Train Loss: 0.2958 | Average Loss: 0.1519
# Epoch:16 | Iter:  220 | Time: 00:04:05 | Train Loss: 0.0129 | Average Loss: 0.1520
# Epoch:16 | Iter:  240 | Time: 00:04:06 | Train Loss: 0.0394 | Average Loss: 0.1515
# Epoch:16 | Iter:  260 | Time: 00:04:07 | Train Loss: 0.0058 | Average Loss: 0.1510
# Epoch:16 | Iter:  280 | Time: 00:04:08 | Train Loss: 0.0023 | Average Loss: 0.1507
# Accuracy: 0.832500 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:04:09 | Train Loss: 0.0048 | Average Loss: 0.1504
# Epoch:17 | Iter:   20 | Time: 00:04:10 | Train Loss: 0.0037 | Average Loss: 0.1502
# Epoch:17 | Iter:   40 | Time: 00:04:11 | Train Loss: 0.0037 | Average Loss: 0.1503
# Epoch:17 | Iter:   60 | Time: 00:04:12 | Train Loss: 0.0011 | Average Loss: 0.1499
# Epoch:17 | Iter:   80 | Time: 00:04:13 | Train Loss: 0.0060 | Average Loss: 0.1495
# Epoch:17 | Iter:  100 | Time: 00:04:14 | Train Loss: 0.0001 | Average Loss: 0.1490
# Epoch:17 | Iter:  120 | Time: 00:04:15 | Train Loss: 0.1169 | Average Loss: 0.1484
# Epoch:17 | Iter:  140 | Time: 00:04:16 | Train Loss: 0.0024 | Average Loss: 0.1479
# Epoch:17 | Iter:  160 | Time: 00:04:17 | Train Loss: 0.0001 | Average Loss: 0.1475
# Epoch:17 | Iter:  180 | Time: 00:04:18 | Train Loss: 0.0502 | Average Loss: 0.1470
# Epoch:17 | Iter:  200 | Time: 00:04:19 | Train Loss: 0.0017 | Average Loss: 0.1465
# Epoch:17 | Iter:  220 | Time: 00:04:20 | Train Loss: 0.0019 | Average Loss: 0.1460
# Epoch:17 | Iter:  240 | Time: 00:04:21 | Train Loss: 0.1029 | Average Loss: 0.1455
# Epoch:17 | Iter:  260 | Time: 00:04:22 | Train Loss: 0.0000 | Average Loss: 0.1453
# Epoch:17 | Iter:  280 | Time: 00:04:23 | Train Loss: 0.0185 | Average Loss: 0.1448
# Accuracy: 0.790000 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:04:24 | Train Loss: 0.0601 | Average Loss: 0.1445
# Epoch:18 | Iter:   20 | Time: 00:04:25 | Train Loss: 0.0447 | Average Loss: 0.1441
# Epoch:18 | Iter:   40 | Time: 00:04:26 | Train Loss: 0.0008 | Average Loss: 0.1436
# Epoch:18 | Iter:   60 | Time: 00:04:27 | Train Loss: 0.1379 | Average Loss: 0.1431
# Epoch:18 | Iter:   80 | Time: 00:04:28 | Train Loss: 0.0000 | Average Loss: 0.1426
# Epoch:18 | Iter:  100 | Time: 00:04:29 | Train Loss: 0.0002 | Average Loss: 0.1421
# Epoch:18 | Iter:  120 | Time: 00:04:30 | Train Loss: 0.0433 | Average Loss: 0.1418
# Epoch:18 | Iter:  140 | Time: 00:04:31 | Train Loss: 0.0002 | Average Loss: 0.1413
# Epoch:18 | Iter:  160 | Time: 00:04:32 | Train Loss: 0.0243 | Average Loss: 0.1409
# Epoch:18 | Iter:  180 | Time: 00:04:33 | Train Loss: 0.0000 | Average Loss: 0.1404
# Epoch:18 | Iter:  200 | Time: 00:04:34 | Train Loss: 0.0919 | Average Loss: 0.1400
# Epoch:18 | Iter:  220 | Time: 00:04:35 | Train Loss: 0.0010 | Average Loss: 0.1396
# Epoch:18 | Iter:  240 | Time: 00:04:36 | Train Loss: 0.0003 | Average Loss: 0.1391
# Epoch:18 | Iter:  260 | Time: 00:04:37 | Train Loss: 0.0004 | Average Loss: 0.1388
# Epoch:18 | Iter:  280 | Time: 00:04:38 | Train Loss: 0.0007 | Average Loss: 0.1383
# Accuracy: 0.807500 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:04:39 | Train Loss: 0.0397 | Average Loss: 0.1378
# Epoch:19 | Iter:   20 | Time: 00:04:40 | Train Loss: 0.0001 | Average Loss: 0.1374
# Epoch:19 | Iter:   40 | Time: 00:04:41 | Train Loss: 0.1172 | Average Loss: 0.1371
# Epoch:19 | Iter:   60 | Time: 00:04:42 | Train Loss: 0.0139 | Average Loss: 0.1368
# Epoch:19 | Iter:   80 | Time: 00:04:43 | Train Loss: 0.2341 | Average Loss: 0.1365
# Epoch:19 | Iter:  100 | Time: 00:04:44 | Train Loss: 0.1739 | Average Loss: 0.1363
# Epoch:19 | Iter:  120 | Time: 00:04:45 | Train Loss: 0.1123 | Average Loss: 0.1360
# Epoch:19 | Iter:  140 | Time: 00:04:46 | Train Loss: 0.0006 | Average Loss: 0.1356
# Epoch:19 | Iter:  160 | Time: 00:04:47 | Train Loss: 0.0003 | Average Loss: 0.1353
# Epoch:19 | Iter:  180 | Time: 00:04:48 | Train Loss: 0.1217 | Average Loss: 0.1350
# Epoch:19 | Iter:  200 | Time: 00:04:49 | Train Loss: 0.1965 | Average Loss: 0.1346
# Epoch:19 | Iter:  220 | Time: 00:04:50 | Train Loss: 0.1670 | Average Loss: 0.1342
# Epoch:19 | Iter:  240 | Time: 00:04:51 | Train Loss: 0.0909 | Average Loss: 0.1337
# Epoch:19 | Iter:  260 | Time: 00:04:52 | Train Loss: 0.0002 | Average Loss: 0.1335
# Epoch:19 | Iter:  280 | Time: 00:04:53 | Train Loss: 0.0025 | Average Loss: 0.1331
# Accuracy: 0.815000 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:04:54 | Train Loss: 0.0012 | Average Loss: 0.1328
# Epoch:20 | Iter:   20 | Time: 00:04:55 | Train Loss: 0.0078 | Average Loss: 0.1325
# Epoch:20 | Iter:   40 | Time: 00:04:56 | Train Loss: 0.0011 | Average Loss: 0.1321
# Epoch:20 | Iter:   60 | Time: 00:04:57 | Train Loss: 0.0069 | Average Loss: 0.1316
# Epoch:20 | Iter:   80 | Time: 00:04:58 | Train Loss: 0.0012 | Average Loss: 0.1312
# Epoch:20 | Iter:  100 | Time: 00:04:59 | Train Loss: 0.0024 | Average Loss: 0.1307
# Epoch:20 | Iter:  120 | Time: 00:05:00 | Train Loss: 0.0000 | Average Loss: 0.1303
# Epoch:20 | Iter:  140 | Time: 00:05:01 | Train Loss: 0.0008 | Average Loss: 0.1299
# Epoch:20 | Iter:  160 | Time: 00:05:02 | Train Loss: 0.0002 | Average Loss: 0.1296
# Epoch:20 | Iter:  180 | Time: 00:05:03 | Train Loss: 0.0000 | Average Loss: 0.1292
# Epoch:20 | Iter:  200 | Time: 00:05:04 | Train Loss: 0.0003 | Average Loss: 0.1289
# Epoch:20 | Iter:  220 | Time: 00:05:05 | Train Loss: 0.1911 | Average Loss: 0.1287
# Epoch:20 | Iter:  240 | Time: 00:05:06 | Train Loss: 0.0232 | Average Loss: 0.1283
# Epoch:20 | Iter:  260 | Time: 00:05:07 | Train Loss: 0.0820 | Average Loss: 0.1280
# Epoch:20 | Iter:  280 | Time: 00:05:08 | Train Loss: 0.0001 | Average Loss: 0.1279
# Accuracy: 0.760000 | Time: 00:00:00
# Epoch:21 | Iter:    0 | Time: 00:05:09 | Train Loss: 0.0183 | Average Loss: 0.1278
# Epoch:21 | Iter:   20 | Time: 00:05:10 | Train Loss: 0.4075 | Average Loss: 0.1281
# Epoch:21 | Iter:   40 | Time: 00:05:11 | Train Loss: 0.0981 | Average Loss: 0.1281
# Epoch:21 | Iter:   60 | Time: 00:05:12 | Train Loss: 0.0917 | Average Loss: 0.1280
# Epoch:21 | Iter:   80 | Time: 00:05:13 | Train Loss: 0.0946 | Average Loss: 0.1279
# Epoch:21 | Iter:  100 | Time: 00:05:14 | Train Loss: 0.2805 | Average Loss: 0.1279
# Epoch:21 | Iter:  120 | Time: 00:05:15 | Train Loss: 0.0131 | Average Loss: 0.1279
# Epoch:21 | Iter:  140 | Time: 00:05:16 | Train Loss: 0.0008 | Average Loss: 0.1277
# Epoch:21 | Iter:  160 | Time: 00:05:17 | Train Loss: 0.0474 | Average Loss: 0.1274
# Epoch:21 | Iter:  180 | Time: 00:05:18 | Train Loss: 0.0040 | Average Loss: 0.1270
# Epoch:21 | Iter:  200 | Time: 00:05:19 | Train Loss: 0.0546 | Average Loss: 0.1268
# Epoch:21 | Iter:  220 | Time: 00:05:20 | Train Loss: 0.0058 | Average Loss: 0.1266
# Epoch:21 | Iter:  240 | Time: 00:05:21 | Train Loss: 0.0015 | Average Loss: 0.1267
# Epoch:21 | Iter:  260 | Time: 00:05:22 | Train Loss: 0.0007 | Average Loss: 0.1265
# Epoch:21 | Iter:  280 | Time: 00:05:23 | Train Loss: 0.0036 | Average Loss: 0.1264
# Accuracy: 0.825000 | Time: 00:00:00
# Epoch:22 | Iter:    0 | Time: 00:05:24 | Train Loss: 0.2885 | Average Loss: 0.1264
# Epoch:22 | Iter:   20 | Time: 00:05:25 | Train Loss: 0.0025 | Average Loss: 0.1261
# Epoch:22 | Iter:   40 | Time: 00:05:26 | Train Loss: 0.0004 | Average Loss: 0.1259
# Epoch:22 | Iter:   60 | Time: 00:05:27 | Train Loss: 0.0018 | Average Loss: 0.1256
# Epoch:22 | Iter:   80 | Time: 00:05:28 | Train Loss: 0.0002 | Average Loss: 0.1254
# Epoch:22 | Iter:  100 | Time: 00:05:29 | Train Loss: 0.0031 | Average Loss: 0.1252
# Epoch:22 | Iter:  120 | Time: 00:05:30 | Train Loss: 0.3424 | Average Loss: 0.1249
# Epoch:22 | Iter:  140 | Time: 00:05:31 | Train Loss: 0.0015 | Average Loss: 0.1246
# Epoch:22 | Iter:  160 | Time: 00:05:32 | Train Loss: 0.0070 | Average Loss: 0.1243
# Epoch:22 | Iter:  180 | Time: 00:05:33 | Train Loss: 0.0400 | Average Loss: 0.1241
# Epoch:22 | Iter:  200 | Time: 00:05:34 | Train Loss: 0.0482 | Average Loss: 0.1237
# Epoch:22 | Iter:  220 | Time: 00:05:35 | Train Loss: 0.0019 | Average Loss: 0.1233
# Epoch:22 | Iter:  240 | Time: 00:05:36 | Train Loss: 0.0010 | Average Loss: 0.1230
# Epoch:22 | Iter:  260 | Time: 00:05:37 | Train Loss: 0.0000 | Average Loss: 0.1226
# Epoch:22 | Iter:  280 | Time: 00:05:38 | Train Loss: 0.0000 | Average Loss: 0.1225
# Accuracy: 0.812500 | Time: 00:00:00
# Epoch:23 | Iter:    0 | Time: 00:05:39 | Train Loss: 0.0000 | Average Loss: 0.1223
# Epoch:23 | Iter:   20 | Time: 00:05:40 | Train Loss: 0.1369 | Average Loss: 0.1220
# Epoch:23 | Iter:   40 | Time: 00:05:41 | Train Loss: 0.0137 | Average Loss: 0.1218
# Epoch:23 | Iter:   60 | Time: 00:05:42 | Train Loss: 0.1995 | Average Loss: 0.1216
# Epoch:23 | Iter:   80 | Time: 00:05:43 | Train Loss: 0.0009 | Average Loss: 0.1213
# Epoch:23 | Iter:  100 | Time: 00:05:44 | Train Loss: 0.0017 | Average Loss: 0.1210
# Epoch:23 | Iter:  120 | Time: 00:05:45 | Train Loss: 0.0240 | Average Loss: 0.1209
# Epoch:23 | Iter:  140 | Time: 00:05:46 | Train Loss: 0.0003 | Average Loss: 0.1208
# Epoch:23 | Iter:  160 | Time: 00:05:47 | Train Loss: 0.0011 | Average Loss: 0.1205
# Epoch:23 | Iter:  180 | Time: 00:05:48 | Train Loss: 0.0016 | Average Loss: 0.1203
# Epoch:23 | Iter:  200 | Time: 00:05:49 | Train Loss: 0.2339 | Average Loss: 0.1201
# Epoch:23 | Iter:  220 | Time: 00:05:50 | Train Loss: 0.0002 | Average Loss: 0.1199
# Epoch:23 | Iter:  240 | Time: 00:05:51 | Train Loss: 0.0059 | Average Loss: 0.1197
# Epoch:23 | Iter:  260 | Time: 00:05:52 | Train Loss: 0.0002 | Average Loss: 0.1196
# Epoch:23 | Iter:  280 | Time: 00:05:53 | Train Loss: 0.0329 | Average Loss: 0.1195
# Accuracy: 0.825000 | Time: 00:00:00
# Epoch:24 | Iter:    0 | Time: 00:05:54 | Train Loss: 0.0005 | Average Loss: 0.1193
# Epoch:24 | Iter:   20 | Time: 00:05:55 | Train Loss: 0.0046 | Average Loss: 0.1190
# Epoch:24 | Iter:   40 | Time: 00:05:56 | Train Loss: 0.0029 | Average Loss: 0.1187
# Epoch:24 | Iter:   60 | Time: 00:05:57 | Train Loss: 0.2643 | Average Loss: 0.1185
# Epoch:24 | Iter:   80 | Time: 00:05:58 | Train Loss: 0.0001 | Average Loss: 0.1183
# Epoch:24 | Iter:  100 | Time: 00:05:59 | Train Loss: 0.0073 | Average Loss: 0.1181
# Epoch:24 | Iter:  120 | Time: 00:06:00 | Train Loss: 0.0000 | Average Loss: 0.1179
# Epoch:24 | Iter:  140 | Time: 00:06:01 | Train Loss: 0.0107 | Average Loss: 0.1177
# Epoch:24 | Iter:  160 | Time: 00:06:02 | Train Loss: 0.0088 | Average Loss: 0.1175
# Epoch:24 | Iter:  180 | Time: 00:06:03 | Train Loss: 0.0005 | Average Loss: 0.1172
# Epoch:24 | Iter:  200 | Time: 00:06:04 | Train Loss: 0.0179 | Average Loss: 0.1170
# Epoch:24 | Iter:  220 | Time: 00:06:05 | Train Loss: 0.0404 | Average Loss: 0.1168
# Epoch:24 | Iter:  240 | Time: 00:06:06 | Train Loss: 0.0093 | Average Loss: 0.1166
# Epoch:24 | Iter:  260 | Time: 00:06:07 | Train Loss: 0.0000 | Average Loss: 0.1164
# Epoch:24 | Iter:  280 | Time: 00:06:08 | Train Loss: 0.0099 | Average Loss: 0.1162
# Accuracy: 0.817500 | Time: 00:00:00
# Epoch:25 | Iter:    0 | Time: 00:06:09 | Train Loss: 0.0010 | Average Loss: 0.1160
# Epoch:25 | Iter:   20 | Time: 00:06:10 | Train Loss: 0.0000 | Average Loss: 0.1158
# Epoch:25 | Iter:   40 | Time: 00:06:11 | Train Loss: 0.0261 | Average Loss: 0.1155
# Epoch:25 | Iter:   60 | Time: 00:06:12 | Train Loss: 0.0042 | Average Loss: 0.1152
# Epoch:25 | Iter:   80 | Time: 00:06:13 | Train Loss: 0.0338 | Average Loss: 0.1150
# Epoch:25 | Iter:  100 | Time: 00:06:14 | Train Loss: 0.0040 | Average Loss: 0.1147
# Epoch:25 | Iter:  120 | Time: 00:06:15 | Train Loss: 0.0035 | Average Loss: 0.1145
# Epoch:25 | Iter:  140 | Time: 00:06:16 | Train Loss: 0.0007 | Average Loss: 0.1143
# Epoch:25 | Iter:  160 | Time: 00:06:17 | Train Loss: 0.0094 | Average Loss: 0.1141
# Epoch:25 | Iter:  180 | Time: 00:06:18 | Train Loss: 0.0921 | Average Loss: 0.1139
# Epoch:25 | Iter:  200 | Time: 00:06:19 | Train Loss: 0.0505 | Average Loss: 0.1138
# Epoch:25 | Iter:  220 | Time: 00:06:20 | Train Loss: 0.0004 | Average Loss: 0.1136
# Epoch:25 | Iter:  240 | Time: 00:06:21 | Train Loss: 0.0000 | Average Loss: 0.1138
# Epoch:25 | Iter:  260 | Time: 00:06:22 | Train Loss: 0.0006 | Average Loss: 0.1138
# Epoch:25 | Iter:  280 | Time: 00:06:23 | Train Loss: 0.0474 | Average Loss: 0.1138
# Accuracy: 0.805000 | Time: 00:00:00
# Epoch:26 | Iter:    0 | Time: 00:06:24 | Train Loss: 0.0685 | Average Loss: 0.1137
# Epoch:26 | Iter:   20 | Time: 00:06:25 | Train Loss: 0.0156 | Average Loss: 0.1136
# Epoch:26 | Iter:   40 | Time: 00:06:26 | Train Loss: 0.0004 | Average Loss: 0.1134
# Epoch:26 | Iter:   60 | Time: 00:06:27 | Train Loss: 0.0030 | Average Loss: 0.1132
# Epoch:26 | Iter:   80 | Time: 00:06:28 | Train Loss: 0.0000 | Average Loss: 0.1129
# Epoch:26 | Iter:  100 | Time: 00:06:29 | Train Loss: 0.0026 | Average Loss: 0.1127
# Epoch:26 | Iter:  120 | Time: 00:06:30 | Train Loss: 0.0001 | Average Loss: 0.1124
# Epoch:26 | Iter:  140 | Time: 00:06:31 | Train Loss: 0.0000 | Average Loss: 0.1122
# Epoch:26 | Iter:  160 | Time: 00:06:32 | Train Loss: 0.0003 | Average Loss: 0.1120
# Epoch:26 | Iter:  180 | Time: 00:06:33 | Train Loss: 0.0127 | Average Loss: 0.1119
# Epoch:26 | Iter:  200 | Time: 00:06:34 | Train Loss: 0.0061 | Average Loss: 0.1117
# Epoch:26 | Iter:  220 | Time: 00:06:35 | Train Loss: 0.0008 | Average Loss: 0.1115
# Epoch:26 | Iter:  240 | Time: 00:06:36 | Train Loss: 0.0645 | Average Loss: 0.1114
# Epoch:26 | Iter:  260 | Time: 00:06:37 | Train Loss: 0.1105 | Average Loss: 0.1114
# Epoch:26 | Iter:  280 | Time: 00:06:38 | Train Loss: 0.0116 | Average Loss: 0.1113
# Accuracy: 0.772500 | Time: 00:00:00
# Epoch:27 | Iter:    0 | Time: 00:06:39 | Train Loss: 0.0443 | Average Loss: 0.1111
# Epoch:27 | Iter:   20 | Time: 00:06:40 | Train Loss: 0.0074 | Average Loss: 0.1110
# Epoch:27 | Iter:   40 | Time: 00:06:41 | Train Loss: 0.0011 | Average Loss: 0.1109
# Epoch:27 | Iter:   60 | Time: 00:06:42 | Train Loss: 0.0000 | Average Loss: 0.1108
# Epoch:27 | Iter:   80 | Time: 00:06:43 | Train Loss: 0.0475 | Average Loss: 0.1107
# Epoch:27 | Iter:  100 | Time: 00:06:44 | Train Loss: 0.3848 | Average Loss: 0.1106
# Epoch:27 | Iter:  120 | Time: 00:06:45 | Train Loss: 0.0505 | Average Loss: 0.1104
# Epoch:27 | Iter:  140 | Time: 00:06:46 | Train Loss: 0.0010 | Average Loss: 0.1102
# Epoch:27 | Iter:  160 | Time: 00:06:47 | Train Loss: 0.0021 | Average Loss: 0.1100
# Epoch:27 | Iter:  180 | Time: 00:06:48 | Train Loss: 0.0001 | Average Loss: 0.1099
# Epoch:27 | Iter:  200 | Time: 00:06:49 | Train Loss: 0.0016 | Average Loss: 0.1096
# Epoch:27 | Iter:  220 | Time: 00:06:50 | Train Loss: 0.0004 | Average Loss: 0.1094
# Epoch:27 | Iter:  240 | Time: 00:06:51 | Train Loss: 0.0001 | Average Loss: 0.1092
# Epoch:27 | Iter:  260 | Time: 00:06:52 | Train Loss: 0.0001 | Average Loss: 0.1090
# Epoch:27 | Iter:  280 | Time: 00:06:53 | Train Loss: 0.0004 | Average Loss: 0.1088
# Accuracy: 0.842500 | Time: 00:00:00
# Epoch:28 | Iter:    0 | Time: 00:06:54 | Train Loss: 0.0003 | Average Loss: 0.1085
# Epoch:28 | Iter:   20 | Time: 00:06:55 | Train Loss: 0.0138 | Average Loss: 0.1083
# Epoch:28 | Iter:   40 | Time: 00:06:56 | Train Loss: 0.0053 | Average Loss: 0.1081
# Epoch:28 | Iter:   60 | Time: 00:06:57 | Train Loss: 0.0000 | Average Loss: 0.1078
# Epoch:28 | Iter:   80 | Time: 00:06:58 | Train Loss: 0.0018 | Average Loss: 0.1075
# Epoch:28 | Iter:  100 | Time: 00:06:59 | Train Loss: 0.0001 | Average Loss: 0.1073
# Epoch:28 | Iter:  120 | Time: 00:07:00 | Train Loss: 0.0000 | Average Loss: 0.1070
# Epoch:28 | Iter:  140 | Time: 00:07:01 | Train Loss: 0.0003 | Average Loss: 0.1068
# Epoch:28 | Iter:  160 | Time: 00:07:02 | Train Loss: 0.0004 | Average Loss: 0.1066
# Epoch:28 | Iter:  180 | Time: 00:07:03 | Train Loss: 0.0002 | Average Loss: 0.1064
# Epoch:28 | Iter:  200 | Time: 00:07:04 | Train Loss: 0.0000 | Average Loss: 0.1062
# Epoch:28 | Iter:  220 | Time: 00:07:05 | Train Loss: 0.0000 | Average Loss: 0.1059
# Epoch:28 | Iter:  240 | Time: 00:07:06 | Train Loss: 0.0007 | Average Loss: 0.1057
# Epoch:28 | Iter:  260 | Time: 00:07:07 | Train Loss: 0.0074 | Average Loss: 0.1055
# Epoch:28 | Iter:  280 | Time: 00:07:08 | Train Loss: 0.1603 | Average Loss: 0.1055
# Accuracy: 0.797500 | Time: 00:00:00
# Epoch:29 | Iter:    0 | Time: 00:07:09 | Train Loss: 0.0000 | Average Loss: 0.1057
# Epoch:29 | Iter:   20 | Time: 00:07:10 | Train Loss: 0.0234 | Average Loss: 0.1056
# Epoch:29 | Iter:   40 | Time: 00:07:11 | Train Loss: 0.0058 | Average Loss: 0.1055
# Epoch:29 | Iter:   60 | Time: 00:07:12 | Train Loss: 0.0002 | Average Loss: 0.1053
# Epoch:29 | Iter:   80 | Time: 00:07:13 | Train Loss: 0.0003 | Average Loss: 0.1051
# Epoch:29 | Iter:  100 | Time: 00:07:14 | Train Loss: 0.0006 | Average Loss: 0.1049
# Epoch:29 | Iter:  120 | Time: 00:07:15 | Train Loss: 0.0004 | Average Loss: 0.1048
# Epoch:29 | Iter:  140 | Time: 00:07:16 | Train Loss: 0.0009 | Average Loss: 0.1046
# Epoch:29 | Iter:  160 | Time: 00:07:17 | Train Loss: 0.5533 | Average Loss: 0.1046
# Epoch:29 | Iter:  180 | Time: 00:07:18 | Train Loss: 0.0003 | Average Loss: 0.1044
# Epoch:29 | Iter:  200 | Time: 00:07:19 | Train Loss: 0.0069 | Average Loss: 0.1043
# Epoch:29 | Iter:  220 | Time: 00:07:20 | Train Loss: 0.0146 | Average Loss: 0.1042
# Epoch:29 | Iter:  240 | Time: 00:07:21 | Train Loss: 0.0301 | Average Loss: 0.1041
# Epoch:29 | Iter:  260 | Time: 00:07:22 | Train Loss: 0.0018 | Average Loss: 0.1039
# Epoch:29 | Iter:  280 | Time: 00:07:23 | Train Loss: 0.0001 | Average Loss: 0.1038
# Accuracy: 0.795000 | Time: 00:00:00
# Epoch:30 | Iter:    0 | Time: 00:07:24 | Train Loss: 0.0022 | Average Loss: 0.1037
# Epoch:30 | Iter:   20 | Time: 00:07:25 | Train Loss: 0.0005 | Average Loss: 0.1035
# Epoch:30 | Iter:   40 | Time: 00:07:26 | Train Loss: 0.0000 | Average Loss: 0.1033
# Epoch:30 | Iter:   60 | Time: 00:07:27 | Train Loss: 0.0000 | Average Loss: 0.1031
# Epoch:30 | Iter:   80 | Time: 00:07:28 | Train Loss: 0.0149 | Average Loss: 0.1029
# Epoch:30 | Iter:  100 | Time: 00:07:29 | Train Loss: 0.0000 | Average Loss: 0.1027
# Epoch:30 | Iter:  120 | Time: 00:07:30 | Train Loss: 0.0008 | Average Loss: 0.1024
# Epoch:30 | Iter:  140 | Time: 00:07:31 | Train Loss: 0.0002 | Average Loss: 0.1022
# Epoch:30 | Iter:  160 | Time: 00:07:32 | Train Loss: 0.0000 | Average Loss: 0.1020
# Epoch:30 | Iter:  180 | Time: 00:07:33 | Train Loss: 0.0013 | Average Loss: 0.1018
# Epoch:30 | Iter:  200 | Time: 00:07:34 | Train Loss: 0.1866 | Average Loss: 0.1017
# Epoch:30 | Iter:  220 | Time: 00:07:35 | Train Loss: 0.0202 | Average Loss: 0.1016
# Epoch:30 | Iter:  240 | Time: 00:07:36 | Train Loss: 0.2451 | Average Loss: 0.1015
# Epoch:30 | Iter:  260 | Time: 00:07:37 | Train Loss: 0.0000 | Average Loss: 0.1014
# Epoch:30 | Iter:  280 | Time: 00:07:38 | Train Loss: 0.0011 | Average Loss: 0.1011
# Accuracy: 0.825000 | Time: 00:00:00
# max accuracy tensor(0.8525, device='cuda:0')

# %% [markdown]
# **Answer**:
#
# (1) which layers of AlexNet have been replaced:
#  The last layer of classification layer is replaced with fully connected layer of size 1024.
#
#
#
# (2) the architecture of the new layers added including activation methods (same as problem 1)
#
# Data augmentation: Mirroring Images
#
# Data normalization: Zero centered mean
#
# Features Layers : Default feature layers of CNN
#
# Classifier Layer 1: Replaced last layer of size 1000 with layer of size 1024
#
# Classifier Layer 2: FC layer of size 16 for classification
#
# ...
#
# (3) the final accuracy on test set
#
# Accuracy on test set: 0.8525

# %% [markdown]
# ### Problem 2.2
# **Strategy B**: One could use those 1000 activations as a feature in place of a hand crafted feature such as a bag-of-features representation. You would train a classifier (typically a linear SVM) in that 1000 dimensional feature space. However, those activations are clearly very object specific and may not generalize well to new recognition tasks. It is generally better to use the activations in slightly earlier layers of the network, e.g. the 4096 activations in the last 2nd fully-connected layer. You can often get away with sub-sampling those 4096 activations considerably, e.g. taking only the first 1000 activations.
#
# (25 points) Implement Strategy B where you use the activations of the pre-trained **AlexNet** as features to train **one-vs-all SVMs** for your scene classification task. Report the final accuracy on test set. You should be able to achieve accuracy of **0.80** approximately. The minimum accuracy required for this section is **0.70**.

# %%
model = models.alexnet(pretrained=True)
model.classifier = nn.Sequential(*list(model.classifier.children())[:-1])

# %%
class Adi_Net(nn.Module):
  def __init__(self):
    super(Adi_Net,self).__init__()  
          
    self.features = torch.nn.Sequential(
      model,
    )
    
  def forward(self, x):
    x = self.features(x) 
    # print(x.size()) 
    x = torch.flatten(x, 1)
    return x

# %%
#--------------------------------------------------
#       Get Features from AlexNet
#--------------------------------------------------

def get_features(net, dataloader):
  image_feats = []
  image_labels = []

  with torch.no_grad():
    device = 'gpu' if next(net.parameters()).is_cuda else 'cpu'
    net.eval()

    
    for iter, (x, y) in enumerate(dataloader):
          count += x.shape[0]
          batch_x = Variable(x).float()
          batch_y = Variable(y).long()
          if device == 'gpu':
            batch_x = batch_x.cuda()
            batch_y = batch_y.cuda()
          outputs = net(batch_x)
          image_feats.append(outputs)
          image_labels.append(batch_y)
  return image_feats, image_labels

net = Adi_Net()
device_option = {}
device_option['device'] = 'gpu'
train_feat, train_label = get_features(net, trainloader_large)
test_feat, test_label = get_features(net, testloader_large)

# %%
train_feat = torch.cat(train_feat)
train_label = torch.cat(train_label)
test_feat = torch.cat(test_feat)
test_label = torch.cat(test_label)

# %%
train_feat = train_feat[:,:1000]
test_feat = test_feat[:,:1000]

print(train_feat.size())
print(train_label.size())
print(test_feat.size())
print(test_label.size())
# Out:
# torch.Size([4800, 1000])
# torch.Size([4800])
# torch.Size([400, 1000])
# torch.Size([400])

# %%
#--------------------------------------------------
#       Train and Evaluate SVM
#--------------------------------------------------
from sklearn import svm
from sklearn.preprocessing import StandardScaler

clf = svm.SVC(C=1, max_iter=5000)
clf.fit(train_feat, train_label)
predict = clf.predict(test_feat)

# %%
predict = torch.Tensor(predict)
accuracy = sum(predict == test_label) / test_label.size()[0]
print(accuracy)
# Out:
# tensor(0.8300)

# %% [markdown]
# **Answer**:
#
# Accuracy on test set: 0.8300

# %% [markdown]
# ### Problem 2.3 (Bonus)
#
# (Bonus: 10 points) Bonus will be given to those who fine-tune the [ResNet network](https://pytorch.org/docs/stable/_modules/torchvision/models/resnet.html) [(paper)](https://arxiv.org/abs/1512.03385) and compare performance with AlexNet. Explain why ResNet performed better or worse. You are **required** to use **resnet50** model. You should be able to achieve accuracy of **0.99** approximately. The minimum accuracy required for this section is **0.85**.

# %%
#--------------------------------------------------
#       Fine-Tune Pretrained Network
#--------------------------------------------------
model = models.resnet50(pretrained=True)
# model.classifier[-1] = nn.Linear(in_features=4096, out_features=1024, bias=True)

class Tuned_Resnet50(nn.Module):
  def __init__(self):
    super(Tuned_Resnet50,self).__init__()  
          
    self.features = torch.nn.Sequential(
      model,
    )
    
    self.classifier = nn.Sequential(
        nn.Linear(1000, 16)
    )
    
  def forward(self, x):
    x = self.features(x) 
    # print(x.size()) 
    x = torch.flatten(x, 1)
    x = self.classifier(x)
    return x

net = Tuned_Resnet50()
train_option = {}
train_option['lr'] = 0.0001
train_option['epoch'] = 30
train_option['device'] = 'gpu'
max_accuracy = trainModel(net, trainloader_large, train_option, testloader_large)
print("max accuracy", max_accuracy)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
# HBox(children=(FloatProgress(value=0.0, max=102502400.0), HTML(value='')))
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 3.4803 | Average Loss: 3.4803
# Epoch: 1 | Iter:   20 | Time: 00:00:04 | Train Loss: 1.1312 | Average Loss: 1.7622
# Epoch: 1 | Iter:   40 | Time: 00:00:07 | Train Loss: 0.6915 | Average Loss: 1.3049
# Epoch: 1 | Iter:   60 | Time: 00:00:11 | Train Loss: 0.5419 | Average Loss: 1.0810
# Epoch: 1 | Iter:   80 | Time: 00:00:15 | Train Loss: 0.2492 | Average Loss: 0.9520
# Epoch: 1 | Iter:  100 | Time: 00:00:19 | Train Loss: 0.6122 | Average Loss: 0.8622
# Epoch: 1 | Iter:  120 | Time: 00:00:22 | Train Loss: 0.8009 | Average Loss: 0.8149
# Epoch: 1 | Iter:  140 | Time: 00:00:26 | Train Loss: 0.3178 | Average Loss: 0.7714
# Epoch: 1 | Iter:  160 | Time: 00:00:30 | Train Loss: 0.3937 | Average Loss: 0.7486
# Epoch: 1 | Iter:  180 | Time: 00:00:34 | Train Loss: 0.2054 | Average Loss: 0.7243
# Epoch: 1 | Iter:  200 | Time: 00:00:38 | Train Loss: 0.4499 | Average Loss: 0.7059
# Epoch: 1 | Iter:  220 | Time: 00:00:42 | Train Loss: 0.3191 | Average Loss: 0.6849
# Epoch: 1 | Iter:  240 | Time: 00:00:45 | Train Loss: 0.3553 | Average Loss: 0.6724
# Epoch: 1 | Iter:  260 | Time: 00:00:49 | Train Loss: 0.3764 | Average Loss: 0.6535
# Epoch: 1 | Iter:  280 | Time: 00:00:53 | Train Loss: 0.3362 | Average Loss: 0.6368
# Accuracy: 0.892500 | Time: 00:00:01
# Epoch: 2 | Iter:    0 | Time: 00:00:58 | Train Loss: 0.1800 | Average Loss: 0.6163
# Epoch: 2 | Iter:   20 | Time: 00:01:02 | Train Loss: 0.1090 | Average Loss: 0.5914
# Epoch: 2 | Iter:   40 | Time: 00:01:06 | Train Loss: 0.1737 | Average Loss: 0.5735
# Epoch: 2 | Iter:   60 | Time: 00:01:10 | Train Loss: 0.1348 | Average Loss: 0.5477
# Epoch: 2 | Iter:   80 | Time: 00:01:14 | Train Loss: 0.0535 | Average Loss: 0.5232
# Epoch: 2 | Iter:  100 | Time: 00:01:17 | Train Loss: 0.2541 | Average Loss: 0.5008
# Epoch: 2 | Iter:  120 | Time: 00:01:21 | Train Loss: 0.0262 | Average Loss: 0.4809
# Epoch: 2 | Iter:  140 | Time: 00:01:25 | Train Loss: 0.0113 | Average Loss: 0.4620
# Epoch: 2 | Iter:  160 | Time: 00:01:29 | Train Loss: 0.1130 | Average Loss: 0.4459
# Epoch: 2 | Iter:  180 | Time: 00:01:32 | Train Loss: 0.0311 | Average Loss: 0.4299
# Epoch: 2 | Iter:  200 | Time: 00:01:36 | Train Loss: 0.2250 | Average Loss: 0.4167
# Epoch: 2 | Iter:  220 | Time: 00:01:40 | Train Loss: 0.0756 | Average Loss: 0.4040
# Epoch: 2 | Iter:  240 | Time: 00:01:44 | Train Loss: 0.1680 | Average Loss: 0.3944
# Epoch: 2 | Iter:  260 | Time: 00:01:48 | Train Loss: 0.0283 | Average Loss: 0.3829
# Epoch: 2 | Iter:  280 | Time: 00:01:51 | Train Loss: 0.1800 | Average Loss: 0.3734
# Accuracy: 0.882500 | Time: 00:00:01
# Epoch: 3 | Iter:    0 | Time: 00:01:57 | Train Loss: 0.0499 | Average Loss: 0.3638
# Epoch: 3 | Iter:   20 | Time: 00:02:00 | Train Loss: 0.0229 | Average Loss: 0.3557
# Epoch: 3 | Iter:   40 | Time: 00:02:04 | Train Loss: 0.4007 | Average Loss: 0.3491
# Epoch: 3 | Iter:   60 | Time: 00:02:08 | Train Loss: 0.0836 | Average Loss: 0.3407
# Epoch: 3 | Iter:   80 | Time: 00:02:12 | Train Loss: 0.0367 | Average Loss: 0.3319
# Epoch: 3 | Iter:  100 | Time: 00:02:16 | Train Loss: 0.0825 | Average Loss: 0.3239
# Epoch: 3 | Iter:  120 | Time: 00:02:19 | Train Loss: 0.0153 | Average Loss: 0.3164
# Epoch: 3 | Iter:  140 | Time: 00:02:23 | Train Loss: 0.0203 | Average Loss: 0.3088
# Epoch: 3 | Iter:  160 | Time: 00:02:27 | Train Loss: 0.0236 | Average Loss: 0.3019
# Epoch: 3 | Iter:  180 | Time: 00:02:31 | Train Loss: 0.0758 | Average Loss: 0.2955
# Epoch: 3 | Iter:  200 | Time: 00:02:35 | Train Loss: 0.3154 | Average Loss: 0.2910
# Epoch: 3 | Iter:  220 | Time: 00:02:38 | Train Loss: 0.0193 | Average Loss: 0.2857
# Epoch: 3 | Iter:  240 | Time: 00:02:42 | Train Loss: 0.1045 | Average Loss: 0.2817
# Epoch: 3 | Iter:  260 | Time: 00:02:46 | Train Loss: 0.0276 | Average Loss: 0.2777
# Epoch: 3 | Iter:  280 | Time: 00:02:50 | Train Loss: 0.0882 | Average Loss: 0.2751
# Accuracy: 0.857500 | Time: 00:00:01
# Epoch: 4 | Iter:    0 | Time: 00:02:55 | Train Loss: 0.2814 | Average Loss: 0.2716
# Epoch: 4 | Iter:   20 | Time: 00:02:59 | Train Loss: 0.0271 | Average Loss: 0.2677
# Epoch: 4 | Iter:   40 | Time: 00:03:03 | Train Loss: 0.5645 | Average Loss: 0.2669
# Epoch: 4 | Iter:   60 | Time: 00:03:06 | Train Loss: 0.0835 | Average Loss: 0.2645
# Epoch: 4 | Iter:   80 | Time: 00:03:10 | Train Loss: 0.3114 | Average Loss: 0.2616
# Epoch: 4 | Iter:  100 | Time: 00:03:14 | Train Loss: 0.1764 | Average Loss: 0.2598
# Epoch: 4 | Iter:  120 | Time: 00:03:18 | Train Loss: 0.5578 | Average Loss: 0.2594
# Epoch: 4 | Iter:  140 | Time: 00:03:22 | Train Loss: 0.0049 | Average Loss: 0.2577
# Epoch: 4 | Iter:  160 | Time: 00:03:25 | Train Loss: 0.5144 | Average Loss: 0.2557
# Epoch: 4 | Iter:  180 | Time: 00:03:29 | Train Loss: 0.0286 | Average Loss: 0.2535
# Epoch: 4 | Iter:  200 | Time: 00:03:33 | Train Loss: 0.3510 | Average Loss: 0.2517
# Epoch: 4 | Iter:  220 | Time: 00:03:37 | Train Loss: 0.2186 | Average Loss: 0.2497
# Epoch: 4 | Iter:  240 | Time: 00:03:40 | Train Loss: 0.0174 | Average Loss: 0.2495
# Epoch: 4 | Iter:  260 | Time: 00:03:44 | Train Loss: 0.0096 | Average Loss: 0.2470
# Epoch: 4 | Iter:  280 | Time: 00:03:48 | Train Loss: 0.0152 | Average Loss: 0.2447
# Accuracy: 0.880000 | Time: 00:00:01
# Epoch: 5 | Iter:    0 | Time: 00:03:53 | Train Loss: 0.0076 | Average Loss: 0.2426
# Epoch: 5 | Iter:   20 | Time: 00:03:57 | Train Loss: 0.1434 | Average Loss: 0.2402
# Epoch: 5 | Iter:   40 | Time: 00:04:01 | Train Loss: 0.0763 | Average Loss: 0.2382
# Epoch: 5 | Iter:   60 | Time: 00:04:05 | Train Loss: 0.0727 | Average Loss: 0.2354
# Epoch: 5 | Iter:   80 | Time: 00:04:08 | Train Loss: 0.1701 | Average Loss: 0.2329
# Epoch: 5 | Iter:  100 | Time: 00:04:12 | Train Loss: 0.1867 | Average Loss: 0.2312
# Epoch: 5 | Iter:  120 | Time: 00:04:16 | Train Loss: 0.1135 | Average Loss: 0.2294
# Epoch: 5 | Iter:  140 | Time: 00:04:20 | Train Loss: 0.0086 | Average Loss: 0.2273
# Epoch: 5 | Iter:  160 | Time: 00:04:24 | Train Loss: 0.0187 | Average Loss: 0.2261
# Epoch: 5 | Iter:  180 | Time: 00:04:27 | Train Loss: 0.0123 | Average Loss: 0.2243
# Epoch: 5 | Iter:  200 | Time: 00:04:31 | Train Loss: 0.3901 | Average Loss: 0.2234
# Epoch: 5 | Iter:  220 | Time: 00:04:35 | Train Loss: 0.0433 | Average Loss: 0.2219
# Epoch: 5 | Iter:  240 | Time: 00:04:39 | Train Loss: 0.2327 | Average Loss: 0.2203
# Epoch: 5 | Iter:  260 | Time: 00:04:43 | Train Loss: 0.0094 | Average Loss: 0.2184
# Epoch: 5 | Iter:  280 | Time: 00:04:46 | Train Loss: 0.0180 | Average Loss: 0.2168
# Accuracy: 0.890000 | Time: 00:00:01
# Epoch: 6 | Iter:    0 | Time: 00:04:52 | Train Loss: 0.0207 | Average Loss: 0.2148
# Epoch: 6 | Iter:   20 | Time: 00:04:55 | Train Loss: 0.1059 | Average Loss: 0.2133
# Epoch: 6 | Iter:   40 | Time: 00:04:59 | Train Loss: 0.0327 | Average Loss: 0.2116
# Epoch: 6 | Iter:   60 | Time: 00:05:03 | Train Loss: 0.1524 | Average Loss: 0.2102
# Epoch: 6 | Iter:   80 | Time: 00:05:07 | Train Loss: 0.0271 | Average Loss: 0.2087
# Epoch: 6 | Iter:  100 | Time: 00:05:11 | Train Loss: 0.0086 | Average Loss: 0.2067
# Epoch: 6 | Iter:  120 | Time: 00:05:14 | Train Loss: 0.1444 | Average Loss: 0.2048
# Epoch: 6 | Iter:  140 | Time: 00:05:18 | Train Loss: 0.0036 | Average Loss: 0.2033
# Epoch: 6 | Iter:  160 | Time: 00:05:22 | Train Loss: 0.2129 | Average Loss: 0.2031
# Epoch: 6 | Iter:  180 | Time: 00:05:26 | Train Loss: 0.0056 | Average Loss: 0.2016
# Epoch: 6 | Iter:  200 | Time: 00:05:30 | Train Loss: 0.3992 | Average Loss: 0.2003
# Epoch: 6 | Iter:  220 | Time: 00:05:33 | Train Loss: 0.0111 | Average Loss: 0.1993
# Epoch: 6 | Iter:  240 | Time: 00:05:37 | Train Loss: 0.1011 | Average Loss: 0.1981
# Epoch: 6 | Iter:  260 | Time: 00:05:41 | Train Loss: 0.0058 | Average Loss: 0.1966
# Epoch: 6 | Iter:  280 | Time: 00:05:45 | Train Loss: 0.1090 | Average Loss: 0.1954
# Accuracy: 0.882500 | Time: 00:00:01
# Epoch: 7 | Iter:    0 | Time: 00:05:50 | Train Loss: 0.0007 | Average Loss: 0.1938
# Epoch: 7 | Iter:   20 | Time: 00:05:54 | Train Loss: 0.0224 | Average Loss: 0.1925
# Epoch: 7 | Iter:   40 | Time: 00:05:57 | Train Loss: 0.0147 | Average Loss: 0.1909
# Epoch: 7 | Iter:   60 | Time: 00:06:01 | Train Loss: 0.0055 | Average Loss: 0.1896
# Epoch: 7 | Iter:   80 | Time: 00:06:05 | Train Loss: 0.0045 | Average Loss: 0.1881
# Epoch: 7 | Iter:  100 | Time: 00:06:09 | Train Loss: 0.0055 | Average Loss: 0.1869
# Epoch: 7 | Iter:  120 | Time: 00:06:13 | Train Loss: 0.0004 | Average Loss: 0.1855
# Epoch: 7 | Iter:  140 | Time: 00:06:16 | Train Loss: 0.0088 | Average Loss: 0.1839
# Epoch: 7 | Iter:  160 | Time: 00:06:20 | Train Loss: 0.0220 | Average Loss: 0.1823
# Epoch: 7 | Iter:  180 | Time: 00:06:24 | Train Loss: 0.0141 | Average Loss: 0.1811
# Epoch: 7 | Iter:  200 | Time: 00:06:28 | Train Loss: 0.0181 | Average Loss: 0.1797
# Epoch: 7 | Iter:  220 | Time: 00:06:32 | Train Loss: 0.0391 | Average Loss: 0.1783
# Epoch: 7 | Iter:  240 | Time: 00:06:35 | Train Loss: 0.0002 | Average Loss: 0.1769
# Epoch: 7 | Iter:  260 | Time: 00:06:39 | Train Loss: 0.0491 | Average Loss: 0.1754
# Epoch: 7 | Iter:  280 | Time: 00:06:43 | Train Loss: 0.0666 | Average Loss: 0.1741
# Accuracy: 0.910000 | Time: 00:00:01
# Epoch: 8 | Iter:    0 | Time: 00:06:48 | Train Loss: 0.0558 | Average Loss: 0.1728
# Epoch: 8 | Iter:   20 | Time: 00:06:52 | Train Loss: 0.0006 | Average Loss: 0.1714
# Epoch: 8 | Iter:   40 | Time: 00:06:56 | Train Loss: 0.0854 | Average Loss: 0.1705
# Epoch: 8 | Iter:   60 | Time: 00:07:00 | Train Loss: 0.0324 | Average Loss: 0.1704
# Epoch: 8 | Iter:   80 | Time: 00:07:03 | Train Loss: 0.2513 | Average Loss: 0.1699
# Epoch: 8 | Iter:  100 | Time: 00:07:07 | Train Loss: 0.5443 | Average Loss: 0.1697
# Epoch: 8 | Iter:  120 | Time: 00:07:11 | Train Loss: 0.0737 | Average Loss: 0.1703
# Epoch: 8 | Iter:  140 | Time: 00:07:15 | Train Loss: 0.0210 | Average Loss: 0.1702
# Epoch: 8 | Iter:  160 | Time: 00:07:19 | Train Loss: 0.0077 | Average Loss: 0.1701
# Epoch: 8 | Iter:  180 | Time: 00:07:23 | Train Loss: 0.1251 | Average Loss: 0.1695
# Epoch: 8 | Iter:  200 | Time: 00:07:26 | Train Loss: 0.4148 | Average Loss: 0.1691
# Epoch: 8 | Iter:  220 | Time: 00:07:30 | Train Loss: 0.0044 | Average Loss: 0.1683
# Epoch: 8 | Iter:  240 | Time: 00:07:34 | Train Loss: 0.0004 | Average Loss: 0.1679
# Epoch: 8 | Iter:  260 | Time: 00:07:38 | Train Loss: 0.0017 | Average Loss: 0.1669
# Epoch: 8 | Iter:  280 | Time: 00:07:42 | Train Loss: 0.0539 | Average Loss: 0.1660
# Accuracy: 0.887500 | Time: 00:00:01
# Epoch: 9 | Iter:    0 | Time: 00:07:47 | Train Loss: 0.0220 | Average Loss: 0.1652
# Epoch: 9 | Iter:   20 | Time: 00:07:50 | Train Loss: 0.0060 | Average Loss: 0.1643
# Epoch: 9 | Iter:   40 | Time: 00:07:54 | Train Loss: 0.0075 | Average Loss: 0.1635
# Epoch: 9 | Iter:   60 | Time: 00:07:58 | Train Loss: 0.0126 | Average Loss: 0.1629
# Epoch: 9 | Iter:   80 | Time: 00:08:02 | Train Loss: 0.0019 | Average Loss: 0.1622
# Epoch: 9 | Iter:  100 | Time: 00:08:06 | Train Loss: 0.1040 | Average Loss: 0.1614
# Epoch: 9 | Iter:  120 | Time: 00:08:09 | Train Loss: 0.0191 | Average Loss: 0.1603
# Epoch: 9 | Iter:  140 | Time: 00:08:13 | Train Loss: 0.0038 | Average Loss: 0.1598
# Epoch: 9 | Iter:  160 | Time: 00:08:17 | Train Loss: 0.0279 | Average Loss: 0.1587
# Epoch: 9 | Iter:  180 | Time: 00:08:21 | Train Loss: 0.0079 | Average Loss: 0.1576
# Epoch: 9 | Iter:  200 | Time: 00:08:25 | Train Loss: 0.0166 | Average Loss: 0.1568
# Epoch: 9 | Iter:  220 | Time: 00:08:28 | Train Loss: 0.0049 | Average Loss: 0.1559
# Epoch: 9 | Iter:  240 | Time: 00:08:32 | Train Loss: 0.0001 | Average Loss: 0.1551
# Epoch: 9 | Iter:  260 | Time: 00:08:36 | Train Loss: 0.1787 | Average Loss: 0.1546
# Epoch: 9 | Iter:  280 | Time: 00:08:40 | Train Loss: 0.2277 | Average Loss: 0.1540
# Accuracy: 0.890000 | Time: 00:00:01
# Epoch:10 | Iter:    0 | Time: 00:08:45 | Train Loss: 0.0004 | Average Loss: 0.1535
# Epoch:10 | Iter:   20 | Time: 00:08:49 | Train Loss: 0.0026 | Average Loss: 0.1530
# Epoch:10 | Iter:   40 | Time: 00:08:53 | Train Loss: 0.0067 | Average Loss: 0.1523
# Epoch:10 | Iter:   60 | Time: 00:08:56 | Train Loss: 0.0001 | Average Loss: 0.1514
# Epoch:10 | Iter:   80 | Time: 00:09:00 | Train Loss: 0.0011 | Average Loss: 0.1506
# Epoch:10 | Iter:  100 | Time: 00:09:04 | Train Loss: 0.0134 | Average Loss: 0.1498
# Epoch:10 | Iter:  120 | Time: 00:09:08 | Train Loss: 0.0158 | Average Loss: 0.1492
# Epoch:10 | Iter:  140 | Time: 00:09:11 | Train Loss: 0.0088 | Average Loss: 0.1485
# Epoch:10 | Iter:  160 | Time: 00:09:15 | Train Loss: 0.0661 | Average Loss: 0.1482
# Epoch:10 | Iter:  180 | Time: 00:09:19 | Train Loss: 0.0000 | Average Loss: 0.1474
# Epoch:10 | Iter:  200 | Time: 00:09:23 | Train Loss: 0.0041 | Average Loss: 0.1468
# Epoch:10 | Iter:  220 | Time: 00:09:27 | Train Loss: 0.0024 | Average Loss: 0.1460
# Epoch:10 | Iter:  240 | Time: 00:09:30 | Train Loss: 0.0217 | Average Loss: 0.1452
# Epoch:10 | Iter:  260 | Time: 00:09:34 | Train Loss: 0.7528 | Average Loss: 0.1451
# Epoch:10 | Iter:  280 | Time: 00:09:38 | Train Loss: 0.2063 | Average Loss: 0.1451
# Accuracy: 0.902500 | Time: 00:00:01
# Epoch:11 | Iter:    0 | Time: 00:09:43 | Train Loss: 0.0016 | Average Loss: 0.1447
# Epoch:11 | Iter:   20 | Time: 00:09:47 | Train Loss: 0.0226 | Average Loss: 0.1444
# Epoch:11 | Iter:   40 | Time: 00:09:51 | Train Loss: 0.0265 | Average Loss: 0.1440
# Epoch:11 | Iter:   60 | Time: 00:09:55 | Train Loss: 0.0109 | Average Loss: 0.1436
# Epoch:11 | Iter:   80 | Time: 00:09:58 | Train Loss: 0.0034 | Average Loss: 0.1432
# Epoch:11 | Iter:  100 | Time: 00:10:02 | Train Loss: 0.1379 | Average Loss: 0.1428
# Epoch:11 | Iter:  120 | Time: 00:10:06 | Train Loss: 0.3776 | Average Loss: 0.1424
# Epoch:11 | Iter:  140 | Time: 00:10:10 | Train Loss: 0.0039 | Average Loss: 0.1417
# Epoch:11 | Iter:  160 | Time: 00:10:14 | Train Loss: 0.0042 | Average Loss: 0.1410
# Epoch:11 | Iter:  180 | Time: 00:10:17 | Train Loss: 0.0341 | Average Loss: 0.1405
# Epoch:11 | Iter:  200 | Time: 00:10:21 | Train Loss: 0.0137 | Average Loss: 0.1399
# Epoch:11 | Iter:  220 | Time: 00:10:25 | Train Loss: 0.0133 | Average Loss: 0.1392
# Epoch:11 | Iter:  240 | Time: 00:10:29 | Train Loss: 0.0180 | Average Loss: 0.1388
# Epoch:11 | Iter:  260 | Time: 00:10:33 | Train Loss: 0.4403 | Average Loss: 0.1384
# Epoch:11 | Iter:  280 | Time: 00:10:36 | Train Loss: 0.0121 | Average Loss: 0.1378
# Accuracy: 0.910000 | Time: 00:00:01
# Epoch:12 | Iter:    0 | Time: 00:10:42 | Train Loss: 0.0009 | Average Loss: 0.1373
# Epoch:12 | Iter:   20 | Time: 00:10:45 | Train Loss: 0.0047 | Average Loss: 0.1368
# Epoch:12 | Iter:   40 | Time: 00:10:49 | Train Loss: 0.0347 | Average Loss: 0.1364
# Epoch:12 | Iter:   60 | Time: 00:10:53 | Train Loss: 0.1839 | Average Loss: 0.1360
# Epoch:12 | Iter:   80 | Time: 00:10:57 | Train Loss: 0.0007 | Average Loss: 0.1354
# Epoch:12 | Iter:  100 | Time: 00:11:01 | Train Loss: 0.0115 | Average Loss: 0.1351
# Epoch:12 | Iter:  120 | Time: 00:11:04 | Train Loss: 0.6973 | Average Loss: 0.1347
# Epoch:12 | Iter:  140 | Time: 00:11:08 | Train Loss: 0.0073 | Average Loss: 0.1343
# Epoch:12 | Iter:  160 | Time: 00:11:12 | Train Loss: 0.0022 | Average Loss: 0.1338
# Epoch:12 | Iter:  180 | Time: 00:11:16 | Train Loss: 0.0050 | Average Loss: 0.1332
# Epoch:12 | Iter:  200 | Time: 00:11:20 | Train Loss: 0.0008 | Average Loss: 0.1328
# Epoch:12 | Iter:  220 | Time: 00:11:23 | Train Loss: 0.0864 | Average Loss: 0.1326
# Epoch:12 | Iter:  240 | Time: 00:11:27 | Train Loss: 0.2211 | Average Loss: 0.1324
# Epoch:12 | Iter:  260 | Time: 00:11:31 | Train Loss: 0.0277 | Average Loss: 0.1320
# Epoch:12 | Iter:  280 | Time: 00:11:35 | Train Loss: 0.0109 | Average Loss: 0.1315
# Accuracy: 0.875000 | Time: 00:00:01
# Epoch:13 | Iter:    0 | Time: 00:11:40 | Train Loss: 0.0028 | Average Loss: 0.1309
# Epoch:13 | Iter:   20 | Time: 00:11:44 | Train Loss: 0.1283 | Average Loss: 0.1304
# Epoch:13 | Iter:   40 | Time: 00:11:48 | Train Loss: 0.0109 | Average Loss: 0.1301
# Epoch:13 | Iter:   60 | Time: 00:11:51 | Train Loss: 0.0009 | Average Loss: 0.1297
# Epoch:13 | Iter:   80 | Time: 00:11:55 | Train Loss: 0.0036 | Average Loss: 0.1293
# Epoch:13 | Iter:  100 | Time: 00:11:59 | Train Loss: 0.1539 | Average Loss: 0.1288
# Epoch:13 | Iter:  120 | Time: 00:12:03 | Train Loss: 0.0022 | Average Loss: 0.1285
# Epoch:13 | Iter:  140 | Time: 00:12:07 | Train Loss: 0.0298 | Average Loss: 0.1282
# Epoch:13 | Iter:  160 | Time: 00:12:10 | Train Loss: 0.0452 | Average Loss: 0.1282
# Epoch:13 | Iter:  180 | Time: 00:12:14 | Train Loss: 0.0025 | Average Loss: 0.1279
# Epoch:13 | Iter:  200 | Time: 00:12:18 | Train Loss: 0.0232 | Average Loss: 0.1275
# Epoch:13 | Iter:  220 | Time: 00:12:22 | Train Loss: 0.0045 | Average Loss: 0.1272
# Epoch:13 | Iter:  240 | Time: 00:12:26 | Train Loss: 0.0261 | Average Loss: 0.1270
# Epoch:13 | Iter:  260 | Time: 00:12:29 | Train Loss: 0.4071 | Average Loss: 0.1270
# Epoch:13 | Iter:  280 | Time: 00:12:33 | Train Loss: 0.0092 | Average Loss: 0.1267
# Accuracy: 0.885000 | Time: 00:00:01
# Epoch:14 | Iter:    0 | Time: 00:12:38 | Train Loss: 0.1324 | Average Loss: 0.1263
# Epoch:14 | Iter:   20 | Time: 00:12:42 | Train Loss: 0.3369 | Average Loss: 0.1261
# Epoch:14 | Iter:   40 | Time: 00:12:46 | Train Loss: 0.1536 | Average Loss: 0.1259
# Epoch:14 | Iter:   60 | Time: 00:12:50 | Train Loss: 0.0002 | Average Loss: 0.1254
# Epoch:14 | Iter:   80 | Time: 00:12:53 | Train Loss: 0.0001 | Average Loss: 0.1252
# Epoch:14 | Iter:  100 | Time: 00:12:57 | Train Loss: 0.0008 | Average Loss: 0.1246
# Epoch:14 | Iter:  120 | Time: 00:13:01 | Train Loss: 0.1419 | Average Loss: 0.1245
# Epoch:14 | Iter:  140 | Time: 00:13:05 | Train Loss: 0.0124 | Average Loss: 0.1241
# Epoch:14 | Iter:  160 | Time: 00:13:09 | Train Loss: 0.2131 | Average Loss: 0.1238
# Epoch:14 | Iter:  180 | Time: 00:13:12 | Train Loss: 0.0011 | Average Loss: 0.1236
# Epoch:14 | Iter:  200 | Time: 00:13:16 | Train Loss: 0.2287 | Average Loss: 0.1233
# Epoch:14 | Iter:  220 | Time: 00:13:20 | Train Loss: 0.0344 | Average Loss: 0.1231
# Epoch:14 | Iter:  240 | Time: 00:13:24 | Train Loss: 0.0005 | Average Loss: 0.1226
# Epoch:14 | Iter:  260 | Time: 00:13:28 | Train Loss: 0.0114 | Average Loss: 0.1223
# Epoch:14 | Iter:  280 | Time: 00:13:31 | Train Loss: 1.0562 | Average Loss: 0.1226
# Accuracy: 0.857500 | Time: 00:00:01
# Epoch:15 | Iter:    0 | Time: 00:13:37 | Train Loss: 0.3620 | Average Loss: 0.1229
# Epoch:15 | Iter:   20 | Time: 00:13:40 | Train Loss: 0.0037 | Average Loss: 0.1226
# Epoch:15 | Iter:   40 | Time: 00:13:44 | Train Loss: 0.5425 | Average Loss: 0.1224
# Epoch:15 | Iter:   60 | Time: 00:13:48 | Train Loss: 0.0034 | Average Loss: 0.1223
# Epoch:15 | Iter:   80 | Time: 00:13:52 | Train Loss: 0.0086 | Average Loss: 0.1222
# Epoch:15 | Iter:  100 | Time: 00:13:56 | Train Loss: 0.0039 | Average Loss: 0.1219
# Epoch:15 | Iter:  120 | Time: 00:13:59 | Train Loss: 0.0316 | Average Loss: 0.1217
# Epoch:15 | Iter:  140 | Time: 00:14:03 | Train Loss: 0.0004 | Average Loss: 0.1217
# Epoch:15 | Iter:  160 | Time: 00:14:07 | Train Loss: 0.0495 | Average Loss: 0.1216
# Epoch:15 | Iter:  180 | Time: 00:14:11 | Train Loss: 0.0121 | Average Loss: 0.1212
# Epoch:15 | Iter:  200 | Time: 00:14:15 | Train Loss: 0.0078 | Average Loss: 0.1208
# Epoch:15 | Iter:  220 | Time: 00:14:18 | Train Loss: 0.0017 | Average Loss: 0.1203
# Epoch:15 | Iter:  240 | Time: 00:14:22 | Train Loss: 0.2503 | Average Loss: 0.1199
# Epoch:15 | Iter:  260 | Time: 00:14:26 | Train Loss: 0.0222 | Average Loss: 0.1194
# Epoch:15 | Iter:  280 | Time: 00:14:30 | Train Loss: 0.0145 | Average Loss: 0.1189
# Accuracy: 0.902500 | Time: 00:00:01
# Epoch:16 | Iter:    0 | Time: 00:14:35 | Train Loss: 0.0023 | Average Loss: 0.1185
# Epoch:16 | Iter:   20 | Time: 00:14:39 | Train Loss: 0.0018 | Average Loss: 0.1182
# Epoch:16 | Iter:   40 | Time: 00:14:42 | Train Loss: 0.0026 | Average Loss: 0.1177
# Epoch:16 | Iter:   60 | Time: 00:14:46 | Train Loss: 0.0045 | Average Loss: 0.1173
# Epoch:16 | Iter:   80 | Time: 00:14:50 | Train Loss: 0.0151 | Average Loss: 0.1169
# Epoch:16 | Iter:  100 | Time: 00:14:54 | Train Loss: 0.0012 | Average Loss: 0.1165
# Epoch:16 | Iter:  120 | Time: 00:14:58 | Train Loss: 0.0041 | Average Loss: 0.1160
# Epoch:16 | Iter:  140 | Time: 00:15:02 | Train Loss: 0.0002 | Average Loss: 0.1155
# Epoch:16 | Iter:  160 | Time: 00:15:05 | Train Loss: 0.0067 | Average Loss: 0.1151
# Epoch:16 | Iter:  180 | Time: 00:15:09 | Train Loss: 0.0001 | Average Loss: 0.1146
# Epoch:16 | Iter:  200 | Time: 00:15:13 | Train Loss: 0.1109 | Average Loss: 0.1142
# Epoch:16 | Iter:  220 | Time: 00:15:17 | Train Loss: 0.0013 | Average Loss: 0.1138
# Epoch:16 | Iter:  240 | Time: 00:15:21 | Train Loss: 0.0001 | Average Loss: 0.1134
# Epoch:16 | Iter:  260 | Time: 00:15:24 | Train Loss: 0.0486 | Average Loss: 0.1130
# Epoch:16 | Iter:  280 | Time: 00:15:28 | Train Loss: 0.0662 | Average Loss: 0.1126
# Accuracy: 0.900000 | Time: 00:00:01
# Epoch:17 | Iter:    0 | Time: 00:15:33 | Train Loss: 0.0001 | Average Loss: 0.1121
# Epoch:17 | Iter:   20 | Time: 00:15:37 | Train Loss: 0.0011 | Average Loss: 0.1117
# Epoch:17 | Iter:   40 | Time: 00:15:41 | Train Loss: 0.0013 | Average Loss: 0.1112
# Epoch:17 | Iter:   60 | Time: 00:15:45 | Train Loss: 0.0002 | Average Loss: 0.1108
# Epoch:17 | Iter:   80 | Time: 00:15:48 | Train Loss: 0.0001 | Average Loss: 0.1104
# Epoch:17 | Iter:  100 | Time: 00:15:52 | Train Loss: 0.0151 | Average Loss: 0.1099
# Epoch:17 | Iter:  120 | Time: 00:15:56 | Train Loss: 0.0001 | Average Loss: 0.1095
# Epoch:17 | Iter:  140 | Time: 00:16:00 | Train Loss: 0.0001 | Average Loss: 0.1091
# Epoch:17 | Iter:  160 | Time: 00:16:04 | Train Loss: 0.0010 | Average Loss: 0.1087
# Epoch:17 | Iter:  180 | Time: 00:16:08 | Train Loss: 0.0002 | Average Loss: 0.1082
# Epoch:17 | Iter:  200 | Time: 00:16:11 | Train Loss: 0.0025 | Average Loss: 0.1078
# Epoch:17 | Iter:  220 | Time: 00:16:15 | Train Loss: 0.0013 | Average Loss: 0.1074
# Epoch:17 | Iter:  240 | Time: 00:16:19 | Train Loss: 0.0000 | Average Loss: 0.1070
# Epoch:17 | Iter:  260 | Time: 00:16:23 | Train Loss: 0.0001 | Average Loss: 0.1065
# Epoch:17 | Iter:  280 | Time: 00:16:27 | Train Loss: 0.0000 | Average Loss: 0.1061
# Accuracy: 0.920000 | Time: 00:00:01
# Epoch:18 | Iter:    0 | Time: 00:16:32 | Train Loss: 0.0001 | Average Loss: 0.1057
# Epoch:18 | Iter:   20 | Time: 00:16:35 | Train Loss: 0.0007 | Average Loss: 0.1053
# Epoch:18 | Iter:   40 | Time: 00:16:39 | Train Loss: 0.0005 | Average Loss: 0.1049
# Epoch:18 | Iter:   60 | Time: 00:16:43 | Train Loss: 0.0001 | Average Loss: 0.1045
# Epoch:18 | Iter:   80 | Time: 00:16:47 | Train Loss: 0.0001 | Average Loss: 0.1041
# Epoch:18 | Iter:  100 | Time: 00:16:51 | Train Loss: 0.0001 | Average Loss: 0.1037
# Epoch:18 | Iter:  120 | Time: 00:16:54 | Train Loss: 0.0002 | Average Loss: 0.1034
# Epoch:18 | Iter:  140 | Time: 00:16:58 | Train Loss: 0.0002 | Average Loss: 0.1030
# Epoch:18 | Iter:  160 | Time: 00:17:02 | Train Loss: 0.0015 | Average Loss: 0.1026
# Epoch:18 | Iter:  180 | Time: 00:17:06 | Train Loss: 0.0001 | Average Loss: 0.1022
# Epoch:18 | Iter:  200 | Time: 00:17:10 | Train Loss: 0.0088 | Average Loss: 0.1018
# Epoch:18 | Iter:  220 | Time: 00:17:13 | Train Loss: 0.0002 | Average Loss: 0.1015
# Epoch:18 | Iter:  240 | Time: 00:17:17 | Train Loss: 0.0000 | Average Loss: 0.1011
# Epoch:18 | Iter:  260 | Time: 00:17:21 | Train Loss: 0.0008 | Average Loss: 0.1007
# Epoch:18 | Iter:  280 | Time: 00:17:25 | Train Loss: 0.0004 | Average Loss: 0.1003
# Accuracy: 0.922500 | Time: 00:00:01
# Epoch:19 | Iter:    0 | Time: 00:17:30 | Train Loss: 0.0002 | Average Loss: 0.1000
# Epoch:19 | Iter:   20 | Time: 00:17:34 | Train Loss: 0.0015 | Average Loss: 0.0996
# Epoch:19 | Iter:   40 | Time: 00:17:38 | Train Loss: 0.0006 | Average Loss: 0.0992
# Epoch:19 | Iter:   60 | Time: 00:17:41 | Train Loss: 0.0001 | Average Loss: 0.0989
# Epoch:19 | Iter:   80 | Time: 00:17:45 | Train Loss: 0.0001 | Average Loss: 0.0985
# Epoch:19 | Iter:  100 | Time: 00:17:49 | Train Loss: 0.0001 | Average Loss: 0.0982
# Epoch:19 | Iter:  120 | Time: 00:17:53 | Train Loss: 0.0001 | Average Loss: 0.0978
# Epoch:19 | Iter:  140 | Time: 00:17:57 | Train Loss: 0.0000 | Average Loss: 0.0974
# Epoch:19 | Iter:  160 | Time: 00:18:00 | Train Loss: 0.0001 | Average Loss: 0.0971
# Epoch:19 | Iter:  180 | Time: 00:18:04 | Train Loss: 0.0000 | Average Loss: 0.0967
# Epoch:19 | Iter:  200 | Time: 00:18:08 | Train Loss: 0.0003 | Average Loss: 0.0964
# Epoch:19 | Iter:  220 | Time: 00:18:12 | Train Loss: 0.0003 | Average Loss: 0.0961
# Epoch:19 | Iter:  240 | Time: 00:18:16 | Train Loss: 0.0000 | Average Loss: 0.0957
# Epoch:19 | Iter:  260 | Time: 00:18:19 | Train Loss: 0.0002 | Average Loss: 0.0954
# Epoch:19 | Iter:  280 | Time: 00:18:23 | Train Loss: 0.0000 | Average Loss: 0.0950
# Accuracy: 0.922500 | Time: 00:00:01
# Epoch:20 | Iter:    0 | Time: 00:18:28 | Train Loss: 0.0001 | Average Loss: 0.0947
# Epoch:20 | Iter:   20 | Time: 00:18:32 | Train Loss: 0.0002 | Average Loss: 0.0944
# Epoch:20 | Iter:   40 | Time: 00:18:36 | Train Loss: 0.0002 | Average Loss: 0.0941
# Epoch:20 | Iter:   60 | Time: 00:18:40 | Train Loss: 0.0001 | Average Loss: 0.0937
# Epoch:20 | Iter:   80 | Time: 00:18:44 | Train Loss: 0.0001 | Average Loss: 0.0934
# Epoch:20 | Iter:  100 | Time: 00:18:47 | Train Loss: 0.0001 | Average Loss: 0.0931
# Epoch:20 | Iter:  120 | Time: 00:18:51 | Train Loss: 0.0001 | Average Loss: 0.0928
# Epoch:20 | Iter:  140 | Time: 00:18:55 | Train Loss: 0.0000 | Average Loss: 0.0924
# Epoch:20 | Iter:  160 | Time: 00:18:59 | Train Loss: 0.0001 | Average Loss: 0.0921
# Epoch:20 | Iter:  180 | Time: 00:19:03 | Train Loss: 0.0000 | Average Loss: 0.0918
# Epoch:20 | Iter:  200 | Time: 00:19:06 | Train Loss: 0.0001 | Average Loss: 0.0915
# Epoch:20 | Iter:  220 | Time: 00:19:10 | Train Loss: 0.0002 | Average Loss: 0.0912
# Epoch:20 | Iter:  240 | Time: 00:19:14 | Train Loss: 0.0000 | Average Loss: 0.0909
# Epoch:20 | Iter:  260 | Time: 00:19:18 | Train Loss: 0.0001 | Average Loss: 0.0906
# Epoch:20 | Iter:  280 | Time: 00:19:22 | Train Loss: 0.0000 | Average Loss: 0.0903
# Accuracy: 0.925000 | Time: 00:00:01
# max accuracy tensor(0.9250, device='cuda:0')

# %% [markdown]
# **Answer**:
#
# Accuracy on test set: 0.9250
#
# ResNet has more convolution layers so it's easier for it to learn more features that's why its accuracy increases.

# %% [markdown]
# ## Submission guidelines
# ---
# Extract the downloaded .zip file to a folder of your preference. The input and output paths are predefined and **DO NOT** change them, (we assume that 'Surname_Givenname_SBUID_hw4' is your working directory, and all the paths are relative to this directory).  The image read and write functions are already written for you. All you need to do is to fill in the blanks as indicated to generate proper outputs. **DO NOT** zip and upload the dataset on blackboard due to size limit.
#
# When submitting your .zip file through blackboard, please
# -- name your .zip file as **Surname_Givenname_SBUID_hw*.zip**.
#
# This zip file should include:
# ```
# Surname_Givenname_SBUID_hw*
#         |---Surname_Givenname_SBUID_hw*.ipynb
#         |---Surname_Givenname_SBUID_hw*.pdf
# ```
#
# For instance, student Yann LeCun should submit a zip file named "LeCun_Yann_111134567_hw4.zip" for homework4 in this structure:
# ```
# LeCun_Yann_111134567_hw4
#         |---LeCun_Yann_111134567_hw4.ipynb
#         |---LeCun_Yann_111134567_hw4.pdf
# ```
#
# The **Surname_Givenname_SBUID_hw*.pdf** should include a **google shared link**. To generate the **google shared link**, first create a folder named **Surname_Givenname_SBUID_hw*** in your Google Drive with your Stony Brook account. The structure of the files in the folder should be exactly the same as the one you downloaded. If you alter the folder structures, the grading of your homework will be significantly delayed and possibly penalized.
#
# Then right click this folder, click ***Get shareable link***, in the People textfield, enter TA's emails. Make sure that TAs who have the link **can edit**, ***not just*** **can view**, and also **uncheck** the **Notify people** box.
#
# Colab has a good feature of version control, you should take advantage of this to save your work properly. However, the timestamp of the submission made in blackboard is the only one that we consider for grading. To be more specific, we will only grade the version of your code right before the timestamp of the submission made in blackboard.
#
# You are encouraged to post and answer questions on Piazza. Based on the amount of email that we have received in past years, there might be dealys in replying to personal emails. Please ask questions on Piazza and send emails only for personal issues.
#
# Be aware that your code will undergo plagiarism check both vertically and horizontally. Please do your own work.
#
# **Late submission penalty:** <br>
# There will be a 10% penalty per day for late submission. However, you will have 4 days throughout the whole semester to submit late without penalty. Note that the grace period is calculated by days instead of hours. If you submit the homework one minute after the deadline, one late day will be counted. Likewise, if you submit one minute after the deadline, the 10% penaly will be imposed if not using the grace period.

# %% [markdown]
# <!--Write your report here in markdown or html-->
